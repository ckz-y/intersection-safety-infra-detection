# %% [markdown]
# # Setup

# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import os

os.system(
    "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py"
)
os.system(
    "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py"
)
os.system(
    "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py"
)
os.system(
    "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py"
)
os.system(
    "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py"
)
# Out:
# 0

# %%
import torch
from torch.utils.data import Subset, DataLoader

from torchvision import tv_tensors
from torchvision.io import decode_image

from torchvision.transforms import v2 as T
from torchvision.transforms.v2.functional import (
    to_dtype,
    get_size,
    convert_bounding_box_format,
)

from torchvision.models.detection import fasterrcnn_resnet50_fpn_v2
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

import pandas as pd
import numpy as np

import os
import json

import math
import sys

import utils
from engine import train_one_epoch, evaluate

# %% [markdown]
# # Data

# %%
class AerialImageryDataset(torch.utils.data.Dataset):
    def __init__(self, image_dir_path, annotation_path, background_weight, train=False):
        self.image_dir_path = image_dir_path

        self.transforms = []
        if train:
            self.transforms.append(T.RandomHorizontalFlip(p=0.5))
            self.transforms.append(T.RandomVerticalFlip(p=0.5))

        self.transforms.append(T.ToDtype(torch.float, scale=True))
        self.transforms.append(T.ToPureTensor())
        self.transforms = T.Compose(self.transforms)

        self.label_map = {"daylighting": 1, "safety_islands": 2, "curb_extensions": 3}

        with open(annotation_path) as json_file:
            self.annotations = json.load(json_file)

        self.weights = []

        for item in tqdm(self.annotations):
            curr_weight = 1

            if "label" in item:
                for label in item["label"]:
                    if label["rectanglelabels"][0] == "curb_extensions":
                        curr_weight = 3
                        break
            else:
                curr_weight = background_weight

            self.weights.append(curr_weight)

    def __getitem__(self, idx):
        img_path = os.path.join(
            self.image_dir_path, self.annotations[idx]["image"].split("%5C")[-1]
        )

        img = decode_image(img_path, mode="RGB")

        if img.dtype != torch.float:
            img = to_dtype(img, dtype=torch.float, scale=True)

        img = tv_tensors.Image(img)

        if "label" in self.annotations[idx]:
            boxes = [
                [i["x"], i["y"], i["width"], i["height"]]
                for i in self.annotations[idx]["label"]
            ]

            boxes = convert_bounding_box_format(
                tv_tensors.BoundingBoxes(
                    boxes, format="XYWH", canvas_size=get_size(img)
                ),
                new_format="XYXY",
            )
            boxes = tv_tensors.BoundingBoxes(
                boxes * 416 / 100, format="XYXY", canvas_size=get_size(img)
            )
            labels = torch.tensor(
                [
                    self.label_map[i["rectanglelabels"][0]]
                    for i in self.annotations[idx]["label"]
                ]
            )

        else:
            boxes = torch.zeros((0, 4), dtype=torch.float32)
            labels = torch.zeros((0,), dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = int(
            "".join(
                self.annotations[idx]["image"].split("%5C")[-1].split(".")[0].split("_")
            )
        )
        target["area"] = torch.tensor(
            [(box[2] - box[0]) * (box[3] - box[1]) for box in boxes]
        )
        target["iscrowd"] = torch.tensor([0] * len(boxes))

        img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.annotations)

# %%
from tqdm import tqdm

image_path = os.path.join(
    "/content/gdrive/My Drive/Grad School/Dissertation/Data", "test"
)
label_path = os.path.join(
    "/content/gdrive/My Drive/Grad School/Dissertation/Data", "test.json"
)

batch_size = 16

dataset_train = AerialImageryDataset(
    image_dir_path=image_path,
    annotation_path=label_path,
    background_weight=0.0001,
    train=True,
)
dataset_valtest = AerialImageryDataset(
    image_dir_path=image_path,
    annotation_path=label_path,
    background_weight=0.0001,
    train=False,
)


g = torch.Generator()
g.manual_seed(2025)
indices = torch.randperm(n=len(dataset_train), generator=g).tolist()

subset_train = Subset(dataset_train, indices[: int(len(dataset_train) * 0.8)])
subset_val = Subset(
    dataset_valtest,
    indices[int(len(dataset_valtest) * 0.8) : int(len(dataset_valtest) * 0.9)],
)
subset_test = Subset(dataset_valtest, indices[int(len(dataset_valtest) * 0.9) :])

train_weights = [
    dataset_train.weights[idx] for idx in indices[: int(len(dataset_train) * 0.8)]
]

data_loader_train = DataLoader(
    subset_train,
    batch_size=batch_size,
    sampler=torch.utils.data.WeightedRandomSampler(train_weights, len(train_weights)),
    collate_fn=utils.collate_fn,
)
data_loader_val = DataLoader(
    subset_val, batch_size=batch_size, collate_fn=utils.collate_fn
)

data_loader_test = DataLoader(
    subset_test, batch_size=batch_size, collate_fn=utils.collate_fn
)

annotated_indices = []
unannotated_indices = []

for i in subset_val.indices:
    if "label" in subset_val.dataset.annotations[i]:
        annotated_indices.append(i)
    else:
        unannotated_indices.append(i)

subset_val_annotated = Subset(dataset_valtest, annotated_indices)
subset_val_unannotated = Subset(dataset_valtest, unannotated_indices)

data_loader_val_annotated = DataLoader(
    subset_val_annotated, batch_size=batch_size, collate_fn=utils.collate_fn
)

data_loader_val_unannotated = DataLoader(
    subset_val_unannotated, batch_size=batch_size, collate_fn=utils.collate_fn
)
# Out:
# 100%|██████████| 5000/5000 [00:00<00:00, 2452522.51it/s]
# 100%|██████████| 5000/5000 [00:00<00:00, 3004946.27it/s]

# %% [markdown]
# # Training

# %%
def train_one_epoch_no_schedule(
    model, optimizer, data_loader, device, epoch, print_freq
):
    model.train()
    metric_logger = utils.MetricLogger(delimiter="  ")
    metric_logger.add_meter("lr", utils.SmoothedValue(window_size=1, fmt="{value:.6f}"))
    header = f"Epoch: [{epoch}]"

    for images, targets in metric_logger.log_every(data_loader, print_freq, header):
        images = list(image.to(device) for image in images)
        targets = [
            {
                k: v.to(device) if isinstance(v, torch.Tensor) else v
                for k, v in t.items()
            }
            for t in targets
        ]

        with torch.amp.autocast("cuda", enabled=False):
            loss_dict = model(images, targets)
            losses = sum(loss for loss in loss_dict.values())

        # reduce losses over all GPUs for logging purposes
        loss_dict_reduced = utils.reduce_dict(loss_dict)
        losses_reduced = sum(loss for loss in loss_dict_reduced.values())

        loss_value = losses_reduced.item()

        if not math.isfinite(loss_value):
            print(f"Loss is {loss_value}, stopping training")
            print(loss_dict_reduced)
            sys.exit(1)

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        metric_logger.update(loss=losses_reduced, **loss_dict_reduced)
        metric_logger.update(lr=optimizer.param_groups[0]["lr"])

    return metric_logger

# %%
def training(
    model,
    optimizer,
    num_epochs,
    lr,
    save_loc,
    starting_epoch=0,
):
    device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

    model.to(device)

    for epoch in range(starting_epoch, starting_epoch + num_epochs):
        print("EPOCH " + str(epoch))
        train_one_epoch_no_schedule(
            model, optimizer, data_loader_train, device, epoch, print_freq=50
        )
        # evaluate(model_tune, data_loader_train, device=device)
        print("VALIDATION EVALUATION:")
        evaluate(model_tune, data_loader_val, device=device)
        print("VALIDATION ANNOTATED EVALUATION:")
        evaluate(model_tune, data_loader_val_annotated, device=device)

        save_path = save_loc + "_" + str(lr) + "_" + str(epoch) + ".pt"
        save_path = os.path.join(
            "/content/gdrive/My Drive/Grad School/Dissertation/Data", save_path
        )

        checkpoint = {
            "epoch": epoch,
            "model": model.state_dict(),
            "optimizer": optimizer.state_dict(),
        }
        torch.save(checkpoint, save_path)

    print("Training complete!")

# %% [markdown]
# # Experiments

# %% [markdown]
# ## Experiment 1: Fine-tuning

# %%
lr = 0.00001
model_tune = fasterrcnn_resnet50_fpn_v2(
    weights="DEFAULT",
    # image_mean=[0.4715, 0.4723, 0.4587],
    # image_std=[0.2071, 0.1955, 0.1825]
)

# replace the pre-trained head with a new one
num_classes = 4
in_features = model_tune.roi_heads.box_predictor.cls_score.in_features
model_tune.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

params = [p for p in model_tune.parameters() if p.requires_grad]
optimizer = torch.optim.Adam(
    params,
    lr=lr,
)

training(
    model=model_tune,
    optimizer=optimizer,
    num_epochs=30,
    lr=lr,
    save_loc="pretrain_transform_0.0001",
    starting_epoch=0,
)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth
# 100%|██████████| 167M/167M [00:00<00:00, 200MB/s]
# EPOCH 0
# Epoch: [0]  [  0/250]  eta: 2:42:39  lr: 0.000010  loss: 1.9773 (1.9773)  loss_classifier: 1.5056 (1.5056)  loss_box_reg: 0.0564 (0.0564)  loss_objectness: 0.3852 (0.3852)  loss_rpn_box_reg: 0.0301 (0.0301)  time: 39.0371  data: 34.6830  max mem: 18863
# Epoch: [0]  [ 50/250]  eta: 0:22:59  lr: 0.000010  loss: 0.4752 (0.7063)  loss_classifier: 0.2053 (0.3909)  loss_box_reg: 0.1351 (0.1018)  loss_objectness: 0.1129 (0.1916)  loss_rpn_box_reg: 0.0168 (0.0220)  time: 4.6504  data: 2.6652  max mem: 19192
# Epoch: [0]  [100/250]  eta: 0:13:29  lr: 0.000010  loss: 0.4697 (0.6007)  loss_classifier: 0.2034 (0.3045)  loss_box_reg: 0.1644 (0.1310)  loss_objectness: 0.0752 (0.1442)  loss_rpn_box_reg: 0.0144 (0.0210)  time: 3.5498  data: 1.5637  max mem: 19192
# Epoch: [0]  [150/250]  eta: 0:07:39  lr: 0.000010  loss: 0.4782 (0.5585)  loss_classifier: 0.2190 (0.2742)  loss_box_reg: 0.1802 (0.1451)  loss_objectness: 0.0631 (0.1202)  loss_rpn_box_reg: 0.0138 (0.0190)  time: 2.7391  data: 0.7552  max mem: 19192
# Epoch: [0]  [200/250]  eta: 0:03:24  lr: 0.000010  loss: 0.4815 (0.5478)  loss_classifier: 0.2227 (0.2632)  loss_box_reg: 0.1907 (0.1584)  loss_objectness: 0.0542 (0.1072)  loss_rpn_box_reg: 0.0125 (0.0191)  time: 2.5182  data: 0.5281  max mem: 19192
# Epoch: [0]  [249/250]  eta: 0:00:03  lr: 0.000010  loss: 0.4881 (0.5407)  loss_classifier: 0.2200 (0.2572)  loss_box_reg: 0.1974 (0.1678)  loss_objectness: 0.0454 (0.0971)  loss_rpn_box_reg: 0.0121 (0.0186)  time: 2.1633  data: 0.1792  max mem: 19192
# Epoch: [0] Total time: 0:15:35 (3.7429 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8419 (0.8419)  evaluator_time: 0.0164 (0.0164)  time: 0.9599  data: 0.0923  max mem: 19192
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8344 (0.8153)  evaluator_time: 0.0150 (0.0156)  time: 0.9183  data: 0.0906  max mem: 19192
# Test: Total time: 0:00:29 (0.9345 s / it)
# Averaged stats: model_time: 0.8344 (0.8153)  evaluator_time: 0.0150 (0.0156)
# Accumulating evaluation results...
# DONE (t=0.23s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.039
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.040
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.189
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.226
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.011
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:06  model_time: 0.8215 (0.8215)  evaluator_time: 0.1877 (0.1877)  time: 1.1158  data: 0.0972  max mem: 19192
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8247 (0.7820)  evaluator_time: 0.0357 (0.0593)  time: 0.9480  data: 0.0978  max mem: 19192
# Test: Total time: 0:00:05 (0.9483 s / it)
# Averaged stats: model_time: 0.8247 (0.7820)  evaluator_time: 0.0357 (0.0593)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.080
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.040
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.189
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.226
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.011
# EPOCH 1
# Epoch: [1]  [  0/250]  eta: 0:08:41  lr: 0.000010  loss: 0.5108 (0.5108)  loss_classifier: 0.2401 (0.2401)  loss_box_reg: 0.2346 (0.2346)  loss_objectness: 0.0280 (0.0280)  loss_rpn_box_reg: 0.0081 (0.0081)  time: 2.0864  data: 0.1107  max mem: 19192
# Epoch: [1]  [ 50/250]  eta: 0:06:59  lr: 0.000010  loss: 0.4340 (0.4818)  loss_classifier: 0.2051 (0.2212)  loss_box_reg: 0.1780 (0.1953)  loss_objectness: 0.0389 (0.0495)  loss_rpn_box_reg: 0.0120 (0.0158)  time: 2.0894  data: 0.1104  max mem: 19192
# Epoch: [1]  [100/250]  eta: 0:05:14  lr: 0.000010  loss: 0.4588 (0.4896)  loss_classifier: 0.2097 (0.2239)  loss_box_reg: 0.1919 (0.2028)  loss_objectness: 0.0400 (0.0474)  loss_rpn_box_reg: 0.0112 (0.0156)  time: 2.0953  data: 0.1108  max mem: 19192
# Epoch: [1]  [150/250]  eta: 0:03:29  lr: 0.000010  loss: 0.4982 (0.4946)  loss_classifier: 0.2278 (0.2246)  loss_box_reg: 0.2221 (0.2085)  loss_objectness: 0.0370 (0.0457)  loss_rpn_box_reg: 0.0129 (0.0158)  time: 2.1005  data: 0.1161  max mem: 19192
# Epoch: [1]  [200/250]  eta: 0:01:44  lr: 0.000010  loss: 0.4557 (0.4865)  loss_classifier: 0.2051 (0.2202)  loss_box_reg: 0.2064 (0.2080)  loss_objectness: 0.0340 (0.0430)  loss_rpn_box_reg: 0.0122 (0.0154)  time: 2.0973  data: 0.1123  max mem: 19192
# Epoch: [1]  [249/250]  eta: 0:00:02  lr: 0.000010  loss: 0.4818 (0.4803)  loss_classifier: 0.2043 (0.2161)  loss_box_reg: 0.2227 (0.2083)  loss_objectness: 0.0254 (0.0408)  loss_rpn_box_reg: 0.0118 (0.0152)  time: 2.0953  data: 0.1114  max mem: 19192
# Epoch: [1] Total time: 0:08:44 (2.0972 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8281 (0.8281)  evaluator_time: 0.0108 (0.0108)  time: 0.9521  data: 0.1041  max mem: 19192
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8347 (0.8120)  evaluator_time: 0.0134 (0.0139)  time: 0.9159  data: 0.0909  max mem: 19192
# Test: Total time: 0:00:29 (0.9283 s / it)
# Averaged stats: model_time: 0.8347 (0.8120)  evaluator_time: 0.0134 (0.0139)
# Accumulating evaluation results...
# DONE (t=0.19s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.031
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.087
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.042
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.223
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.266
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8297 (0.8297)  evaluator_time: 0.0319 (0.0319)  time: 0.9598  data: 0.0889  max mem: 19192
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8271 (0.7844)  evaluator_time: 0.0319 (0.0552)  time: 0.9485  data: 0.1000  max mem: 19192
# Test: Total time: 0:00:05 (0.9488 s / it)
# Averaged stats: model_time: 0.8271 (0.7844)  evaluator_time: 0.0319 (0.0552)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.052
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.146
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.016
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.069
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.223
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.266
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 2
# Epoch: [2]  [  0/250]  eta: 0:09:57  lr: 0.000010  loss: 0.6298 (0.6298)  loss_classifier: 0.2622 (0.2622)  loss_box_reg: 0.3028 (0.3028)  loss_objectness: 0.0359 (0.0359)  loss_rpn_box_reg: 0.0289 (0.0289)  time: 2.3898  data: 0.3972  max mem: 19192
# Epoch: [2]  [ 50/250]  eta: 0:07:00  lr: 0.000010  loss: 0.4282 (0.4263)  loss_classifier: 0.1837 (0.1845)  loss_box_reg: 0.2032 (0.2035)  loss_objectness: 0.0227 (0.0265)  loss_rpn_box_reg: 0.0102 (0.0118)  time: 2.0919  data: 0.1097  max mem: 19192
# Epoch: [2]  [100/250]  eta: 0:05:14  lr: 0.000010  loss: 0.4233 (0.4299)  loss_classifier: 0.1782 (0.1823)  loss_box_reg: 0.2104 (0.2067)  loss_objectness: 0.0250 (0.0273)  loss_rpn_box_reg: 0.0109 (0.0136)  time: 2.0904  data: 0.1071  max mem: 19192
# Epoch: [2]  [150/250]  eta: 0:03:29  lr: 0.000010  loss: 0.3823 (0.4163)  loss_classifier: 0.1510 (0.1751)  loss_box_reg: 0.1933 (0.2031)  loss_objectness: 0.0189 (0.0255)  loss_rpn_box_reg: 0.0096 (0.0126)  time: 2.0963  data: 0.1084  max mem: 19192
# Epoch: [2]  [200/250]  eta: 0:01:44  lr: 0.000010  loss: 0.3544 (0.4057)  loss_classifier: 0.1349 (0.1692)  loss_box_reg: 0.1703 (0.1997)  loss_objectness: 0.0199 (0.0244)  loss_rpn_box_reg: 0.0084 (0.0124)  time: 2.0964  data: 0.1103  max mem: 19192
# Epoch: [2]  [249/250]  eta: 0:00:02  lr: 0.000010  loss: 0.3266 (0.3963)  loss_classifier: 0.1320 (0.1639)  loss_box_reg: 0.1739 (0.1968)  loss_objectness: 0.0175 (0.0236)  loss_rpn_box_reg: 0.0088 (0.0120)  time: 2.0933  data: 0.1095  max mem: 19192
# Epoch: [2] Total time: 0:08:44 (2.0967 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8276 (0.8276)  evaluator_time: 0.0087 (0.0087)  time: 0.9367  data: 0.0912  max mem: 19192
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8339 (0.8119)  evaluator_time: 0.0103 (0.0105)  time: 0.9133  data: 0.0915  max mem: 19192
# Test: Total time: 0:00:29 (0.9267 s / it)
# Averaged stats: model_time: 0.8339 (0.8119)  evaluator_time: 0.0103 (0.0105)
# Accumulating evaluation results...
# DONE (t=0.12s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.049
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.143
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.065
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.212
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.214
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.113
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.249
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8266 (0.8266)  evaluator_time: 0.0217 (0.0217)  time: 0.9488  data: 0.0913  max mem: 19192
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8269 (0.7854)  evaluator_time: 0.0197 (0.0203)  time: 0.9119  data: 0.0973  max mem: 19192
# Test: Total time: 0:00:05 (0.9122 s / it)
# Averaged stats: model_time: 0.8269 (0.7854)  evaluator_time: 0.0197 (0.0203)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.069
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.196
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.212
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.214
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.113
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.249
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 3
# Epoch: [3]  [  0/250]  eta: 0:10:25  lr: 0.000010  loss: 0.3183 (0.3183)  loss_classifier: 0.1246 (0.1246)  loss_box_reg: 0.1695 (0.1695)  loss_objectness: 0.0150 (0.0150)  loss_rpn_box_reg: 0.0092 (0.0092)  time: 2.5037  data: 0.5106  max mem: 19192
# Epoch: [3]  [ 50/250]  eta: 0:07:00  lr: 0.000010  loss: 0.3678 (0.3584)  loss_classifier: 0.1301 (0.1403)  loss_box_reg: 0.1863 (0.1875)  loss_objectness: 0.0142 (0.0180)  loss_rpn_box_reg: 0.0114 (0.0125)  time: 2.0895  data: 0.1146  max mem: 19192
# Epoch: [3]  [100/250]  eta: 0:05:14  lr: 0.000010  loss: 0.3186 (0.3448)  loss_classifier: 0.1222 (0.1350)  loss_box_reg: 0.1795 (0.1816)  loss_objectness: 0.0151 (0.0167)  loss_rpn_box_reg: 0.0101 (0.0115)  time: 2.0913  data: 0.1092  max mem: 19192
# Epoch: [3]  [150/250]  eta: 0:03:29  lr: 0.000010  loss: 0.3305 (0.3429)  loss_classifier: 0.1249 (0.1327)  loss_box_reg: 0.1766 (0.1823)  loss_objectness: 0.0137 (0.0165)  loss_rpn_box_reg: 0.0091 (0.0113)  time: 2.0944  data: 0.1107  max mem: 19192
# Epoch: [3]  [200/250]  eta: 0:01:44  lr: 0.000010  loss: 0.3240 (0.3359)  loss_classifier: 0.1155 (0.1290)  loss_box_reg: 0.1774 (0.1794)  loss_objectness: 0.0128 (0.0161)  loss_rpn_box_reg: 0.0100 (0.0115)  time: 2.0954  data: 0.1103  max mem: 19192
# Epoch: [3]  [249/250]  eta: 0:00:02  lr: 0.000010  loss: 0.2928 (0.3280)  loss_classifier: 0.1098 (0.1255)  loss_box_reg: 0.1641 (0.1762)  loss_objectness: 0.0100 (0.0152)  loss_rpn_box_reg: 0.0082 (0.0111)  time: 2.0932  data: 0.1081  max mem: 19192
# Epoch: [3] Total time: 0:08:43 (2.0958 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8245 (0.8245)  evaluator_time: 0.0087 (0.0087)  time: 0.9315  data: 0.0887  max mem: 19192
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8340 (0.8122)  evaluator_time: 0.0104 (0.0149)  time: 0.9120  data: 0.0904  max mem: 19192
# Test: Total time: 0:00:29 (0.9282 s / it)
# Averaged stats: model_time: 0.8340 (0.8122)  evaluator_time: 0.0104 (0.0149)
# Accumulating evaluation results...
# DONE (t=0.12s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.054
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.138
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.069
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.085
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.212
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.216
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.123
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.252
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8280 (0.8280)  evaluator_time: 0.0206 (0.0206)  time: 0.9573  data: 0.0993  max mem: 19192
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8280 (0.7845)  evaluator_time: 0.0193 (0.0193)  time: 0.9101  data: 0.0974  max mem: 19192
# Test: Total time: 0:00:05 (0.9104 s / it)
# Averaged stats: model_time: 0.8280 (0.7845)  evaluator_time: 0.0193 (0.0193)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.076
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.197
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.049
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.093
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.085
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.212
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.216
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.123
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.252
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 4
# Epoch: [4]  [  0/250]  eta: 0:08:41  lr: 0.000010  loss: 0.4167 (0.4167)  loss_classifier: 0.1669 (0.1669)  loss_box_reg: 0.2259 (0.2259)  loss_objectness: 0.0143 (0.0143)  loss_rpn_box_reg: 0.0096 (0.0096)  time: 2.0861  data: 0.1076  max mem: 19192
# Epoch: [4]  [ 50/250]  eta: 0:06:59  lr: 0.000010  loss: 0.2556 (0.2895)  loss_classifier: 0.0952 (0.1078)  loss_box_reg: 0.1454 (0.1591)  loss_objectness: 0.0094 (0.0123)  loss_rpn_box_reg: 0.0078 (0.0103)  time: 2.0915  data: 0.1099  max mem: 19192
# Epoch: [4]  [100/250]  eta: 0:05:14  lr: 0.000010  loss: 0.2675 (0.2826)  loss_classifier: 0.1002 (0.1044)  loss_box_reg: 0.1464 (0.1557)  loss_objectness: 0.0107 (0.0123)  loss_rpn_box_reg: 0.0074 (0.0102)  time: 2.0973  data: 0.1133  max mem: 19192
# Epoch: [4]  [150/250]  eta: 0:03:29  lr: 0.000010  loss: 0.2732 (0.2790)  loss_classifier: 0.0978 (0.1018)  loss_box_reg: 0.1531 (0.1553)  loss_objectness: 0.0106 (0.0120)  loss_rpn_box_reg: 0.0086 (0.0099)  time: 2.0944  data: 0.1108  max mem: 19192
# Epoch: [4]  [200/250]  eta: 0:01:44  lr: 0.000010  loss: 0.2349 (0.2733)  loss_classifier: 0.0885 (0.0998)  loss_box_reg: 0.1305 (0.1523)  loss_objectness: 0.0075 (0.0113)  loss_rpn_box_reg: 0.0068 (0.0099)  time: 2.0922  data: 0.1090  max mem: 19192
# Epoch: [4]  [249/250]  eta: 0:00:02  lr: 0.000010  loss: 0.2403 (0.2709)  loss_classifier: 0.0802 (0.0982)  loss_box_reg: 0.1445 (0.1521)  loss_objectness: 0.0078 (0.0108)  loss_rpn_box_reg: 0.0068 (0.0098)  time: 2.0963  data: 0.1104  max mem: 19192
# Epoch: [4] Total time: 0:08:44 (2.0961 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8286 (0.8286)  evaluator_time: 0.0082 (0.0082)  time: 0.9363  data: 0.0895  max mem: 19192
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8337 (0.8119)  evaluator_time: 0.0093 (0.0092)  time: 0.9112  data: 0.0909  max mem: 19192
# Test: Total time: 0:00:29 (0.9231 s / it)
# Averaged stats: model_time: 0.8337 (0.8119)  evaluator_time: 0.0093 (0.0092)
# Accumulating evaluation results...
# DONE (t=0.10s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.065
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.164
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.043
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.038
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.084
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.093
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.208
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.209
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.116
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.246
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8239 (0.8239)  evaluator_time: 0.0168 (0.0168)  time: 0.9369  data: 0.0869  max mem: 19192
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8239 (0.7819)  evaluator_time: 0.0170 (0.0171)  time: 0.9011  data: 0.0933  max mem: 19192
# Test: Total time: 0:00:05 (0.9013 s / it)
# Averaged stats: model_time: 0.8239 (0.7819)  evaluator_time: 0.0170 (0.0171)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.087
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.223
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.055
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.055
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.107
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.093
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.208
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.209
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.116
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.246
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 5
# Epoch: [5]  [  0/250]  eta: 0:08:45  lr: 0.000010  loss: 0.2326 (0.2326)  loss_classifier: 0.0872 (0.0872)  loss_box_reg: 0.1280 (0.1280)  loss_objectness: 0.0101 (0.0101)  loss_rpn_box_reg: 0.0073 (0.0073)  time: 2.1008  data: 0.1242  max mem: 19192
# Epoch: [5]  [ 50/250]  eta: 0:07:05  lr: 0.000010  loss: 0.2586 (0.2520)  loss_classifier: 0.0872 (0.0905)  loss_box_reg: 0.1545 (0.1450)  loss_objectness: 0.0073 (0.0087)  loss_rpn_box_reg: 0.0075 (0.0078)  time: 2.0889  data: 0.1107  max mem: 19192
# Epoch: [5]  [100/250]  eta: 0:05:16  lr: 0.000010  loss: 0.2377 (0.2533)  loss_classifier: 0.0830 (0.0900)  loss_box_reg: 0.1433 (0.1464)  loss_objectness: 0.0065 (0.0081)  loss_rpn_box_reg: 0.0075 (0.0088)  time: 2.0954  data: 0.1116  max mem: 19192
# Epoch: [5]  [150/250]  eta: 0:03:30  lr: 0.000010  loss: 0.2365 (0.2495)  loss_classifier: 0.0805 (0.0879)  loss_box_reg: 0.1359 (0.1439)  loss_objectness: 0.0080 (0.0085)  loss_rpn_box_reg: 0.0073 (0.0093)  time: 2.1045  data: 0.1125  max mem: 19192
# Epoch: [5]  [200/250]  eta: 0:01:45  lr: 0.000010  loss: 0.2217 (0.2474)  loss_classifier: 0.0751 (0.0866)  loss_box_reg: 0.1328 (0.1434)  loss_objectness: 0.0049 (0.0084)  loss_rpn_box_reg: 0.0063 (0.0090)  time: 2.1024  data: 0.1162  max mem: 19192
# Epoch: [5]  [249/250]  eta: 0:00:02  lr: 0.000010  loss: 0.2095 (0.2446)  loss_classifier: 0.0704 (0.0854)  loss_box_reg: 0.1243 (0.1424)  loss_objectness: 0.0057 (0.0081)  loss_rpn_box_reg: 0.0061 (0.0087)  time: 2.0973  data: 0.1124  max mem: 19192
# Epoch: [5] Total time: 0:08:46 (2.1050 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8309 (0.8309)  evaluator_time: 0.0085 (0.0085)  time: 0.9502  data: 0.1013  max mem: 19192
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8344 (0.8122)  evaluator_time: 0.0089 (0.0086)  time: 0.9144  data: 0.0946  max mem: 19192
# Test: Total time: 0:00:29 (0.9276 s / it)
# Averaged stats: model_time: 0.8344 (0.8122)  evaluator_time: 0.0089 (0.0086)
# Accumulating evaluation results...
# DONE (t=0.08s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.070
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.182
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.042
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.198
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.199
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.113
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.229
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8286 (0.8286)  evaluator_time: 0.0157 (0.0157)  time: 0.9484  data: 0.0948  max mem: 19192
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8243 (0.7839)  evaluator_time: 0.0157 (0.0155)  time: 0.9103  data: 0.1019  max mem: 19192
# Test: Total time: 0:00:05 (0.9105 s / it)
# Averaged stats: model_time: 0.8243 (0.7839)  evaluator_time: 0.0157 (0.0155)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.093
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.247
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.051
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.055
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.113
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.198
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.199
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.113
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.229
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 6
# Epoch: [6]  [  0/250]  eta: 0:08:44  lr: 0.000010  loss: 0.0932 (0.0932)  loss_classifier: 0.0351 (0.0351)  loss_box_reg: 0.0519 (0.0519)  loss_objectness: 0.0025 (0.0025)  loss_rpn_box_reg: 0.0036 (0.0036)  time: 2.0969  data: 0.1067  max mem: 19192
# Epoch: [6]  [ 50/250]  eta: 0:06:59  lr: 0.000010  loss: 0.2005 (0.2176)  loss_classifier: 0.0703 (0.0742)  loss_box_reg: 0.1197 (0.1271)  loss_objectness: 0.0051 (0.0075)  loss_rpn_box_reg: 0.0057 (0.0088)  time: 2.0895  data: 0.1086  max mem: 19192
# Epoch: [6]  [100/250]  eta: 0:05:14  lr: 0.000010  loss: 0.2258 (0.2210)  loss_classifier: 0.0715 (0.0750)  loss_box_reg: 0.1321 (0.1302)  loss_objectness: 0.0064 (0.0070)  loss_rpn_box_reg: 0.0077 (0.0088)  time: 2.0953  data: 0.1124  max mem: 19192
# Epoch: [6]  [150/250]  eta: 0:03:29  lr: 0.000010  loss: 0.1997 (0.2151)  loss_classifier: 0.0656 (0.0725)  loss_box_reg: 0.1184 (0.1279)  loss_objectness: 0.0046 (0.0063)  loss_rpn_box_reg: 0.0060 (0.0084)  time: 2.1002  data: 0.1134  max mem: 19192
# Epoch: [6]  [200/250]  eta: 0:01:44  lr: 0.000010  loss: 0.2008 (0.2122)  loss_classifier: 0.0663 (0.0719)  loss_box_reg: 0.1188 (0.1261)  loss_objectness: 0.0047 (0.0059)  loss_rpn_box_reg: 0.0057 (0.0083)  time: 2.0983  data: 0.1108  max mem: 19192
# Epoch: [6]  [249/250]  eta: 0:00:02  lr: 0.000010  loss: 0.1797 (0.2098)  loss_classifier: 0.0578 (0.0707)  loss_box_reg: 0.1146 (0.1252)  loss_objectness: 0.0034 (0.0057)  loss_rpn_box_reg: 0.0059 (0.0082)  time: 2.0949  data: 0.1100  max mem: 19192
# Epoch: [6] Total time: 0:08:44 (2.0989 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8273 (0.8273)  evaluator_time: 0.0079 (0.0079)  time: 0.9367  data: 0.0921  max mem: 19192
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8348 (0.8126)  evaluator_time: 0.0082 (0.0081)  time: 0.9153  data: 0.0947  max mem: 19192
# Test: Total time: 0:00:29 (0.9267 s / it)
# Averaged stats: model_time: 0.8348 (0.8126)  evaluator_time: 0.0082 (0.0081)
# Accumulating evaluation results...
# DONE (t=0.08s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.077
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.187
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.054
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.039
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.092
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.189
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.097
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.229
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8233 (0.8233)  evaluator_time: 0.0143 (0.0143)  time: 0.9418  data: 0.0947  max mem: 19192
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8245 (0.7827)  evaluator_time: 0.0142 (0.0408)  time: 0.9277  data: 0.0953  max mem: 19192
# Test: Total time: 0:00:05 (0.9280 s / it)
# Averaged stats: model_time: 0.8245 (0.7827)  evaluator_time: 0.0142 (0.0408)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.255
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.066
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.052
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.126
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.092
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.189
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.097
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.229
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 7
# Epoch: [7]  [  0/250]  eta: 0:08:44  lr: 0.000010  loss: 0.1584 (0.1584)  loss_classifier: 0.0484 (0.0484)  loss_box_reg: 0.0979 (0.0979)  loss_objectness: 0.0072 (0.0072)  loss_rpn_box_reg: 0.0049 (0.0049)  time: 2.0969  data: 0.1150  max mem: 19192
# Epoch: [7]  [ 50/250]  eta: 0:06:59  lr: 0.000010  loss: 0.1828 (0.1865)  loss_classifier: 0.0557 (0.0613)  loss_box_reg: 0.1078 (0.1135)  loss_objectness: 0.0036 (0.0047)  loss_rpn_box_reg: 0.0054 (0.0070)  time: 2.0914  data: 0.1098  max mem: 19192
# Epoch: [7]  [100/250]  eta: 0:05:14  lr: 0.000010  loss: 0.1874 (0.1908)  loss_classifier: 0.0587 (0.0626)  loss_box_reg: 0.1183 (0.1157)  loss_objectness: 0.0041 (0.0047)  loss_rpn_box_reg: 0.0058 (0.0079)  time: 2.0980  data: 0.1130  max mem: 19192
# Epoch: [7]  [150/250]  eta: 0:03:29  lr: 0.000010  loss: 0.1862 (0.1917)  loss_classifier: 0.0641 (0.0630)  loss_box_reg: 0.1141 (0.1161)  loss_objectness: 0.0034 (0.0047)  loss_rpn_box_reg: 0.0056 (0.0079)  time: 2.0967  data: 0.1099  max mem: 19192
# Epoch: [7]  [200/250]  eta: 0:01:44  lr: 0.000010  loss: 0.1763 (0.1885)  loss_classifier: 0.0525 (0.0617)  loss_box_reg: 0.1054 (0.1145)  loss_objectness: 0.0036 (0.0047)  loss_rpn_box_reg: 0.0060 (0.0076)  time: 2.0962  data: 0.1098  max mem: 19192
# Epoch: [7]  [249/250]  eta: 0:00:02  lr: 0.000010  loss: 0.1800 (0.1866)  loss_classifier: 0.0597 (0.0611)  loss_box_reg: 0.1121 (0.1132)  loss_objectness: 0.0048 (0.0045)  loss_rpn_box_reg: 0.0057 (0.0077)  time: 2.1013  data: 0.1131  max mem: 19192
# Epoch: [7] Total time: 0:08:44 (2.0979 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8291 (0.8291)  evaluator_time: 0.0077 (0.0077)  time: 0.9562  data: 0.1101  max mem: 19192
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8307 (0.8114)  evaluator_time: 0.0081 (0.0082)  time: 0.9111  data: 0.0932  max mem: 19192
# Test: Total time: 0:00:29 (0.9255 s / it)
# Averaged stats: model_time: 0.8307 (0.8114)  evaluator_time: 0.0081 (0.0082)
# Accumulating evaluation results...
# DONE (t=0.08s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.082
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.198
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.055
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.107
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.105
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.112
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.238
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8284 (0.8284)  evaluator_time: 0.0145 (0.0145)  time: 0.9469  data: 0.0945  max mem: 19192
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8284 (0.7871)  evaluator_time: 0.0143 (0.0144)  time: 0.9076  data: 0.0972  max mem: 19192
# Test: Total time: 0:00:05 (0.9078 s / it)
# Averaged stats: model_time: 0.8284 (0.7871)  evaluator_time: 0.0143 (0.0144)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.106
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.266
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.066
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.055
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.132
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.105
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.112
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.238
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 8
# Epoch: [8]  [  0/250]  eta: 0:08:45  lr: 0.000010  loss: 0.1842 (0.1842)  loss_classifier: 0.0592 (0.0592)  loss_box_reg: 0.1129 (0.1129)  loss_objectness: 0.0035 (0.0035)  loss_rpn_box_reg: 0.0086 (0.0086)  time: 2.1019  data: 0.1146  max mem: 19192
# Epoch: [8]  [ 50/250]  eta: 0:06:59  lr: 0.000010  loss: 0.1554 (0.1659)  loss_classifier: 0.0522 (0.0552)  loss_box_reg: 0.0991 (0.1005)  loss_objectness: 0.0031 (0.0036)  loss_rpn_box_reg: 0.0049 (0.0065)  time: 2.0968  data: 0.1103  max mem: 19192
# Epoch: [8]  [100/250]  eta: 0:05:14  lr: 0.000010  loss: 0.1681 (0.1729)  loss_classifier: 0.0556 (0.0569)  loss_box_reg: 0.1064 (0.1050)  loss_objectness: 0.0037 (0.0040)  loss_rpn_box_reg: 0.0053 (0.0069)  time: 2.0985  data: 0.1132  max mem: 19192
# Epoch: [8]  [150/250]  eta: 0:03:29  lr: 0.000010  loss: 0.1612 (0.1712)  loss_classifier: 0.0513 (0.0557)  loss_box_reg: 0.1064 (0.1048)  loss_objectness: 0.0026 (0.0039)  loss_rpn_box_reg: 0.0052 (0.0068)  time: 2.0920  data: 0.1068  max mem: 19192
# Epoch: [8]  [200/250]  eta: 0:01:44  lr: 0.000010  loss: 0.1657 (0.1700)  loss_classifier: 0.0504 (0.0552)  loss_box_reg: 0.1045 (0.1043)  loss_objectness: 0.0029 (0.0039)  loss_rpn_box_reg: 0.0057 (0.0065)  time: 2.0944  data: 0.1077  max mem: 19192
# Epoch: [8]  [249/250]  eta: 0:00:02  lr: 0.000010  loss: 0.1697 (0.1689)  loss_classifier: 0.0522 (0.0546)  loss_box_reg: 0.1009 (0.1039)  loss_objectness: 0.0023 (0.0038)  loss_rpn_box_reg: 0.0053 (0.0066)  time: 2.0928  data: 0.1100  max mem: 19192
# Epoch: [8] Total time: 0:08:44 (2.0970 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8260 (0.8260)  evaluator_time: 0.0091 (0.0091)  time: 0.9351  data: 0.0904  max mem: 19192
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8337 (0.8119)  evaluator_time: 0.0072 (0.0076)  time: 0.9111  data: 0.0920  max mem: 19192
# Test: Total time: 0:00:29 (0.9230 s / it)
# Averaged stats: model_time: 0.8337 (0.8119)  evaluator_time: 0.0072 (0.0076)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.082
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.203
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.045
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.043
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.103
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.098
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.179
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.179
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.099
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.213
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8308 (0.8308)  evaluator_time: 0.0133 (0.0133)  time: 0.9421  data: 0.0884  max mem: 19192
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8281 (0.7862)  evaluator_time: 0.0133 (0.0134)  time: 0.9027  data: 0.0942  max mem: 19192
# Test: Total time: 0:00:05 (0.9030 s / it)
# Averaged stats: model_time: 0.8281 (0.7862)  evaluator_time: 0.0133 (0.0134)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.103
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.264
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.054
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.062
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.127
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.098
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.179
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.179
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.099
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.213
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 9
# Epoch: [9]  [  0/250]  eta: 0:09:49  lr: 0.000010  loss: 0.1681 (0.1681)  loss_classifier: 0.0502 (0.0502)  loss_box_reg: 0.1087 (0.1087)  loss_objectness: 0.0029 (0.0029)  loss_rpn_box_reg: 0.0064 (0.0064)  time: 2.3572  data: 0.3656  max mem: 19192
# Epoch: [9]  [ 50/250]  eta: 0:07:05  lr: 0.000010  loss: 0.1590 (0.1627)  loss_classifier: 0.0514 (0.0530)  loss_box_reg: 0.0943 (0.0996)  loss_objectness: 0.0025 (0.0034)  loss_rpn_box_reg: 0.0057 (0.0066)  time: 2.0959  data: 0.1112  max mem: 19192
# Epoch: [9]  [100/250]  eta: 0:05:16  lr: 0.000010  loss: 0.1530 (0.1590)  loss_classifier: 0.0474 (0.0517)  loss_box_reg: 0.0985 (0.0983)  loss_objectness: 0.0018 (0.0031)  loss_rpn_box_reg: 0.0047 (0.0059)  time: 2.0985  data: 0.1126  max mem: 19192
# Epoch: [9]  [150/250]  eta: 0:03:30  lr: 0.000010  loss: 0.1487 (0.1576)  loss_classifier: 0.0457 (0.0507)  loss_box_reg: 0.0969 (0.0981)  loss_objectness: 0.0023 (0.0029)  loss_rpn_box_reg: 0.0047 (0.0058)  time: 2.0953  data: 0.1108  max mem: 19192
# Epoch: [9]  [200/250]  eta: 0:01:45  lr: 0.000010  loss: 0.1394 (0.1569)  loss_classifier: 0.0477 (0.0504)  loss_box_reg: 0.0879 (0.0978)  loss_objectness: 0.0029 (0.0029)  loss_rpn_box_reg: 0.0045 (0.0058)  time: 2.0935  data: 0.1082  max mem: 19192
# Epoch: [9]  [249/250]  eta: 0:00:02  lr: 0.000010  loss: 0.1447 (0.1557)  loss_classifier: 0.0473 (0.0499)  loss_box_reg: 0.0913 (0.0972)  loss_objectness: 0.0020 (0.0029)  loss_rpn_box_reg: 0.0044 (0.0058)  time: 2.0965  data: 0.1124  max mem: 19192
# Epoch: [9] Total time: 0:08:45 (2.1030 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8282 (0.8282)  evaluator_time: 0.0069 (0.0069)  time: 0.9395  data: 0.0949  max mem: 19192
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8340 (0.8118)  evaluator_time: 0.0074 (0.0075)  time: 0.9086  data: 0.0901  max mem: 19192
# Test: Total time: 0:00:29 (0.9226 s / it)
# Averaged stats: model_time: 0.8340 (0.8118)  evaluator_time: 0.0074 (0.0075)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.087
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.210
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.060
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.050
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.107
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.113
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.107
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.241
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8273 (0.8273)  evaluator_time: 0.0133 (0.0133)  time: 0.9403  data: 0.0903  max mem: 19192
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8273 (0.7850)  evaluator_time: 0.0132 (0.0135)  time: 0.9013  data: 0.0940  max mem: 19192
# Test: Total time: 0:00:05 (0.9015 s / it)
# Averaged stats: model_time: 0.8273 (0.7850)  evaluator_time: 0.0132 (0.0135)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.276
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.069
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.068
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.132
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.113
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.107
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.241
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 10
# Epoch: [10]  [  0/250]  eta: 0:08:44  lr: 0.000010  loss: 0.1649 (0.1649)  loss_classifier: 0.0542 (0.0542)  loss_box_reg: 0.1046 (0.1046)  loss_objectness: 0.0020 (0.0020)  loss_rpn_box_reg: 0.0041 (0.0041)  time: 2.0973  data: 0.1259  max mem: 19192
# Epoch: [10]  [ 50/250]  eta: 0:06:59  lr: 0.000010  loss: 0.1338 (0.1403)  loss_classifier: 0.0433 (0.0445)  loss_box_reg: 0.0830 (0.0882)  loss_objectness: 0.0017 (0.0022)  loss_rpn_box_reg: 0.0044 (0.0054)  time: 2.0943  data: 0.1108  max mem: 19192
# Epoch: [10]  [100/250]  eta: 0:05:14  lr: 0.000010  loss: 0.1394 (0.1412)  loss_classifier: 0.0422 (0.0442)  loss_box_reg: 0.0848 (0.0888)  loss_objectness: 0.0017 (0.0022)  loss_rpn_box_reg: 0.0047 (0.0059)  time: 2.0923  data: 0.1093  max mem: 19192
# Epoch: [10]  [150/250]  eta: 0:03:29  lr: 0.000010  loss: 0.1439 (0.1397)  loss_classifier: 0.0425 (0.0437)  loss_box_reg: 0.0884 (0.0880)  loss_objectness: 0.0016 (0.0023)  loss_rpn_box_reg: 0.0041 (0.0058)  time: 2.0977  data: 0.1124  max mem: 19192
# Epoch: [10]  [200/250]  eta: 0:01:44  lr: 0.000010  loss: 0.1399 (0.1410)  loss_classifier: 0.0427 (0.0440)  loss_box_reg: 0.0910 (0.0887)  loss_objectness: 0.0019 (0.0023)  loss_rpn_box_reg: 0.0047 (0.0060)  time: 2.0993  data: 0.1154  max mem: 19192
# Epoch: [10]  [249/250]  eta: 0:00:02  lr: 0.000010  loss: 0.1326 (0.1394)  loss_classifier: 0.0424 (0.0436)  loss_box_reg: 0.0830 (0.0878)  loss_objectness: 0.0017 (0.0023)  loss_rpn_box_reg: 0.0046 (0.0058)  time: 2.0983  data: 0.1121  max mem: 19192
# Epoch: [10] Total time: 0:08:44 (2.0974 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8237 (0.8237)  evaluator_time: 0.0064 (0.0064)  time: 0.9293  data: 0.0900  max mem: 19192
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8336 (0.8121)  evaluator_time: 0.0072 (0.0069)  time: 0.9191  data: 0.0999  max mem: 19192
# Test: Total time: 0:00:29 (0.9266 s / it)
# Averaged stats: model_time: 0.8336 (0.8121)  evaluator_time: 0.0072 (0.0069)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.081
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.205
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.049
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.051
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# ...
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.210
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.074
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.053
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.123
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.111
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.198
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.198
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.106
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.235
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8234 (0.8234)  evaluator_time: 0.0109 (0.0109)  time: 0.9386  data: 0.0951  max mem: 19192
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8234 (0.7822)  evaluator_time: 0.0109 (0.0107)  time: 0.9010  data: 0.0992  max mem: 19192
# Test: Total time: 0:00:05 (0.9013 s / it)
# Averaged stats: model_time: 0.8234 (0.7822)  evaluator_time: 0.0109 (0.0107)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.123
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.276
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.093
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.075
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.111
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.198
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.198
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.106
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.235
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 27
# Epoch: [27]  [  0/250]  eta: 0:08:38  lr: 0.000010  loss: 0.0773 (0.0773)  loss_classifier: 0.0248 (0.0248)  loss_box_reg: 0.0500 (0.0500)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0021 (0.0021)  time: 2.0740  data: 0.1127  max mem: 19192
# Epoch: [27]  [ 50/250]  eta: 0:07:04  lr: 0.000010  loss: 0.0642 (0.0658)  loss_classifier: 0.0204 (0.0206)  loss_box_reg: 0.0409 (0.0418)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0016 (0.0029)  time: 2.0965  data: 0.1107  max mem: 19192
# Epoch: [27]  [100/250]  eta: 0:05:16  lr: 0.000010  loss: 0.0560 (0.0643)  loss_classifier: 0.0181 (0.0201)  loss_box_reg: 0.0370 (0.0413)  loss_objectness: 0.0003 (0.0005)  loss_rpn_box_reg: 0.0014 (0.0024)  time: 2.0953  data: 0.1092  max mem: 19192
# Epoch: [27]  [150/250]  eta: 0:03:30  lr: 0.000010  loss: 0.0678 (0.0649)  loss_classifier: 0.0206 (0.0202)  loss_box_reg: 0.0449 (0.0417)  loss_objectness: 0.0005 (0.0004)  loss_rpn_box_reg: 0.0018 (0.0025)  time: 2.0957  data: 0.1091  max mem: 19192
# Epoch: [27]  [200/250]  eta: 0:01:45  lr: 0.000010  loss: 0.0587 (0.0642)  loss_classifier: 0.0176 (0.0200)  loss_box_reg: 0.0394 (0.0414)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0015 (0.0023)  time: 2.1020  data: 0.1118  max mem: 19192
# Epoch: [27]  [249/250]  eta: 0:00:02  lr: 0.000010  loss: 0.0563 (0.0635)  loss_classifier: 0.0176 (0.0198)  loss_box_reg: 0.0372 (0.0411)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0014 (0.0022)  time: 2.0980  data: 0.1090  max mem: 19192
# Epoch: [27] Total time: 0:08:45 (2.1038 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8279 (0.8279)  evaluator_time: 0.0046 (0.0046)  time: 0.9352  data: 0.0933  max mem: 19192
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8355 (0.8130)  evaluator_time: 0.0053 (0.0054)  time: 0.9101  data: 0.0914  max mem: 19192
# Test: Total time: 0:00:29 (0.9208 s / it)
# Averaged stats: model_time: 0.8355 (0.8130)  evaluator_time: 0.0053 (0.0054)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.096
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.212
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.063
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.052
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.121
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.116
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.098
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.229
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8213 (0.8213)  evaluator_time: 0.0104 (0.0104)  time: 0.9545  data: 0.1134  max mem: 19192
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8226 (0.7821)  evaluator_time: 0.0104 (0.0106)  time: 0.9022  data: 0.1006  max mem: 19192
# Test: Total time: 0:00:05 (0.9024 s / it)
# Averaged stats: model_time: 0.8226 (0.7821)  evaluator_time: 0.0104 (0.0106)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.123
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.284
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.075
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.072
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.116
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.098
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.229
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 28
# Epoch: [28]  [  0/250]  eta: 0:08:41  lr: 0.000010  loss: 0.0534 (0.0534)  loss_classifier: 0.0168 (0.0168)  loss_box_reg: 0.0333 (0.0333)  loss_objectness: 0.0019 (0.0019)  loss_rpn_box_reg: 0.0013 (0.0013)  time: 2.0856  data: 0.1205  max mem: 19192
# Epoch: [28]  [ 50/250]  eta: 0:07:01  lr: 0.000010  loss: 0.0588 (0.0603)  loss_classifier: 0.0188 (0.0186)  loss_box_reg: 0.0397 (0.0392)  loss_objectness: 0.0004 (0.0005)  loss_rpn_box_reg: 0.0016 (0.0020)  time: 2.1163  data: 0.1299  max mem: 19192
# Epoch: [28]  [100/250]  eta: 0:05:15  lr: 0.000010  loss: 0.0556 (0.0596)  loss_classifier: 0.0168 (0.0183)  loss_box_reg: 0.0376 (0.0389)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0015 (0.0020)  time: 2.0984  data: 0.1115  max mem: 19192
# Epoch: [28]  [150/250]  eta: 0:03:30  lr: 0.000010  loss: 0.0687 (0.0610)  loss_classifier: 0.0214 (0.0189)  loss_box_reg: 0.0436 (0.0396)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0017 (0.0021)  time: 2.1035  data: 0.1132  max mem: 19192
# Epoch: [28]  [200/250]  eta: 0:01:45  lr: 0.000010  loss: 0.0596 (0.0614)  loss_classifier: 0.0188 (0.0190)  loss_box_reg: 0.0391 (0.0396)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0016 (0.0023)  time: 2.0974  data: 0.1096  max mem: 19192
# Epoch: [28]  [249/250]  eta: 0:00:02  lr: 0.000010  loss: 0.0583 (0.0610)  loss_classifier: 0.0169 (0.0189)  loss_box_reg: 0.0398 (0.0394)  loss_objectness: 0.0003 (0.0004)  loss_rpn_box_reg: 0.0015 (0.0022)  time: 2.0957  data: 0.1080  max mem: 19192
# Epoch: [28] Total time: 0:08:44 (2.1000 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8284 (0.8284)  evaluator_time: 0.0050 (0.0050)  time: 0.9316  data: 0.0886  max mem: 19192
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8348 (0.8135)  evaluator_time: 0.0053 (0.0054)  time: 0.9078  data: 0.0900  max mem: 19192
# Test: Total time: 0:00:29 (0.9198 s / it)
# Averaged stats: model_time: 0.8348 (0.8135)  evaluator_time: 0.0053 (0.0054)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.095
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.209
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.073
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.053
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.121
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.111
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.188
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.188
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.102
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.225
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8229 (0.8229)  evaluator_time: 0.0104 (0.0104)  time: 0.9333  data: 0.0907  max mem: 19192
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8229 (0.7807)  evaluator_time: 0.0104 (0.0111)  time: 0.8949  data: 0.0942  max mem: 19192
# Test: Total time: 0:00:05 (0.8952 s / it)
# Averaged stats: model_time: 0.8229 (0.7807)  evaluator_time: 0.0104 (0.0111)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.120
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.271
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.071
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.148
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.111
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.188
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.188
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.102
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.225
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 29
# Epoch: [29]  [  0/250]  eta: 0:08:39  lr: 0.000010  loss: 0.0689 (0.0689)  loss_classifier: 0.0214 (0.0214)  loss_box_reg: 0.0451 (0.0451)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0020 (0.0020)  time: 2.0776  data: 0.1180  max mem: 19192
# Epoch: [29]  [ 50/250]  eta: 0:06:59  lr: 0.000010  loss: 0.0589 (0.0595)  loss_classifier: 0.0180 (0.0187)  loss_box_reg: 0.0372 (0.0389)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0016 (0.0017)  time: 2.0953  data: 0.1110  max mem: 19192
# Epoch: [29]  [100/250]  eta: 0:05:14  lr: 0.000010  loss: 0.0572 (0.0591)  loss_classifier: 0.0171 (0.0183)  loss_box_reg: 0.0382 (0.0388)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0014 (0.0017)  time: 2.0924  data: 0.1079  max mem: 19192
# Epoch: [29]  [150/250]  eta: 0:03:29  lr: 0.000010  loss: 0.0549 (0.0588)  loss_classifier: 0.0176 (0.0183)  loss_box_reg: 0.0352 (0.0384)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0013 (0.0018)  time: 2.0931  data: 0.1045  max mem: 19192
# Epoch: [29]  [200/250]  eta: 0:01:44  lr: 0.000010  loss: 0.0598 (0.0586)  loss_classifier: 0.0185 (0.0183)  loss_box_reg: 0.0372 (0.0383)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0014 (0.0017)  time: 2.0948  data: 0.1088  max mem: 19192
# Epoch: [29]  [249/250]  eta: 0:00:02  lr: 0.000010  loss: 0.0555 (0.0583)  loss_classifier: 0.0176 (0.0183)  loss_box_reg: 0.0366 (0.0380)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0013 (0.0017)  time: 2.0966  data: 0.1098  max mem: 19192
# Epoch: [29] Total time: 0:08:44 (2.0964 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8268 (0.8268)  evaluator_time: 0.0055 (0.0055)  time: 0.9348  data: 0.0931  max mem: 19192
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8350 (0.8125)  evaluator_time: 0.0056 (0.0055)  time: 0.9123  data: 0.0939  max mem: 19192
# Test: Total time: 0:00:29 (0.9219 s / it)
# Averaged stats: model_time: 0.8350 (0.8125)  evaluator_time: 0.0056 (0.0055)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.216
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.070
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.124
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.117
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.197
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.197
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.103
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.236
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8240 (0.8240)  evaluator_time: 0.0102 (0.0102)  time: 0.9350  data: 0.0914  max mem: 19192
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8244 (0.7829)  evaluator_time: 0.0102 (0.0105)  time: 0.8963  data: 0.0940  max mem: 19192
# Test: Total time: 0:00:05 (0.8965 s / it)
# Averaged stats: model_time: 0.8244 (0.7829)  evaluator_time: 0.0102 (0.0105)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.122
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.276
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.084
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.075
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.117
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.197
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.197
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.103
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.236
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Training complete!

# %% [markdown]
# # Evaluation

# %%
model_tune = fasterrcnn_resnet50_fpn_v2(weights="DEFAULT")
num_classes = 4
in_features = model_tune.roi_heads.box_predictor.cls_score.in_features
model_tune.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

checkpoint_path = os.path.join(
    "/content/gdrive/My Drive/Grad School/Dissertation/Data",
    "pretrain_transform_0.001_0.001_21.pt",
)
checkpoint = torch.load(checkpoint_path)

model_tune.load_state_dict(checkpoint["model"])

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model_tune.to(device)

print(f"Model loaded successfully from {checkpoint_path}")
# Out:
# Model loaded successfully from /content/gdrive/My Drive/Grad School/Dissertation/Data/pretrain_transform_0.001_0.001_21.pt

# %%
class AerialImageryDatasetOneClass(torch.utils.data.Dataset):
    def __init__(
        self, image_dir_path, annotation_path, background_weight, label, train=False
    ):
        self.image_dir_path = image_dir_path

        self.transforms = []
        if train:
            self.transforms.append(T.RandomHorizontalFlip(p=0.5))
            self.transforms.append(T.RandomVerticalFlip(p=0.5))

        self.transforms.append(T.ToDtype(torch.float, scale=True))
        self.transforms.append(T.ToPureTensor())
        self.transforms = T.Compose(self.transforms)

        self.label_map = {"daylighting": 1, "safety_islands": 2, "curb_extensions": 3}

        with open(annotation_path) as json_file:
            self.annotations = json.load(json_file)

        self.weights = []

        for item in tqdm(self.annotations):
            curr_weight = 1
            self.weights.append(curr_weight)

        self.label = label

    def __getitem__(self, idx):
        img_path = os.path.join(
            self.image_dir_path, self.annotations[idx]["image"].split("%5C")[-1]
        )

        img = decode_image(img_path, mode="RGB")

        if img.dtype != torch.float:
            img = to_dtype(img, dtype=torch.float, scale=True)

        img = tv_tensors.Image(img)

        if "label" in self.annotations[idx]:
            boxes = [
                [i["x"], i["y"], i["width"], i["height"]]
                for i in self.annotations[idx]["label"]
                if i["rectanglelabels"][0] == self.label
            ]

            if len(boxes) == 0:
                boxes = torch.zeros((0, 4), dtype=torch.float32)
                labels = torch.zeros((0,), dtype=torch.int64)
            else:
                boxes = convert_bounding_box_format(
                    tv_tensors.BoundingBoxes(
                        boxes, format="XYWH", canvas_size=get_size(img)
                    ),
                    new_format="XYXY",
                )
                boxes = tv_tensors.BoundingBoxes(
                    boxes * 416 / 100, format="XYXY", canvas_size=get_size(img)
                )
                labels = torch.tensor(
                    [
                        self.label_map[i["rectanglelabels"][0]]
                        for i in self.annotations[idx]["label"]
                        if i["rectanglelabels"][0] == self.label
                    ]
                )

        else:
            boxes = torch.zeros((0, 4), dtype=torch.float32)
            labels = torch.zeros((0,), dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = int(
            "".join(
                self.annotations[idx]["image"].split("%5C")[-1].split(".")[0].split("_")
            )
        )
        target["area"] = torch.tensor(
            [(box[2] - box[0]) * (box[3] - box[1]) for box in boxes]
        )
        target["iscrowd"] = torch.tensor([0] * len(boxes))

        img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.annotations)

# %%
from tqdm import tqdm

image_path = os.path.join(
    "/content/gdrive/My Drive/Grad School/Dissertation/Data", "test"
)
label_path = os.path.join(
    "/content/gdrive/My Drive/Grad School/Dissertation/Data", "test.json"
)

batch_size = 16

dataset_valtest = AerialImageryDatasetOneClass(
    image_dir_path=image_path,
    annotation_path=label_path,
    background_weight=0.001,
    label="curb_extensions",
    train=False,
)


g = torch.Generator()
g.manual_seed(2025)
indices = torch.randperm(n=len(dataset_valtest), generator=g).tolist()

subset_val = Subset(
    dataset_valtest,
    indices[int(len(dataset_valtest) * 0.8) : int(len(dataset_valtest) * 0.9)],
)

data_loader_val_curb = DataLoader(
    subset_val, batch_size=batch_size, collate_fn=utils.collate_fn
)

dataset_valtest = AerialImageryDatasetOneClass(
    image_dir_path=image_path,
    annotation_path=label_path,
    background_weight=0.001,
    label="daylighting",
    train=False,
)

g = torch.Generator()
g.manual_seed(2025)
indices = torch.randperm(n=len(dataset_valtest), generator=g).tolist()

subset_val = Subset(
    dataset_valtest,
    indices[int(len(dataset_valtest) * 0.8) : int(len(dataset_valtest) * 0.9)],
)

data_loader_val_day = DataLoader(
    subset_val, batch_size=batch_size, collate_fn=utils.collate_fn
)

dataset_valtest = AerialImageryDatasetOneClass(
    image_dir_path=image_path,
    annotation_path=label_path,
    background_weight=0.001,
    label="safety_islands",
    train=False,
)

g = torch.Generator()
g.manual_seed(2025)
indices = torch.randperm(n=len(dataset_valtest), generator=g).tolist()

subset_val = Subset(
    dataset_valtest,
    indices[int(len(dataset_valtest) * 0.8) : int(len(dataset_valtest) * 0.9)],
)

data_loader_val_island = DataLoader(
    subset_val, batch_size=batch_size, collate_fn=utils.collate_fn
)

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
# Out:
# 100%|██████████| 5000/5000 [00:00<00:00, 4317792.88it/s]
# 100%|██████████| 5000/5000 [00:00<00:00, 4184261.77it/s]
# 100%|██████████| 5000/5000 [00:00<00:00, 4104818.95it/s]

# %%
evaluate(model_tune, data_loader_val_curb, device=device)
# Out:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:01:14  model_time: 2.2217 (2.2217)  evaluator_time: 0.0066 (0.0066)  time: 2.3230  data: 0.0857  max mem: 5477
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8319 (0.8561)  evaluator_time: 0.0027 (0.0029)  time: 0.9164  data: 0.1039  max mem: 5486
# Test: Total time: 0:00:31 (0.9690 s / it)
# Averaged stats: model_time: 0.8319 (0.8561)  evaluator_time: 0.0027 (0.0029)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.015
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000

# %%
evaluate(model_tune, data_loader_val_day, device=device)
# Out:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8179 (0.8179)  evaluator_time: 0.0028 (0.0028)  time: 0.9130  data: 0.0834  max mem: 5486
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8261 (0.8045)  evaluator_time: 0.0031 (0.0032)  time: 0.8958  data: 0.0889  max mem: 5486
# Test: Total time: 0:00:29 (0.9069 s / it)
# Averaged stats: model_time: 0.8261 (0.8045)  evaluator_time: 0.0031 (0.0032)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.069
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.032
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.075
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.096
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.096
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.018
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.145
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000

# %%
evaluate(model_tune, data_loader_val_island, device=device)
# Out:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8221 (0.8221)  evaluator_time: 0.0027 (0.0027)  time: 0.9205  data: 0.0866  max mem: 5486
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8328 (0.8099)  evaluator_time: 0.0033 (0.0033)  time: 0.9024  data: 0.0895  max mem: 5486
# Test: Total time: 0:00:29 (0.9132 s / it)
# Averaged stats: model_time: 0.8328 (0.8099)  evaluator_time: 0.0033 (0.0033)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.352
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.653
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.316
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.258
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.419
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.256
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.449
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.449
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.343
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.511
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
