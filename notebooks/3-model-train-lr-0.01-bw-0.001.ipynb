# %% [markdown]
# # Setup

# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import os

os.system(
    "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py"
)
os.system(
    "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py"
)
os.system(
    "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py"
)
os.system(
    "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py"
)
os.system(
    "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py"
)
# Out:
# 0

# %%
import torch
from torch.utils.data import Subset, DataLoader

from torchvision import tv_tensors
from torchvision.io import decode_image

from torchvision.transforms import v2 as T
from torchvision.transforms.v2.functional import (
    to_dtype,
    get_size,
    convert_bounding_box_format,
)

from torchvision.models.detection import fasterrcnn_resnet50_fpn_v2
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

import pandas as pd
import numpy as np

import os
import json

import math
import sys

import utils
from engine import train_one_epoch, evaluate

# %% [markdown]
# # Data

# %%
class AerialImageryDataset(torch.utils.data.Dataset):
    def __init__(self, image_dir_path, annotation_path, background_weight, train=False):
        self.image_dir_path = image_dir_path

        self.transforms = []
        if train:
            self.transforms.append(T.RandomHorizontalFlip(p=0.5))
            self.transforms.append(T.RandomVerticalFlip(p=0.5))

        self.transforms.append(T.ToDtype(torch.float, scale=True))
        self.transforms.append(T.ToPureTensor())
        self.transforms = T.Compose(self.transforms)

        self.label_map = {"daylighting": 1, "safety_islands": 2, "curb_extensions": 3}

        with open(annotation_path) as json_file:
            self.annotations = json.load(json_file)

        self.weights = []

        for item in tqdm(self.annotations):
            curr_weight = 1

            if "label" in item:
                for label in item["label"]:
                    if label["rectanglelabels"][0] == "curb_extensions":
                        curr_weight = 3
                        break
            else:
                curr_weight = background_weight

            self.weights.append(curr_weight)

    def __getitem__(self, idx):
        img_path = os.path.join(
            self.image_dir_path, self.annotations[idx]["image"].split("%5C")[-1]
        )

        img = decode_image(img_path, mode="RGB")

        if img.dtype != torch.float:
            img = to_dtype(img, dtype=torch.float, scale=True)

        img = tv_tensors.Image(img)

        if "label" in self.annotations[idx]:
            boxes = [
                [i["x"], i["y"], i["width"], i["height"]]
                for i in self.annotations[idx]["label"]
            ]

            boxes = convert_bounding_box_format(
                tv_tensors.BoundingBoxes(
                    boxes, format="XYWH", canvas_size=get_size(img)
                ),
                new_format="XYXY",
            )
            boxes = tv_tensors.BoundingBoxes(
                boxes * 416 / 100, format="XYXY", canvas_size=get_size(img)
            )
            labels = torch.tensor(
                [
                    self.label_map[i["rectanglelabels"][0]]
                    for i in self.annotations[idx]["label"]
                ]
            )

        else:
            boxes = torch.zeros((0, 4), dtype=torch.float32)
            labels = torch.zeros((0,), dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = int(
            "".join(
                self.annotations[idx]["image"].split("%5C")[-1].split(".")[0].split("_")
            )
        )
        target["area"] = torch.tensor(
            [(box[2] - box[0]) * (box[3] - box[1]) for box in boxes]
        )
        target["iscrowd"] = torch.tensor([0] * len(boxes))

        img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.annotations)

# %%
from tqdm import tqdm

image_path = os.path.join(
    "/content/gdrive/My Drive/Grad School/Dissertation/Data", "test"
)
label_path = os.path.join(
    "/content/gdrive/My Drive/Grad School/Dissertation/Data", "test.json"
)

batch_size = 16

dataset_train = AerialImageryDataset(
    image_dir_path=image_path,
    annotation_path=label_path,
    background_weight=0.001,
    train=True,
)
dataset_valtest = AerialImageryDataset(
    image_dir_path=image_path,
    annotation_path=label_path,
    background_weight=0.001,
    train=False,
)


g = torch.Generator()
g.manual_seed(2025)
indices = torch.randperm(n=len(dataset_train), generator=g).tolist()

subset_train = Subset(dataset_train, indices[: int(len(dataset_train) * 0.8)])
subset_val = Subset(
    dataset_valtest,
    indices[int(len(dataset_valtest) * 0.8) : int(len(dataset_valtest) * 0.9)],
)
subset_test = Subset(dataset_valtest, indices[int(len(dataset_valtest) * 0.9) :])

train_weights = [
    dataset_train.weights[idx] for idx in indices[: int(len(dataset_train) * 0.8)]
]

data_loader_train = DataLoader(
    subset_train,
    batch_size=batch_size,
    sampler=torch.utils.data.WeightedRandomSampler(train_weights, len(train_weights)),
    collate_fn=utils.collate_fn,
)
data_loader_val = DataLoader(
    subset_val, batch_size=batch_size, collate_fn=utils.collate_fn
)

data_loader_test = DataLoader(
    subset_test, batch_size=batch_size, collate_fn=utils.collate_fn
)

annotated_indices = []
unannotated_indices = []

for i in subset_val.indices:
    if "label" in subset_val.dataset.annotations[i]:
        annotated_indices.append(i)
    else:
        unannotated_indices.append(i)

subset_val_annotated = Subset(dataset_valtest, annotated_indices)
subset_val_unannotated = Subset(dataset_valtest, unannotated_indices)

data_loader_val_annotated = DataLoader(
    subset_val_annotated, batch_size=batch_size, collate_fn=utils.collate_fn
)

data_loader_val_unannotated = DataLoader(
    subset_val_unannotated, batch_size=batch_size, collate_fn=utils.collate_fn
)
# Out:
# 100%|██████████| 5000/5000 [00:00<00:00, 3138039.80it/s]
# 100%|██████████| 5000/5000 [00:00<00:00, 2973418.40it/s]

# %%
train_label_path = os.path.join(
    "/content/gdrive/My Drive/Grad School/Dissertation/Data", "test.json"
)

with open(train_label_path) as json_file:
    test = json.load(json_file)


test = test[int(len(test) * 0.8) : int(len(test) * 0.9)]

daylighting_count = 0
safety_islands_count = 0
curb_extensions_count = 0
empty_count = 0

for item in test:
    if "label" in item:
        counts = [0, 0, 0]
        for annot in item["label"]:
            if annot["rectanglelabels"][0] == "daylighting":
                # daylighting_count += 1
                counts[0] += 1
            elif annot["rectanglelabels"][0] == "safety_islands":
                # safety_islands_count += 1
                counts[1] += 1
            elif annot["rectanglelabels"][0] == "curb_extensions":
                # curb_extensions_count += 1
                counts[2] += 1

        if counts[2] != 0:
            counts = [1 * i for i in counts]
        # elif counts[0] == 0 and counts[2] != 0:
        #     counts = [4 * i for i in counts]

        daylighting_count += counts[0]
        safety_islands_count += counts[1]
        curb_extensions_count += counts[2]

    else:
        empty_count += 1

print(f"Daylighting: {daylighting_count}")
print(f"Safety Islands: {safety_islands_count}")
print(f"Curb Extensions: {curb_extensions_count}")
print(f"Empty: {empty_count}")
# Out:
# Daylighting: 127
# Safety Islands: 53
# Curb Extensions: 37
# Empty: 402

# %% [markdown]
# # Training

# %%
def train_one_epoch_no_schedule(
    model, optimizer, data_loader, device, epoch, print_freq
):
    model.train()
    metric_logger = utils.MetricLogger(delimiter="  ")
    metric_logger.add_meter("lr", utils.SmoothedValue(window_size=1, fmt="{value:.6f}"))
    header = f"Epoch: [{epoch}]"

    for images, targets in metric_logger.log_every(data_loader, print_freq, header):
        images = list(image.to(device) for image in images)
        targets = [
            {
                k: v.to(device) if isinstance(v, torch.Tensor) else v
                for k, v in t.items()
            }
            for t in targets
        ]

        with torch.amp.autocast("cuda", enabled=False):
            loss_dict = model(images, targets)
            losses = sum(loss for loss in loss_dict.values())

        # reduce losses over all GPUs for logging purposes
        loss_dict_reduced = utils.reduce_dict(loss_dict)
        losses_reduced = sum(loss for loss in loss_dict_reduced.values())

        loss_value = losses_reduced.item()

        if not math.isfinite(loss_value):
            print(f"Loss is {loss_value}, stopping training")
            print(loss_dict_reduced)
            sys.exit(1)

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        metric_logger.update(loss=losses_reduced, **loss_dict_reduced)
        metric_logger.update(lr=optimizer.param_groups[0]["lr"])

    return metric_logger

# %%
def training(
    model,
    optimizer,
    num_epochs,
    lr,
    save_loc,
    starting_epoch=0,
):
    device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

    model.to(device)

    for epoch in range(starting_epoch, starting_epoch + num_epochs):
        print("EPOCH " + str(epoch))
        train_one_epoch_no_schedule(
            model, optimizer, data_loader_train, device, epoch, print_freq=50
        )
        # evaluate(model_tune, data_loader_train, device=device)
        print("VALIDATION EVALUATION:")
        evaluate(model_tune, data_loader_val, device=device)
        print("VALIDATION ANNOTATED EVALUATION:")
        evaluate(model_tune, data_loader_val_annotated, device=device)

        save_path = save_loc + "_" + str(lr) + "_" + str(epoch) + ".pt"
        save_path = os.path.join(
            "/content/gdrive/My Drive/Grad School/Dissertation/Data", save_path
        )

        checkpoint = {
            "epoch": epoch,
            "model": model.state_dict(),
            "optimizer": optimizer.state_dict(),
        }
        torch.save(checkpoint, save_path)

    print("Training complete!")

# %% [markdown]
# # Experiments

# %% [markdown]
# ## Experiment 1: Fine-tuning

# %%
lr = 0.01
model_tune = fasterrcnn_resnet50_fpn_v2(
    weights="DEFAULT",
    # image_mean=[0.4715, 0.4723, 0.4587],
    # image_std=[0.2071, 0.1955, 0.1825]
)

# replace the pre-trained head with a new one
num_classes = 4
in_features = model_tune.roi_heads.box_predictor.cls_score.in_features
model_tune.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

params = [p for p in model_tune.parameters() if p.requires_grad]
optimizer = torch.optim.Adam(
    params,
    lr=lr,
)

training(
    model=model_tune,
    optimizer=optimizer,
    num_epochs=30,
    lr=lr,
    save_loc="pretrain_transform_0.001",
    starting_epoch=0,
)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth
# 100%|██████████| 167M/167M [00:00<00:00, 233MB/s]
# EPOCH 0
# Epoch: [0]  [  0/250]  eta: 3:19:29  lr: 0.010000  loss: 2.0771 (2.0771)  loss_classifier: 1.6337 (1.6337)  loss_box_reg: 0.0499 (0.0499)  loss_objectness: 0.3730 (0.3730)  loss_rpn_box_reg: 0.0205 (0.0205)  time: 47.8778  data: 43.7719  max mem: 18863
# Epoch: [0]  [ 50/250]  eta: 0:44:53  lr: 0.010000  loss: 0.3147 (2.0091)  loss_classifier: 0.0922 (0.9372)  loss_box_reg: 0.0353 (0.6596)  loss_objectness: 0.1524 (0.3421)  loss_rpn_box_reg: 0.0248 (0.0702)  time: 10.8769  data: 8.9094  max mem: 19190
# Epoch: [0]  [100/250]  eta: 0:24:08  lr: 0.010000  loss: 0.2820 (1.1847)  loss_classifier: 0.0859 (0.5287)  loss_box_reg: 0.0371 (0.3521)  loss_objectness: 0.1464 (0.2530)  loss_rpn_box_reg: 0.0225 (0.0509)  time: 4.9513  data: 2.9810  max mem: 19190
# Epoch: [0]  [150/250]  eta: 0:12:54  lr: 0.010000  loss: 0.3089 (0.8953)  loss_classifier: 0.0890 (0.3853)  loss_box_reg: 0.0396 (0.2490)  loss_objectness: 0.1447 (0.2188)  loss_rpn_box_reg: 0.0203 (0.0422)  time: 3.7882  data: 1.8239  max mem: 19190
# Epoch: [0]  [200/250]  eta: 0:05:27  lr: 0.010000  loss: 0.3106 (0.7538)  loss_classifier: 0.1143 (0.3175)  loss_box_reg: 0.0568 (0.2008)  loss_objectness: 0.1256 (0.1985)  loss_rpn_box_reg: 0.0179 (0.0370)  time: 2.6858  data: 0.7219  max mem: 19190
# Epoch: [0]  [249/250]  eta: 0:00:05  lr: 0.010000  loss: 0.3230 (0.6704)  loss_classifier: 0.1119 (0.2770)  loss_box_reg: 0.0562 (0.1720)  loss_objectness: 0.1411 (0.1870)  loss_rpn_box_reg: 0.0192 (0.0343)  time: 2.3798  data: 0.4125  max mem: 19190
# Epoch: [0] Total time: 0:23:56 (5.7455 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8118 (0.8118)  evaluator_time: 0.0050 (0.0050)  time: 0.9290  data: 0.1028  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8152 (0.7939)  evaluator_time: 0.0016 (0.0017)  time: 0.8843  data: 0.0894  max mem: 19190
# Test: Total time: 0:00:28 (0.8985 s / it)
# Averaged stats: model_time: 0.8152 (0.7939)  evaluator_time: 0.0016 (0.0017)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8183 (0.8183)  evaluator_time: 0.0042 (0.0042)  time: 0.9216  data: 0.0900  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8178 (0.7748)  evaluator_time: 0.0038 (0.0038)  time: 0.8846  data: 0.0971  max mem: 19190
# Test: Total time: 0:00:05 (0.8849 s / it)
# Averaged stats: model_time: 0.8178 (0.7748)  evaluator_time: 0.0038 (0.0038)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 1
# Epoch: [1]  [  0/250]  eta: 0:08:41  lr: 0.010000  loss: 0.3234 (0.3234)  loss_classifier: 0.1117 (0.1117)  loss_box_reg: 0.0576 (0.0576)  loss_objectness: 0.1282 (0.1282)  loss_rpn_box_reg: 0.0260 (0.0260)  time: 2.0864  data: 0.1131  max mem: 19190
# Epoch: [1]  [ 50/250]  eta: 0:06:54  lr: 0.010000  loss: 0.3543 (0.3520)  loss_classifier: 0.1313 (0.1299)  loss_box_reg: 0.0752 (0.0689)  loss_objectness: 0.1219 (0.1306)  loss_rpn_box_reg: 0.0177 (0.0226)  time: 2.0677  data: 0.1063  max mem: 19190
# Epoch: [1]  [100/250]  eta: 0:05:10  lr: 0.010000  loss: 0.3426 (0.3591)  loss_classifier: 0.1266 (0.1344)  loss_box_reg: 0.0688 (0.0729)  loss_objectness: 0.1208 (0.1291)  loss_rpn_box_reg: 0.0203 (0.0227)  time: 2.0685  data: 0.1080  max mem: 19190
# Epoch: [1]  [150/250]  eta: 0:03:27  lr: 0.010000  loss: 0.3517 (0.3679)  loss_classifier: 0.1135 (0.1336)  loss_box_reg: 0.0547 (0.0721)  loss_objectness: 0.1337 (0.1340)  loss_rpn_box_reg: 0.0219 (0.0281)  time: 2.0673  data: 0.1058  max mem: 19190
# Epoch: [1]  [200/250]  eta: 0:01:43  lr: 0.010000  loss: 0.3372 (0.3627)  loss_classifier: 0.1146 (0.1319)  loss_box_reg: 0.0547 (0.0705)  loss_objectness: 0.1333 (0.1328)  loss_rpn_box_reg: 0.0233 (0.0275)  time: 2.0693  data: 0.1100  max mem: 19190
# Epoch: [1]  [249/250]  eta: 0:00:02  lr: 0.010000  loss: 0.3860 (0.3667)  loss_classifier: 0.1523 (0.1346)  loss_box_reg: 0.0840 (0.0728)  loss_objectness: 0.1196 (0.1320)  loss_rpn_box_reg: 0.0211 (0.0274)  time: 2.0871  data: 0.1127  max mem: 19190
# Epoch: [1] Total time: 0:08:38 (2.0731 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:28  model_time: 0.8065 (0.8065)  evaluator_time: 0.0012 (0.0012)  time: 0.9048  data: 0.0878  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8156 (0.7955)  evaluator_time: 0.0016 (0.0016)  time: 0.8878  data: 0.0914  max mem: 19190
# Test: Total time: 0:00:28 (0.9000 s / it)
# Averaged stats: model_time: 0.8156 (0.7955)  evaluator_time: 0.0016 (0.0016)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8100 (0.8100)  evaluator_time: 0.0040 (0.0040)  time: 0.9306  data: 0.1075  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8116 (0.7691)  evaluator_time: 0.0038 (0.0038)  time: 0.8782  data: 0.0966  max mem: 19190
# Test: Total time: 0:00:05 (0.8785 s / it)
# Averaged stats: model_time: 0.8116 (0.7691)  evaluator_time: 0.0038 (0.0038)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 2
# Epoch: [2]  [  0/250]  eta: 0:08:42  lr: 0.010000  loss: 0.3889 (0.3889)  loss_classifier: 0.1582 (0.1582)  loss_box_reg: 0.0920 (0.0920)  loss_objectness: 0.1164 (0.1164)  loss_rpn_box_reg: 0.0223 (0.0223)  time: 2.0902  data: 0.1228  max mem: 19190
# Epoch: [2]  [ 50/250]  eta: 0:06:54  lr: 0.010000  loss: 0.3440 (0.3731)  loss_classifier: 0.1374 (0.1470)  loss_box_reg: 0.0757 (0.0830)  loss_objectness: 0.1072 (0.1184)  loss_rpn_box_reg: 0.0194 (0.0247)  time: 2.0627  data: 0.1098  max mem: 19190
# Epoch: [2]  [100/250]  eta: 0:05:10  lr: 0.010000  loss: 0.3847 (0.3830)  loss_classifier: 0.1418 (0.1465)  loss_box_reg: 0.0801 (0.0825)  loss_objectness: 0.1270 (0.1253)  loss_rpn_box_reg: 0.0179 (0.0287)  time: 2.0574  data: 0.1043  max mem: 19190
# Epoch: [2]  [150/250]  eta: 0:03:26  lr: 0.010000  loss: 0.3591 (0.3801)  loss_classifier: 0.1384 (0.1458)  loss_box_reg: 0.0798 (0.0822)  loss_objectness: 0.1106 (0.1253)  loss_rpn_box_reg: 0.0164 (0.0267)  time: 2.0663  data: 0.1091  max mem: 19190
# Epoch: [2]  [200/250]  eta: 0:01:43  lr: 0.010000  loss: 0.4124 (0.3838)  loss_classifier: 0.1528 (0.1483)  loss_box_reg: 0.0934 (0.0852)  loss_objectness: 0.1214 (0.1246)  loss_rpn_box_reg: 0.0207 (0.0257)  time: 2.0714  data: 0.1106  max mem: 19190
# Epoch: [2]  [249/250]  eta: 0:00:02  lr: 0.010000  loss: 0.4131 (0.3980)  loss_classifier: 0.1631 (0.1498)  loss_box_reg: 0.1037 (0.0868)  loss_objectness: 0.1316 (0.1266)  loss_rpn_box_reg: 0.0203 (0.0348)  time: 2.0643  data: 0.1087  max mem: 19190
# Epoch: [2] Total time: 0:08:36 (2.0668 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8010 (0.8010)  evaluator_time: 0.0012 (0.0012)  time: 0.9072  data: 0.0958  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8143 (0.7929)  evaluator_time: 0.0016 (0.0015)  time: 0.8892  data: 0.0946  max mem: 19190
# Test: Total time: 0:00:28 (0.8986 s / it)
# Averaged stats: model_time: 0.8143 (0.7929)  evaluator_time: 0.0016 (0.0015)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8039 (0.8039)  evaluator_time: 0.0040 (0.0040)  time: 0.9125  data: 0.0954  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8049 (0.7635)  evaluator_time: 0.0038 (0.0038)  time: 0.8685  data: 0.0924  max mem: 19190
# Test: Total time: 0:00:05 (0.8688 s / it)
# Averaged stats: model_time: 0.8049 (0.7635)  evaluator_time: 0.0038 (0.0038)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 3
# Epoch: [3]  [  0/250]  eta: 0:08:38  lr: 0.010000  loss: 0.3097 (0.3097)  loss_classifier: 0.1262 (0.1262)  loss_box_reg: 0.0827 (0.0827)  loss_objectness: 0.0861 (0.0861)  loss_rpn_box_reg: 0.0147 (0.0147)  time: 2.0750  data: 0.1133  max mem: 19190
# Epoch: [3]  [ 50/250]  eta: 0:06:53  lr: 0.010000  loss: 0.4037 (0.3939)  loss_classifier: 0.1570 (0.1564)  loss_box_reg: 0.0943 (0.0958)  loss_objectness: 0.1160 (0.1189)  loss_rpn_box_reg: 0.0201 (0.0229)  time: 2.0536  data: 0.1105  max mem: 19190
# Epoch: [3]  [100/250]  eta: 0:05:09  lr: 0.010000  loss: 0.3318 (0.4577)  loss_classifier: 0.1117 (0.1420)  loss_box_reg: 0.0569 (0.0832)  loss_objectness: 0.1411 (0.1569)  loss_rpn_box_reg: 0.0205 (0.0757)  time: 2.0623  data: 0.1061  max mem: 19190
# Epoch: [3]  [150/250]  eta: 0:03:26  lr: 0.010000  loss: 0.3803 (0.4316)  loss_classifier: 0.1282 (0.1372)  loss_box_reg: 0.0716 (0.0793)  loss_objectness: 0.1373 (0.1551)  loss_rpn_box_reg: 0.0244 (0.0601)  time: 2.0635  data: 0.1121  max mem: 19190
# Epoch: [3]  [200/250]  eta: 0:01:43  lr: 0.010000  loss: 0.3420 (0.4103)  loss_classifier: 0.1276 (0.1338)  loss_box_reg: 0.0739 (0.0767)  loss_objectness: 0.1269 (0.1485)  loss_rpn_box_reg: 0.0197 (0.0512)  time: 2.0668  data: 0.1141  max mem: 19190
# Epoch: [3]  [249/250]  eta: 0:00:02  lr: 0.010000  loss: 0.3255 (0.3972)  loss_classifier: 0.1240 (0.1331)  loss_box_reg: 0.0704 (0.0762)  loss_objectness: 0.1152 (0.1427)  loss_rpn_box_reg: 0.0182 (0.0451)  time: 2.0558  data: 0.1066  max mem: 19190
# Epoch: [3] Total time: 0:08:35 (2.0621 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:28  model_time: 0.8040 (0.8040)  evaluator_time: 0.0012 (0.0012)  time: 0.9024  data: 0.0881  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8126 (0.7916)  evaluator_time: 0.0016 (0.0015)  time: 0.8849  data: 0.0920  max mem: 19190
# Test: Total time: 0:00:28 (0.8955 s / it)
# Averaged stats: model_time: 0.8126 (0.7916)  evaluator_time: 0.0016 (0.0015)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8048 (0.8048)  evaluator_time: 0.0040 (0.0040)  time: 0.9100  data: 0.0922  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8051 (0.7636)  evaluator_time: 0.0038 (0.0037)  time: 0.8727  data: 0.0965  max mem: 19190
# Test: Total time: 0:00:05 (0.8729 s / it)
# Averaged stats: model_time: 0.8051 (0.7636)  evaluator_time: 0.0038 (0.0037)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 4
# Epoch: [4]  [  0/250]  eta: 0:08:40  lr: 0.010000  loss: 0.4236 (0.4236)  loss_classifier: 0.1398 (0.1398)  loss_box_reg: 0.0846 (0.0846)  loss_objectness: 0.1635 (0.1635)  loss_rpn_box_reg: 0.0356 (0.0356)  time: 2.0830  data: 0.1248  max mem: 19190
# Epoch: [4]  [ 50/250]  eta: 0:06:52  lr: 0.010000  loss: 0.3627 (0.3545)  loss_classifier: 0.1360 (0.1353)  loss_box_reg: 0.0770 (0.0788)  loss_objectness: 0.1151 (0.1196)  loss_rpn_box_reg: 0.0185 (0.0209)  time: 2.0545  data: 0.1097  max mem: 19190
# Epoch: [4]  [100/250]  eta: 0:05:08  lr: 0.010000  loss: 0.3871 (0.3649)  loss_classifier: 0.1380 (0.1387)  loss_box_reg: 0.0811 (0.0804)  loss_objectness: 0.1200 (0.1230)  loss_rpn_box_reg: 0.0201 (0.0228)  time: 2.0526  data: 0.1109  max mem: 19190
# Epoch: [4]  [150/250]  eta: 0:03:25  lr: 0.010000  loss: 0.3771 (0.3766)  loss_classifier: 0.1576 (0.1443)  loss_box_reg: 0.0966 (0.0846)  loss_objectness: 0.1104 (0.1235)  loss_rpn_box_reg: 0.0220 (0.0242)  time: 2.0562  data: 0.1113  max mem: 19190
# Epoch: [4]  [200/250]  eta: 0:01:42  lr: 0.010000  loss: 0.3829 (0.3739)  loss_classifier: 0.1399 (0.1444)  loss_box_reg: 0.0852 (0.0851)  loss_objectness: 0.1076 (0.1213)  loss_rpn_box_reg: 0.0188 (0.0232)  time: 2.0546  data: 0.1108  max mem: 19190
# Epoch: [4]  [249/250]  eta: 0:00:02  lr: 0.010000  loss: 0.3488 (0.3730)  loss_classifier: 0.1354 (0.1446)  loss_box_reg: 0.0872 (0.0853)  loss_objectness: 0.1106 (0.1201)  loss_rpn_box_reg: 0.0183 (0.0230)  time: 2.0493  data: 0.1072  max mem: 19190
# Epoch: [4] Total time: 0:08:33 (2.0551 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:28  model_time: 0.8078 (0.8078)  evaluator_time: 0.0012 (0.0012)  time: 0.9052  data: 0.0871  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8150 (0.7940)  evaluator_time: 0.0015 (0.0015)  time: 0.8848  data: 0.0903  max mem: 19190
# Test: Total time: 0:00:28 (0.8970 s / it)
# Averaged stats: model_time: 0.8150 (0.7940)  evaluator_time: 0.0015 (0.0015)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8105 (0.8105)  evaluator_time: 0.0045 (0.0045)  time: 0.9126  data: 0.0887  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8096 (0.7659)  evaluator_time: 0.0035 (0.0037)  time: 0.8725  data: 0.0941  max mem: 19190
# Test: Total time: 0:00:05 (0.8727 s / it)
# Averaged stats: model_time: 0.8096 (0.7659)  evaluator_time: 0.0035 (0.0037)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 5
# Epoch: [5]  [  0/250]  eta: 0:08:32  lr: 0.010000  loss: 0.4623 (0.4623)  loss_classifier: 0.1996 (0.1996)  loss_box_reg: 0.1360 (0.1360)  loss_objectness: 0.1109 (0.1109)  loss_rpn_box_reg: 0.0158 (0.0158)  time: 2.0506  data: 0.1077  max mem: 19190
# Epoch: [5]  [ 50/250]  eta: 0:06:56  lr: 0.010000  loss: 0.4086 (0.3965)  loss_classifier: 0.1512 (0.1615)  loss_box_reg: 0.0933 (0.1011)  loss_objectness: 0.1153 (0.1129)  loss_rpn_box_reg: 0.0205 (0.0210)  time: 2.0573  data: 0.1140  max mem: 19190
# Epoch: [5]  [100/250]  eta: 0:05:10  lr: 0.010000  loss: 0.3931 (0.3941)  loss_classifier: 0.1637 (0.1616)  loss_box_reg: 0.1042 (0.1018)  loss_objectness: 0.1012 (0.1097)  loss_rpn_box_reg: 0.0174 (0.0210)  time: 2.0592  data: 0.1101  max mem: 19190
# Epoch: [5]  [150/250]  eta: 0:03:26  lr: 0.010000  loss: 0.3594 (0.3887)  loss_classifier: 0.1474 (0.1593)  loss_box_reg: 0.0946 (0.0996)  loss_objectness: 0.1010 (0.1087)  loss_rpn_box_reg: 0.0196 (0.0210)  time: 2.0555  data: 0.1094  max mem: 19190
# Epoch: [5]  [200/250]  eta: 0:01:43  lr: 0.010000  loss: 0.3605 (0.3926)  loss_classifier: 0.1415 (0.1564)  loss_box_reg: 0.0823 (0.0973)  loss_objectness: 0.1071 (0.1100)  loss_rpn_box_reg: 0.0182 (0.0289)  time: 2.0574  data: 0.1082  max mem: 19190
# Epoch: [5]  [249/250]  eta: 0:00:02  lr: 0.010000  loss: 0.3203 (0.3874)  loss_classifier: 0.1307 (0.1541)  loss_box_reg: 0.0772 (0.0952)  loss_objectness: 0.1072 (0.1107)  loss_rpn_box_reg: 0.0162 (0.0274)  time: 2.0593  data: 0.1045  max mem: 19190
# Epoch: [5] Total time: 0:08:36 (2.0644 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8147 (0.8147)  evaluator_time: 0.0040 (0.0040)  time: 0.9164  data: 0.0884  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8164 (0.7960)  evaluator_time: 0.0038 (0.0039)  time: 0.8890  data: 0.0901  max mem: 19190
# Test: Total time: 0:00:28 (0.9026 s / it)
# Averaged stats: model_time: 0.8164 (0.7960)  evaluator_time: 0.0038 (0.0039)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8099 (0.8099)  evaluator_time: 0.0068 (0.0068)  time: 0.9144  data: 0.0887  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8100 (0.7699)  evaluator_time: 0.0068 (0.0067)  time: 0.8769  data: 0.0916  max mem: 19190
# Test: Total time: 0:00:05 (0.8772 s / it)
# Averaged stats: model_time: 0.8100 (0.7699)  evaluator_time: 0.0068 (0.0067)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 6
# Epoch: [6]  [  0/250]  eta: 0:08:34  lr: 0.010000  loss: 0.3386 (0.3386)  loss_classifier: 0.1267 (0.1267)  loss_box_reg: 0.0831 (0.0831)  loss_objectness: 0.1091 (0.1091)  loss_rpn_box_reg: 0.0197 (0.0197)  time: 2.0568  data: 0.1044  max mem: 19190
# Epoch: [6]  [ 50/250]  eta: 0:06:53  lr: 0.010000  loss: 0.3845 (0.3832)  loss_classifier: 0.1571 (0.1563)  loss_box_reg: 0.0893 (0.0965)  loss_objectness: 0.1064 (0.1085)  loss_rpn_box_reg: 0.0197 (0.0219)  time: 2.0609  data: 0.1097  max mem: 19190
# Epoch: [6]  [100/250]  eta: 0:05:09  lr: 0.010000  loss: 0.3921 (0.3929)  loss_classifier: 0.1608 (0.1579)  loss_box_reg: 0.0977 (0.0982)  loss_objectness: 0.1016 (0.1116)  loss_rpn_box_reg: 0.0195 (0.0252)  time: 2.0673  data: 0.1114  max mem: 19190
# Epoch: [6]  [150/250]  eta: 0:03:26  lr: 0.010000  loss: 0.4150 (0.3939)  loss_classifier: 0.1678 (0.1596)  loss_box_reg: 0.1154 (0.1007)  loss_objectness: 0.1007 (0.1094)  loss_rpn_box_reg: 0.0210 (0.0242)  time: 2.0652  data: 0.1102  max mem: 19190
# Epoch: [6]  [200/250]  eta: 0:01:43  lr: 0.010000  loss: 0.3978 (0.3975)  loss_classifier: 0.1628 (0.1624)  loss_box_reg: 0.1120 (0.1038)  loss_objectness: 0.0960 (0.1076)  loss_rpn_box_reg: 0.0174 (0.0237)  time: 2.0631  data: 0.1071  max mem: 19190
# Epoch: [6]  [249/250]  eta: 0:00:02  lr: 0.010000  loss: 0.4145 (0.3985)  loss_classifier: 0.1758 (0.1636)  loss_box_reg: 0.1215 (0.1061)  loss_objectness: 0.0912 (0.1054)  loss_rpn_box_reg: 0.0204 (0.0233)  time: 2.0711  data: 0.1142  max mem: 19190
# Epoch: [6] Total time: 0:08:36 (2.0651 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8155 (0.8155)  evaluator_time: 0.0086 (0.0086)  time: 0.9235  data: 0.0901  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8227 (0.8010)  evaluator_time: 0.0100 (0.0100)  time: 0.9001  data: 0.0901  max mem: 19190
# Test: Total time: 0:00:29 (0.9109 s / it)
# Averaged stats: model_time: 0.8227 (0.8010)  evaluator_time: 0.0100 (0.0100)
# Accumulating evaluation results...
# DONE (t=0.13s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8161 (0.8161)  evaluator_time: 0.0215 (0.0215)  time: 0.9358  data: 0.0889  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8168 (0.7749)  evaluator_time: 0.0165 (0.0173)  time: 0.8922  data: 0.0911  max mem: 19190
# Test: Total time: 0:00:05 (0.8925 s / it)
# Averaged stats: model_time: 0.8168 (0.7749)  evaluator_time: 0.0165 (0.0173)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 7
# Epoch: [7]  [  0/250]  eta: 0:10:38  lr: 0.010000  loss: 0.3786 (0.3786)  loss_classifier: 0.1688 (0.1688)  loss_box_reg: 0.1021 (0.1021)  loss_objectness: 0.0911 (0.0911)  loss_rpn_box_reg: 0.0165 (0.0165)  time: 2.5555  data: 0.5977  max mem: 19190
# Epoch: [7]  [ 50/250]  eta: 0:06:54  lr: 0.010000  loss: 0.4196 (0.4283)  loss_classifier: 0.1780 (0.1764)  loss_box_reg: 0.1213 (0.1214)  loss_objectness: 0.1008 (0.1055)  loss_rpn_box_reg: 0.0203 (0.0250)  time: 2.0545  data: 0.1068  max mem: 19190
# Epoch: [7]  [100/250]  eta: 0:05:10  lr: 0.010000  loss: 0.3789 (0.4181)  loss_classifier: 0.1598 (0.1745)  loss_box_reg: 0.1050 (0.1195)  loss_objectness: 0.0865 (0.1012)  loss_rpn_box_reg: 0.0158 (0.0229)  time: 2.0642  data: 0.1099  max mem: 19190
# Epoch: [7]  [150/250]  eta: 0:03:26  lr: 0.010000  loss: 0.3947 (0.4171)  loss_classifier: 0.1675 (0.1735)  loss_box_reg: 0.1057 (0.1180)  loss_objectness: 0.0916 (0.1021)  loss_rpn_box_reg: 0.0177 (0.0235)  time: 2.0673  data: 0.1112  max mem: 19190
# Epoch: [7]  [200/250]  eta: 0:01:43  lr: 0.010000  loss: 0.4089 (0.4151)  loss_classifier: 0.1696 (0.1738)  loss_box_reg: 0.1174 (0.1184)  loss_objectness: 0.0886 (0.0999)  loss_rpn_box_reg: 0.0198 (0.0229)  time: 2.0644  data: 0.1114  max mem: 19190
# Epoch: [7]  [249/250]  eta: 0:00:02  lr: 0.010000  loss: 0.3944 (0.4156)  loss_classifier: 0.1693 (0.1745)  loss_box_reg: 0.1197 (0.1192)  loss_objectness: 0.0810 (0.0989)  loss_rpn_box_reg: 0.0202 (0.0231)  time: 2.0653  data: 0.1087  max mem: 19190
# Epoch: [7] Total time: 0:08:36 (2.0664 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8169 (0.8169)  evaluator_time: 0.0095 (0.0095)  time: 0.9268  data: 0.0912  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8253 (0.8041)  evaluator_time: 0.0118 (0.0121)  time: 0.9047  data: 0.0894  max mem: 19190
# Test: Total time: 0:00:29 (0.9165 s / it)
# Averaged stats: model_time: 0.8253 (0.8041)  evaluator_time: 0.0118 (0.0121)
# Accumulating evaluation results...
# DONE (t=0.16s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.012
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.046
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.068
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.028
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.083
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8229 (0.8229)  evaluator_time: 0.0295 (0.0295)  time: 0.9518  data: 0.0900  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8195 (0.7774)  evaluator_time: 0.0295 (0.0526)  time: 0.9305  data: 0.0917  max mem: 19190
# Test: Total time: 0:00:05 (0.9308 s / it)
# Averaged stats: model_time: 0.8195 (0.7774)  evaluator_time: 0.0295 (0.0526)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.014
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.012
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.046
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.068
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.028
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.083
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 8
# Epoch: [8]  [  0/250]  eta: 0:08:36  lr: 0.010000  loss: 0.4286 (0.4286)  loss_classifier: 0.1899 (0.1899)  loss_box_reg: 0.1316 (0.1316)  loss_objectness: 0.0870 (0.0870)  loss_rpn_box_reg: 0.0201 (0.0201)  time: 2.0646  data: 0.1073  max mem: 19190
# Epoch: [8]  [ 50/250]  eta: 0:06:59  lr: 0.010000  loss: 0.4032 (0.4023)  loss_classifier: 0.1729 (0.1683)  loss_box_reg: 0.1176 (0.1180)  loss_objectness: 0.0842 (0.0925)  loss_rpn_box_reg: 0.0228 (0.0234)  time: 2.0662  data: 0.1115  max mem: 19190
# Epoch: [8]  [100/250]  eta: 0:05:12  lr: 0.010000  loss: 0.4452 (0.4028)  loss_classifier: 0.1720 (0.1693)  loss_box_reg: 0.1187 (0.1176)  loss_objectness: 0.0988 (0.0928)  loss_rpn_box_reg: 0.0204 (0.0231)  time: 2.0643  data: 0.1070  max mem: 19190
# Epoch: [8]  [150/250]  eta: 0:03:27  lr: 0.010000  loss: 0.3655 (0.4044)  loss_classifier: 0.1565 (0.1705)  loss_box_reg: 0.1062 (0.1188)  loss_objectness: 0.0896 (0.0921)  loss_rpn_box_reg: 0.0194 (0.0230)  time: 2.0633  data: 0.1068  max mem: 19190
# Epoch: [8]  [200/250]  eta: 0:01:43  lr: 0.010000  loss: 0.3924 (0.4067)  loss_classifier: 0.1644 (0.1715)  loss_box_reg: 0.1168 (0.1203)  loss_objectness: 0.0897 (0.0918)  loss_rpn_box_reg: 0.0213 (0.0231)  time: 2.0622  data: 0.1069  max mem: 19190
# Epoch: [8]  [249/250]  eta: 0:00:02  lr: 0.010000  loss: 0.4124 (0.4082)  loss_classifier: 0.1829 (0.1724)  loss_box_reg: 0.1326 (0.1223)  loss_objectness: 0.0839 (0.0904)  loss_rpn_box_reg: 0.0189 (0.0231)  time: 2.0634  data: 0.1062  max mem: 19190
# Epoch: [8] Total time: 0:08:37 (2.0706 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8155 (0.8155)  evaluator_time: 0.0069 (0.0069)  time: 0.9213  data: 0.0897  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8211 (0.8005)  evaluator_time: 0.0074 (0.0075)  time: 0.9002  data: 0.0926  max mem: 19190
# Test: Total time: 0:00:29 (0.9107 s / it)
# Averaged stats: model_time: 0.8211 (0.8005)  evaluator_time: 0.0074 (0.0075)
# Accumulating evaluation results...
# DONE (t=0.08s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.029
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.019
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8155 (0.8155)  evaluator_time: 0.0120 (0.0120)  time: 0.9252  data: 0.0884  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8174 (0.7746)  evaluator_time: 0.0129 (0.0139)  time: 0.8917  data: 0.0944  max mem: 19190
# Test: Total time: 0:00:05 (0.8919 s / it)
# Averaged stats: model_time: 0.8174 (0.7746)  evaluator_time: 0.0129 (0.0139)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.029
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.019
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 9
# Epoch: [9]  [  0/250]  eta: 0:08:42  lr: 0.010000  loss: 0.3713 (0.3713)  loss_classifier: 0.1557 (0.1557)  loss_box_reg: 0.1052 (0.1052)  loss_objectness: 0.0927 (0.0927)  loss_rpn_box_reg: 0.0178 (0.0178)  time: 2.0900  data: 0.1188  max mem: 19190
# Epoch: [9]  [ 50/250]  eta: 0:06:53  lr: 0.010000  loss: 0.4341 (0.4131)  loss_classifier: 0.1765 (0.1735)  loss_box_reg: 0.1285 (0.1246)  loss_objectness: 0.0798 (0.0912)  loss_rpn_box_reg: 0.0180 (0.0237)  time: 2.0596  data: 0.1090  max mem: 19190
# Epoch: [9]  [100/250]  eta: 0:05:09  lr: 0.010000  loss: 0.4022 (0.4101)  loss_classifier: 0.1637 (0.1737)  loss_box_reg: 0.1244 (0.1278)  loss_objectness: 0.0785 (0.0869)  loss_rpn_box_reg: 0.0185 (0.0216)  time: 2.0623  data: 0.1075  max mem: 19190
# Epoch: [9]  [150/250]  eta: 0:03:26  lr: 0.010000  loss: 0.4325 (0.4136)  loss_classifier: 0.1867 (0.1755)  loss_box_reg: 0.1488 (0.1311)  loss_objectness: 0.0781 (0.0851)  loss_rpn_box_reg: 0.0177 (0.0219)  time: 2.0672  data: 0.1070  max mem: 19190
# Epoch: [9]  [200/250]  eta: 0:01:43  lr: 0.010000  loss: 0.4255 (0.4201)  loss_classifier: 0.1759 (0.1780)  loss_box_reg: 0.1358 (0.1345)  loss_objectness: 0.0731 (0.0848)  loss_rpn_box_reg: 0.0181 (0.0228)  time: 2.0663  data: 0.1075  max mem: 19190
# Epoch: [9]  [249/250]  eta: 0:00:02  lr: 0.010000  loss: 0.3918 (0.4215)  loss_classifier: 0.1768 (0.1776)  loss_box_reg: 0.1261 (0.1340)  loss_objectness: 0.0785 (0.0850)  loss_rpn_box_reg: 0.0191 (0.0249)  time: 2.0675  data: 0.1127  max mem: 19190
# Epoch: [9] Total time: 0:08:36 (2.0664 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8154 (0.8154)  evaluator_time: 0.0117 (0.0117)  time: 0.9253  data: 0.0889  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8229 (0.8031)  evaluator_time: 0.0136 (0.0191)  time: 0.9137  data: 0.0895  max mem: 19190
# Test: Total time: 0:00:29 (0.9235 s / it)
# Averaged stats: model_time: 0.8229 (0.8031)  evaluator_time: 0.0136 (0.0191)
# Accumulating evaluation results...
# DONE (t=0.20s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.045
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.016
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.024
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.070
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.030
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.136
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8180 (0.8180)  evaluator_time: 0.0328 (0.0328)  time: 0.9628  data: 0.1025  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8170 (0.7740)  evaluator_time: 0.0324 (0.0308)  time: 0.9096  data: 0.0959  max mem: 19190
# Test: Total time: 0:00:05 (0.9098 s / it)
# Averaged stats: model_time: 0.8170 (0.7740)  evaluator_time: 0.0324 (0.0308)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.072
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.024
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.070
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.030
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.136
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 10
# Epoch: [10]  [  0/250]  eta: 0:08:37  lr: 0.010000  loss: 0.4214 (0.4214)  loss_classifier: 0.1736 (0.1736)  loss_box_reg: 0.1335 (0.1335)  loss_objectness: 0.0973 (0.0973)  loss_rpn_box_reg: 0.0170 (0.0170)  time: 2.0713  data: 0.1219  max mem: 19190
# Epoch: [10]  [ 50/250]  eta: 0:06:53  lr: 0.010000  loss: 0.3685 (0.4020)  loss_classifier: 0.1590 (0.1652)  loss_box_reg: 0.1201 (0.1225)  loss_objectness: 0.0793 (0.0885)  loss_rpn_box_reg: 0.0194 (0.0257)  time: 2.0590  data: 0.1115  max mem: 19190
# Epoch: [10]  [100/250]  eta: 0:05:09  lr: 0.010000  loss: 0.4004 (0.4086)  loss_classifier: 0.1620 (0.1693)  loss_box_reg: 0.1231 (0.1277)  loss_objectness: 0.0877 (0.0871)  loss_rpn_box_reg: 0.0257 (0.0245)  time: 2.0625  data: 0.1097  max mem: 19190
# Epoch: [10]  [150/250]  eta: 0:03:26  lr: 0.010000  loss: 0.3858 (0.4058)  loss_classifier: 0.1640 (0.1691)  loss_box_reg: 0.1230 (0.1274)  loss_objectness: 0.0773 (0.0856)  loss_rpn_box_reg: 0.0182 (0.0237)  time: 2.0591  data: 0.1091  max mem: 19190
# Epoch: [10]  [200/250]  eta: 0:01:43  lr: 0.010000  loss: 0.3945 (0.4054)  loss_classifier: 0.1590 (0.1689)  loss_box_reg: 0.1246 (0.1283)  loss_objectness: 0.0766 (0.0844)  loss_rpn_box_reg: 0.0210 (0.0237)  time: 2.0621  data: 0.1092  max mem: 19190
# Epoch: [10]  [249/250]  eta: 0:00:02  lr: 0.010000  loss: 0.3699 (0.4026)  loss_classifier: 0.1546 (0.1678)  loss_box_reg: 0.1283 (0.1277)  loss_objectness: 0.0731 (0.0834)  loss_rpn_box_reg: 0.0198 (0.0237)  time: 2.0585  data: 0.1060  max mem: 19190
# Epoch: [10] Total time: 0:08:35 (2.0630 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8169 (0.8169)  evaluator_time: 0.0126 (0.0126)  time: 0.9434  data: 0.1042  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8261 (0.8046)  evaluator_time: 0.0129 (0.0183)  time: 0.9143  data: 0.0894  max mem: 19190
# Test: Total time: 0:00:29 (0.9242 s / it)
# Averaged stats: model_time: 0.8261 (0.8046)  evaluator_time: 0.0129 (0.0183)
# Accumulating evaluation results...
# DONE (t=0.18s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.016
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.062
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.023
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.016
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# ...
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.061
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.117
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.122
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.070
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.147
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8281 (0.8281)  evaluator_time: 0.0193 (0.0193)  time: 0.9591  data: 0.1023  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8280 (0.7848)  evaluator_time: 0.0185 (0.0184)  time: 0.9058  data: 0.0939  max mem: 19190
# Test: Total time: 0:00:05 (0.9060 s / it)
# Averaged stats: model_time: 0.8280 (0.7848)  evaluator_time: 0.0185 (0.0184)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.062
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.159
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.081
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.061
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.117
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.122
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.070
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.147
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 27
# Epoch: [27]  [  0/250]  eta: 0:08:40  lr: 0.010000  loss: 0.1815 (0.1815)  loss_classifier: 0.0596 (0.0596)  loss_box_reg: 0.0868 (0.0868)  loss_objectness: 0.0149 (0.0149)  loss_rpn_box_reg: 0.0201 (0.0201)  time: 2.0839  data: 0.1233  max mem: 19190
# Epoch: [27]  [ 50/250]  eta: 0:07:05  lr: 0.010000  loss: 0.2116 (0.2251)  loss_classifier: 0.0795 (0.0797)  loss_box_reg: 0.1051 (0.1077)  loss_objectness: 0.0115 (0.0136)  loss_rpn_box_reg: 0.0175 (0.0241)  time: 2.1217  data: 0.1603  max mem: 19190
# Epoch: [27]  [100/250]  eta: 0:05:14  lr: 0.010000  loss: 0.2274 (0.2301)  loss_classifier: 0.0841 (0.0810)  loss_box_reg: 0.1092 (0.1084)  loss_objectness: 0.0146 (0.0171)  loss_rpn_box_reg: 0.0181 (0.0236)  time: 2.0665  data: 0.1090  max mem: 19190
# Epoch: [27]  [150/250]  eta: 0:03:28  lr: 0.010000  loss: 0.2098 (0.2281)  loss_classifier: 0.0751 (0.0803)  loss_box_reg: 0.0923 (0.1071)  loss_objectness: 0.0125 (0.0165)  loss_rpn_box_reg: 0.0191 (0.0242)  time: 2.0626  data: 0.1089  max mem: 19190
# Epoch: [27]  [200/250]  eta: 0:01:44  lr: 0.010000  loss: 0.2115 (0.2256)  loss_classifier: 0.0743 (0.0801)  loss_box_reg: 0.0948 (0.1065)  loss_objectness: 0.0150 (0.0160)  loss_rpn_box_reg: 0.0184 (0.0230)  time: 2.0758  data: 0.1094  max mem: 19190
# Epoch: [27]  [249/250]  eta: 0:00:02  lr: 0.010000  loss: 0.2270 (0.2248)  loss_classifier: 0.0813 (0.0804)  loss_box_reg: 0.1006 (0.1064)  loss_objectness: 0.0125 (0.0155)  loss_rpn_box_reg: 0.0177 (0.0224)  time: 2.0685  data: 0.1096  max mem: 19190
# Epoch: [27] Total time: 0:08:39 (2.0793 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8264 (0.8264)  evaluator_time: 0.0100 (0.0100)  time: 0.9449  data: 0.0995  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8404 (0.8181)  evaluator_time: 0.0123 (0.0124)  time: 0.9232  data: 0.0927  max mem: 19190
# Test: Total time: 0:00:30 (0.9486 s / it)
# Averaged stats: model_time: 0.8404 (0.8181)  evaluator_time: 0.0123 (0.0124)
# Accumulating evaluation results...
# DONE (t=0.15s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.047
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.113
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.064
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.153
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.154
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8242 (0.8242)  evaluator_time: 0.0211 (0.0211)  time: 0.9412  data: 0.0868  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8288 (0.7868)  evaluator_time: 0.0211 (0.0217)  time: 0.9085  data: 0.0912  max mem: 19190
# Test: Total time: 0:00:05 (0.9088 s / it)
# Averaged stats: model_time: 0.8288 (0.7868)  evaluator_time: 0.0211 (0.0217)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.062
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.158
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.030
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.081
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.153
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.154
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 28
# Epoch: [28]  [  0/250]  eta: 0:10:03  lr: 0.010000  loss: 0.2169 (0.2169)  loss_classifier: 0.0815 (0.0815)  loss_box_reg: 0.0960 (0.0960)  loss_objectness: 0.0100 (0.0100)  loss_rpn_box_reg: 0.0294 (0.0294)  time: 2.4140  data: 0.4481  max mem: 19190
# Epoch: [28]  [ 50/250]  eta: 0:07:00  lr: 0.010000  loss: 0.2151 (0.2319)  loss_classifier: 0.0788 (0.0838)  loss_box_reg: 0.1061 (0.1102)  loss_objectness: 0.0122 (0.0157)  loss_rpn_box_reg: 0.0195 (0.0222)  time: 2.1156  data: 0.1586  max mem: 19190
# Epoch: [28]  [100/250]  eta: 0:05:12  lr: 0.010000  loss: 0.2375 (0.2328)  loss_classifier: 0.0855 (0.0841)  loss_box_reg: 0.1119 (0.1113)  loss_objectness: 0.0136 (0.0151)  loss_rpn_box_reg: 0.0169 (0.0223)  time: 2.0685  data: 0.1117  max mem: 19190
# Epoch: [28]  [150/250]  eta: 0:03:27  lr: 0.010000  loss: 0.2080 (0.2285)  loss_classifier: 0.0774 (0.0821)  loss_box_reg: 0.1007 (0.1095)  loss_objectness: 0.0144 (0.0150)  loss_rpn_box_reg: 0.0176 (0.0220)  time: 2.0713  data: 0.1099  max mem: 19190
# Epoch: [28]  [200/250]  eta: 0:01:43  lr: 0.010000  loss: 0.5056 (0.2876)  loss_classifier: 0.1357 (0.0926)  loss_box_reg: 0.1041 (0.1087)  loss_objectness: 0.1398 (0.0486)  loss_rpn_box_reg: 0.0479 (0.0377)  time: 2.0691  data: 0.1091  max mem: 19190
# Epoch: [28]  [249/250]  eta: 0:00:02  lr: 0.010000  loss: 0.3854 (0.3102)  loss_classifier: 0.1540 (0.1006)  loss_box_reg: 0.1187 (0.1081)  loss_objectness: 0.0793 (0.0604)  loss_rpn_box_reg: 0.0273 (0.0411)  time: 2.0668  data: 0.1072  max mem: 19190
# Epoch: [28] Total time: 0:08:38 (2.0747 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8244 (0.8244)  evaluator_time: 0.0138 (0.0138)  time: 0.9508  data: 0.1034  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8315 (0.8103)  evaluator_time: 0.0185 (0.0236)  time: 0.9166  data: 0.0882  max mem: 19190
# Test: Total time: 0:00:29 (0.9344 s / it)
# Averaged stats: model_time: 0.8315 (0.8103)  evaluator_time: 0.0185 (0.0236)
# Accumulating evaluation results...
# DONE (t=0.30s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.074
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.032
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.055
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.123
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.140
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.165
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8230 (0.8230)  evaluator_time: 0.0418 (0.0418)  time: 0.9760  data: 0.1019  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8241 (0.7818)  evaluator_time: 0.0375 (0.0377)  time: 0.9242  data: 0.0958  max mem: 19190
# Test: Total time: 0:00:05 (0.9245 s / it)
# Averaged stats: model_time: 0.8241 (0.7818)  evaluator_time: 0.0375 (0.0377)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.039
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.119
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.007
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.044
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.042
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.055
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.123
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.140
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.165
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 29
# Epoch: [29]  [  0/250]  eta: 0:08:38  lr: 0.010000  loss: 0.5014 (0.5014)  loss_classifier: 0.2034 (0.2034)  loss_box_reg: 0.2070 (0.2070)  loss_objectness: 0.0593 (0.0593)  loss_rpn_box_reg: 0.0316 (0.0316)  time: 2.0742  data: 0.1146  max mem: 19190
# Epoch: [29]  [ 50/250]  eta: 0:07:04  lr: 0.010000  loss: 0.3125 (0.3596)  loss_classifier: 0.1283 (0.1492)  loss_box_reg: 0.1271 (0.1397)  loss_objectness: 0.0398 (0.0476)  loss_rpn_box_reg: 0.0179 (0.0231)  time: 2.1114  data: 0.1578  max mem: 19190
# Epoch: [29]  [100/250]  eta: 0:05:14  lr: 0.010000  loss: 0.2759 (0.3251)  loss_classifier: 0.1083 (0.1315)  loss_box_reg: 0.1169 (0.1309)  loss_objectness: 0.0288 (0.0394)  loss_rpn_box_reg: 0.0183 (0.0232)  time: 2.0684  data: 0.1134  max mem: 19190
# Epoch: [29]  [150/250]  eta: 0:03:28  lr: 0.010000  loss: 0.2681 (0.3080)  loss_classifier: 0.1005 (0.1222)  loss_box_reg: 0.1233 (0.1270)  loss_objectness: 0.0253 (0.0351)  loss_rpn_box_reg: 0.0197 (0.0237)  time: 2.0656  data: 0.1115  max mem: 19190
# Epoch: [29]  [200/250]  eta: 0:01:44  lr: 0.010000  loss: 0.2396 (0.2959)  loss_classifier: 0.0929 (0.1161)  loss_box_reg: 0.1118 (0.1249)  loss_objectness: 0.0178 (0.0316)  loss_rpn_box_reg: 0.0161 (0.0232)  time: 2.0633  data: 0.1082  max mem: 19190
# Epoch: [29]  [249/250]  eta: 0:00:02  lr: 0.010000  loss: 0.2235 (0.2850)  loss_classifier: 0.0804 (0.1107)  loss_box_reg: 0.1069 (0.1227)  loss_objectness: 0.0173 (0.0289)  loss_rpn_box_reg: 0.0203 (0.0227)  time: 2.0644  data: 0.1075  max mem: 19190
# Epoch: [29] Total time: 0:08:39 (2.0774 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8186 (0.8186)  evaluator_time: 0.0076 (0.0076)  time: 0.9207  data: 0.0853  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8296 (0.8084)  evaluator_time: 0.0083 (0.0090)  time: 0.9084  data: 0.0927  max mem: 19190
# Test: Total time: 0:00:30 (0.9496 s / it)
# Averaged stats: model_time: 0.8296 (0.8084)  evaluator_time: 0.0083 (0.0090)
# Accumulating evaluation results...
# DONE (t=0.08s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.045
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.113
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.065
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.055
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.124
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.078
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.158
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8227 (0.8227)  evaluator_time: 0.0151 (0.0151)  time: 0.9409  data: 0.0941  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8241 (0.7836)  evaluator_time: 0.0151 (0.0155)  time: 0.9065  data: 0.0986  max mem: 19190
# Test: Total time: 0:00:05 (0.9067 s / it)
# Averaged stats: model_time: 0.8241 (0.7836)  evaluator_time: 0.0151 (0.0155)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.062
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.162
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.083
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.055
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.124
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.078
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.158
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Training complete!

# %% [markdown]
# # Evaluation

# %%
model_tune = fasterrcnn_resnet50_fpn_v2(weights="DEFAULT")
num_classes = 4
in_features = model_tune.roi_heads.box_predictor.cls_score.in_features
model_tune.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

checkpoint_path = os.path.join(
    "/content/gdrive/My Drive/Grad School/Dissertation/Data",
    "pretrain_transform_0.001_0.001_21.pt",
)
checkpoint = torch.load(checkpoint_path)

model_tune.load_state_dict(checkpoint["model"])

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model_tune.to(device)

print(f"Model loaded successfully from {checkpoint_path}")
# Out:
# Model loaded successfully from /content/gdrive/My Drive/Grad School/Dissertation/Data/pretrain_transform_0.001_0.001_21.pt

# %%
class AerialImageryDatasetOneClass(torch.utils.data.Dataset):
    def __init__(
        self, image_dir_path, annotation_path, background_weight, label, train=False
    ):
        self.image_dir_path = image_dir_path

        self.transforms = []
        if train:
            self.transforms.append(T.RandomHorizontalFlip(p=0.5))
            self.transforms.append(T.RandomVerticalFlip(p=0.5))

        self.transforms.append(T.ToDtype(torch.float, scale=True))
        self.transforms.append(T.ToPureTensor())
        self.transforms = T.Compose(self.transforms)

        self.label_map = {"daylighting": 1, "safety_islands": 2, "curb_extensions": 3}

        with open(annotation_path) as json_file:
            self.annotations = json.load(json_file)

        self.weights = []

        for item in tqdm(self.annotations):
            curr_weight = 1
            self.weights.append(curr_weight)

        self.label = label

    def __getitem__(self, idx):
        img_path = os.path.join(
            self.image_dir_path, self.annotations[idx]["image"].split("%5C")[-1]
        )

        img = decode_image(img_path, mode="RGB")

        if img.dtype != torch.float:
            img = to_dtype(img, dtype=torch.float, scale=True)

        img = tv_tensors.Image(img)

        if "label" in self.annotations[idx]:
            boxes = [
                [i["x"], i["y"], i["width"], i["height"]]
                for i in self.annotations[idx]["label"]
                if i["rectanglelabels"][0] == self.label
            ]

            if len(boxes) == 0:
                boxes = torch.zeros((0, 4), dtype=torch.float32)
                labels = torch.zeros((0,), dtype=torch.int64)
            else:
                boxes = convert_bounding_box_format(
                    tv_tensors.BoundingBoxes(
                        boxes, format="XYWH", canvas_size=get_size(img)
                    ),
                    new_format="XYXY",
                )
                boxes = tv_tensors.BoundingBoxes(
                    boxes * 416 / 100, format="XYXY", canvas_size=get_size(img)
                )
                labels = torch.tensor(
                    [
                        self.label_map[i["rectanglelabels"][0]]
                        for i in self.annotations[idx]["label"]
                        if i["rectanglelabels"][0] == self.label
                    ]
                )

        else:
            boxes = torch.zeros((0, 4), dtype=torch.float32)
            labels = torch.zeros((0,), dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = int(
            "".join(
                self.annotations[idx]["image"].split("%5C")[-1].split(".")[0].split("_")
            )
        )
        target["area"] = torch.tensor(
            [(box[2] - box[0]) * (box[3] - box[1]) for box in boxes]
        )
        target["iscrowd"] = torch.tensor([0] * len(boxes))

        img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.annotations)

# %%
from tqdm import tqdm

image_path = os.path.join(
    "/content/gdrive/My Drive/Grad School/Dissertation/Data", "test"
)
label_path = os.path.join(
    "/content/gdrive/My Drive/Grad School/Dissertation/Data", "test.json"
)

batch_size = 16

dataset_valtest = AerialImageryDatasetOneClass(
    image_dir_path=image_path,
    annotation_path=label_path,
    background_weight=0.001,
    label="curb_extensions",
    train=False,
)


g = torch.Generator()
g.manual_seed(2025)
indices = torch.randperm(n=len(dataset_valtest), generator=g).tolist()

subset_val = Subset(
    dataset_valtest,
    indices[int(len(dataset_valtest) * 0.8) : int(len(dataset_valtest) * 0.9)],
)

data_loader_val_curb = DataLoader(
    subset_val, batch_size=batch_size, collate_fn=utils.collate_fn
)

dataset_valtest = AerialImageryDatasetOneClass(
    image_dir_path=image_path,
    annotation_path=label_path,
    background_weight=0.001,
    label="daylighting",
    train=False,
)

g = torch.Generator()
g.manual_seed(2025)
indices = torch.randperm(n=len(dataset_valtest), generator=g).tolist()

subset_val = Subset(
    dataset_valtest,
    indices[int(len(dataset_valtest) * 0.8) : int(len(dataset_valtest) * 0.9)],
)

data_loader_val_day = DataLoader(
    subset_val, batch_size=batch_size, collate_fn=utils.collate_fn
)

dataset_valtest = AerialImageryDatasetOneClass(
    image_dir_path=image_path,
    annotation_path=label_path,
    background_weight=0.001,
    label="safety_islands",
    train=False,
)

g = torch.Generator()
g.manual_seed(2025)
indices = torch.randperm(n=len(dataset_valtest), generator=g).tolist()

subset_val = Subset(
    dataset_valtest,
    indices[int(len(dataset_valtest) * 0.8) : int(len(dataset_valtest) * 0.9)],
)

data_loader_val_island = DataLoader(
    subset_val, batch_size=batch_size, collate_fn=utils.collate_fn
)

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
# Out:
# 100%|██████████| 5000/5000 [00:00<00:00, 4317792.88it/s]
# 100%|██████████| 5000/5000 [00:00<00:00, 4184261.77it/s]
# 100%|██████████| 5000/5000 [00:00<00:00, 4104818.95it/s]

# %%
evaluate(model_tune, data_loader_val_curb, device=device)
# Out:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:01:14  model_time: 2.2217 (2.2217)  evaluator_time: 0.0066 (0.0066)  time: 2.3230  data: 0.0857  max mem: 5477
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8319 (0.8561)  evaluator_time: 0.0027 (0.0029)  time: 0.9164  data: 0.1039  max mem: 5486
# Test: Total time: 0:00:31 (0.9690 s / it)
# Averaged stats: model_time: 0.8319 (0.8561)  evaluator_time: 0.0027 (0.0029)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.015
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000

# %%
evaluate(model_tune, data_loader_val_day, device=device)
# Out:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8179 (0.8179)  evaluator_time: 0.0028 (0.0028)  time: 0.9130  data: 0.0834  max mem: 5486
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8261 (0.8045)  evaluator_time: 0.0031 (0.0032)  time: 0.8958  data: 0.0889  max mem: 5486
# Test: Total time: 0:00:29 (0.9069 s / it)
# Averaged stats: model_time: 0.8261 (0.8045)  evaluator_time: 0.0031 (0.0032)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.069
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.032
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.075
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.096
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.096
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.018
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.145
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000

# %%
evaluate(model_tune, data_loader_val_island, device=device)
# Out:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8221 (0.8221)  evaluator_time: 0.0027 (0.0027)  time: 0.9205  data: 0.0866  max mem: 5486
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8328 (0.8099)  evaluator_time: 0.0033 (0.0033)  time: 0.9024  data: 0.0895  max mem: 5486
# Test: Total time: 0:00:29 (0.9132 s / it)
# Averaged stats: model_time: 0.8328 (0.8099)  evaluator_time: 0.0033 (0.0033)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.352
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.653
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.316
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.258
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.419
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.256
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.449
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.449
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.343
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.511
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
