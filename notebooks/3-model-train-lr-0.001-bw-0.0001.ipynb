# %% [markdown]
# # Setup

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py")
os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py")
os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py")
os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py")
os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py")
# Out:
# 0

# %%
import torch
from torch.utils.data import Subset, DataLoader

from torchvision import tv_tensors
from torchvision.io import decode_image

from torchvision.transforms import v2 as T
from torchvision.transforms.v2.functional import to_dtype, get_size, convert_bounding_box_format

from torchvision.models.detection import fasterrcnn_resnet50_fpn_v2
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

import pandas as pd
import numpy as np

import os
import json

import math
import sys

import utils
from engine import train_one_epoch, evaluate

# %% [markdown]
# # Data

# %%
class AerialImageryDataset(torch.utils.data.Dataset):
    def __init__(self, image_dir_path, annotation_path, background_weight, train=False):
        self.image_dir_path = image_dir_path

        self.transforms = []
        if train:
            self.transforms.append(T.RandomHorizontalFlip(p=0.5))
            self.transforms.append(T.RandomVerticalFlip(p=0.5))

        self.transforms.append(T.ToDtype(torch.float, scale=True))
        self.transforms.append(T.ToPureTensor())
        self.transforms = T.Compose(self.transforms)

        self.label_map = {"daylighting": 1,
                          "safety_islands": 2,
                          "curb_extensions": 3}

        with open(annotation_path) as json_file:
            self.annotations = json.load(json_file)

        self.weights = []

        for item in tqdm(self.annotations):
            curr_weight = 1

            if "label" in item:
                for label in item["label"]:
                    if label["rectanglelabels"][0] == "curb_extensions":
                        curr_weight = 3
                        break
            else:
                curr_weight = background_weight

            self.weights.append(curr_weight)

    def __getitem__(self, idx):
        img_path = os.path.join(
            self.image_dir_path,
            self.annotations[idx]["image"].split("%5C")[-1])

        img = decode_image(img_path, mode="RGB")

        if img.dtype != torch.float:
            img = to_dtype(img, dtype=torch.float, scale=True)

        img = tv_tensors.Image(img)

        if "label" in self.annotations[idx]:
            boxes = [[
                i["x"],
                i["y"],
                i["width"],
                i["height"]] for i in self.annotations[idx]["label"]]

            boxes = convert_bounding_box_format(tv_tensors.BoundingBoxes(boxes, format="XYWH", canvas_size=get_size(img)), new_format="XYXY")
            boxes = tv_tensors.BoundingBoxes(boxes * 416 / 100, format="XYXY", canvas_size=get_size(img))
            labels = torch.tensor([self.label_map[i["rectanglelabels"][0]] for i in self.annotations[idx]["label"]])

        else:
            boxes = torch.zeros((0, 4), dtype=torch.float32)
            labels = torch.zeros((0,), dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = int("".join(self.annotations[idx]["image"].split("%5C")[-1].split(".")[0].split("_")))
        target["area"] = torch.tensor([(box[2] - box[0]) * (box[3] - box[1]) for box in boxes])
        target["iscrowd"] = torch.tensor([0] * len(boxes))

        img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.annotations)

# %%
from tqdm import tqdm

image_path = os.path.join("/content/gdrive/My Drive/Grad School/Dissertation/Data", "test")
label_path = os.path.join("/content/gdrive/My Drive/Grad School/Dissertation/Data", "test.json")

batch_size = 16

dataset_train = AerialImageryDataset(
    image_dir_path=image_path,
    annotation_path=label_path,
    background_weight=0.0001,
    train=True)
dataset_valtest = AerialImageryDataset(
    image_dir_path=image_path,
    annotation_path=label_path,
    background_weight=0.0001,
    train=False)


g = torch.Generator()
g.manual_seed(2025)
indices = torch.randperm(n=len(dataset_train), generator=g).tolist()

subset_train = Subset(dataset_train, indices[:int(len(dataset_train) * 0.8)])
subset_val = Subset(dataset_valtest, indices[int(len(dataset_valtest) * 0.8):int(len(dataset_valtest) * 0.9)])
subset_test = Subset(dataset_valtest, indices[int(len(dataset_valtest) * 0.9):])

train_weights = [dataset_train.weights[idx] for idx in indices[:int(len(dataset_train) * 0.8)]]

data_loader_train = DataLoader(
    subset_train,
    batch_size=batch_size,
    sampler=torch.utils.data.WeightedRandomSampler(train_weights, len(train_weights)),
    collate_fn=utils.collate_fn
)
data_loader_val = DataLoader(
    subset_val,
    batch_size=batch_size,
    collate_fn=utils.collate_fn
)

data_loader_test = DataLoader(
    subset_test,
    batch_size=batch_size,
    collate_fn=utils.collate_fn
)

annotated_indices = []
unannotated_indices = []

for i in subset_val.indices:
    if "label" in subset_val.dataset.annotations[i]:
        annotated_indices.append(i)
    else:
        unannotated_indices.append(i)

subset_val_annotated = Subset(dataset_valtest, annotated_indices)
subset_val_unannotated = Subset(dataset_valtest, unannotated_indices)

data_loader_val_annotated = DataLoader(
    subset_val_annotated,
    batch_size=batch_size,
    collate_fn=utils.collate_fn
)

data_loader_val_unannotated = DataLoader(
    subset_val_unannotated,
    batch_size=batch_size,
    collate_fn=utils.collate_fn
)
# Out:
# 100%|██████████| 5000/5000 [00:00<00:00, 3145098.98it/s]
# 100%|██████████| 5000/5000 [00:00<00:00, 3203225.90it/s]

# %% [markdown]
# # Training

# %%
def train_one_epoch_no_schedule(model, optimizer, data_loader, device, epoch, print_freq):
    model.train()
    metric_logger = utils.MetricLogger(delimiter="  ")
    metric_logger.add_meter("lr", utils.SmoothedValue(window_size=1, fmt="{value:.6f}"))
    header = f"Epoch: [{epoch}]"

    for images, targets in metric_logger.log_every(data_loader, print_freq, header):
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) if isinstance(v, torch.Tensor) else v for k, v in t.items()} for t in targets]

        with torch.amp.autocast('cuda', enabled=False):
            loss_dict = model(images, targets)
            losses = sum(loss for loss in loss_dict.values())

        # reduce losses over all GPUs for logging purposes
        loss_dict_reduced = utils.reduce_dict(loss_dict)
        losses_reduced = sum(loss for loss in loss_dict_reduced.values())

        loss_value = losses_reduced.item()

        if not math.isfinite(loss_value):
            print(f"Loss is {loss_value}, stopping training")
            print(loss_dict_reduced)
            sys.exit(1)

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        metric_logger.update(loss=losses_reduced, **loss_dict_reduced)
        metric_logger.update(lr=optimizer.param_groups[0]["lr"])

    return metric_logger

# %%
def training(model, optimizer, num_epochs, lr, save_loc, starting_epoch=0,):
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

    model.to(device)

    for epoch in range(starting_epoch, starting_epoch + num_epochs):
        print("EPOCH " + str(epoch))
        train_one_epoch_no_schedule(model, optimizer, data_loader_train, device, epoch, print_freq=50)
        # evaluate(model_tune, data_loader_train, device=device)
        print("VALIDATION EVALUATION:")
        evaluate(model_tune, data_loader_val, device=device)
        print("VALIDATION ANNOTATED EVALUATION:")
        evaluate(model_tune, data_loader_val_annotated, device=device)

        save_path = save_loc + "_" + str(lr) + "_" + str(epoch) + ".pt"
        save_path = os.path.join("/content/gdrive/My Drive/Grad School/Dissertation/Data", save_path)

        checkpoint = {
            'epoch': epoch,
            'model': model.state_dict(),
            'optimizer': optimizer.state_dict(),}
        torch.save(checkpoint, save_path)

    print("Training complete!")

# %% [markdown]
# # Experiments

# %% [markdown]
# ## Experiment 1: Fine-tuning

# %%
lr = 0.001
model_tune = fasterrcnn_resnet50_fpn_v2(
    weights="DEFAULT",
    # image_mean=[0.4715, 0.4723, 0.4587],
    # image_std=[0.2071, 0.1955, 0.1825]
    )

# replace the pre-trained head with a new one
num_classes = 4
in_features = model_tune.roi_heads.box_predictor.cls_score.in_features
model_tune.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

params = [p for p in model_tune.parameters() if p.requires_grad]
optimizer = torch.optim.Adam(
    params,
    lr=lr,
)

training(model=model_tune, optimizer=optimizer, num_epochs=30, lr=lr, save_loc="pretrain_transform_0.0001", starting_epoch=0)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth
# 100%|██████████| 167M/167M [00:00<00:00, 227MB/s]
# EPOCH 0
# Epoch: [0]  [  0/250]  eta: 2:16:28  lr: 0.001000  loss: 2.0890 (2.0890)  loss_classifier: 1.7199 (1.7199)  loss_box_reg: 0.0246 (0.0246)  loss_objectness: 0.3301 (0.3301)  loss_rpn_box_reg: 0.0144 (0.0144)  time: 32.7558  data: 28.4001  max mem: 18863
# Epoch: [0]  [ 50/250]  eta: 0:21:35  lr: 0.001000  loss: 0.4248 (0.4893)  loss_classifier: 0.1681 (0.2225)  loss_box_reg: 0.0984 (0.1104)  loss_objectness: 0.1022 (0.1325)  loss_rpn_box_reg: 0.0158 (0.0239)  time: 4.4388  data: 2.4378  max mem: 19190
# Epoch: [0]  [100/250]  eta: 0:12:29  lr: 0.001000  loss: 0.4977 (0.4925)  loss_classifier: 0.2040 (0.2172)  loss_box_reg: 0.1585 (0.1360)  loss_objectness: 0.0927 (0.1165)  loss_rpn_box_reg: 0.0160 (0.0228)  time: 3.0908  data: 1.0953  max mem: 19190
# Epoch: [0]  [150/250]  eta: 0:07:06  lr: 0.001000  loss: 0.5163 (0.5029)  loss_classifier: 0.2210 (0.2177)  loss_box_reg: 0.2078 (0.1543)  loss_objectness: 0.0878 (0.1085)  loss_rpn_box_reg: 0.0155 (0.0225)  time: 2.6590  data: 0.6649  max mem: 19190
# Epoch: [0]  [200/250]  eta: 0:03:10  lr: 0.001000  loss: 0.4688 (0.5032)  loss_classifier: 0.1930 (0.2160)  loss_box_reg: 0.1754 (0.1613)  loss_objectness: 0.0783 (0.1033)  loss_rpn_box_reg: 0.0189 (0.0226)  time: 2.2614  data: 0.2700  max mem: 19190
# Epoch: [0]  [249/250]  eta: 0:00:03  lr: 0.001000  loss: 0.4678 (0.5020)  loss_classifier: 0.2034 (0.2156)  loss_box_reg: 0.1910 (0.1680)  loss_objectness: 0.0556 (0.0967)  loss_rpn_box_reg: 0.0146 (0.0218)  time: 2.3313  data: 0.3368  max mem: 19190
# Epoch: [0] Total time: 0:14:39 (3.5184 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8457 (0.8457)  evaluator_time: 0.0162 (0.0162)  time: 0.9667  data: 0.0955  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8417 (0.8224)  evaluator_time: 0.0085 (0.0092)  time: 0.9186  data: 0.0905  max mem: 19190
# Test: Total time: 0:00:29 (0.9351 s / it)
# Averaged stats: model_time: 0.8417 (0.8224)  evaluator_time: 0.0085 (0.0092)
# Accumulating evaluation results...
# DONE (t=0.11s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.048
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.119
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.030
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.031
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.060
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.145
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.159
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.121
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.189
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.044
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8312 (0.8312)  evaluator_time: 0.0212 (0.0212)  time: 0.9645  data: 0.1030  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8312 (0.7892)  evaluator_time: 0.0208 (0.0194)  time: 0.9133  data: 0.0958  max mem: 19190
# Test: Total time: 0:00:05 (0.9135 s / it)
# Averaged stats: model_time: 0.8312 (0.7892)  evaluator_time: 0.0208 (0.0194)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.147
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.073
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.145
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.159
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.121
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.189
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.044
# EPOCH 1
# Epoch: [1]  [  0/250]  eta: 0:08:50  lr: 0.001000  loss: 0.5445 (0.5445)  loss_classifier: 0.2403 (0.2403)  loss_box_reg: 0.2182 (0.2182)  loss_objectness: 0.0670 (0.0670)  loss_rpn_box_reg: 0.0191 (0.0191)  time: 2.1204  data: 0.1312  max mem: 19190
# Epoch: [1]  [ 50/250]  eta: 0:07:07  lr: 0.001000  loss: 0.5093 (0.4918)  loss_classifier: 0.2217 (0.2150)  loss_box_reg: 0.2170 (0.1974)  loss_objectness: 0.0605 (0.0627)  loss_rpn_box_reg: 0.0146 (0.0167)  time: 2.0953  data: 0.1090  max mem: 19190
# Epoch: [1]  [100/250]  eta: 0:05:17  lr: 0.001000  loss: 0.4496 (0.4919)  loss_classifier: 0.1963 (0.2149)  loss_box_reg: 0.1826 (0.1985)  loss_objectness: 0.0493 (0.0616)  loss_rpn_box_reg: 0.0130 (0.0169)  time: 2.0993  data: 0.1061  max mem: 19190
# Epoch: [1]  [150/250]  eta: 0:03:31  lr: 0.001000  loss: 0.5128 (0.5024)  loss_classifier: 0.2218 (0.2199)  loss_box_reg: 0.2137 (0.2044)  loss_objectness: 0.0494 (0.0606)  loss_rpn_box_reg: 0.0144 (0.0175)  time: 2.1004  data: 0.1103  max mem: 19190
# Epoch: [1]  [200/250]  eta: 0:01:45  lr: 0.001000  loss: 0.4655 (0.5009)  loss_classifier: 0.2086 (0.2194)  loss_box_reg: 0.2016 (0.2048)  loss_objectness: 0.0483 (0.0594)  loss_rpn_box_reg: 0.0133 (0.0173)  time: 2.0953  data: 0.1066  max mem: 19190
# Epoch: [1]  [249/250]  eta: 0:00:02  lr: 0.001000  loss: 0.5220 (0.5055)  loss_classifier: 0.2295 (0.2220)  loss_box_reg: 0.2277 (0.2096)  loss_objectness: 0.0411 (0.0566)  loss_rpn_box_reg: 0.0148 (0.0173)  time: 2.0974  data: 0.1093  max mem: 19190
# Epoch: [1] Total time: 0:08:46 (2.1065 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8329 (0.8329)  evaluator_time: 0.0091 (0.0091)  time: 0.9520  data: 0.1008  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8406 (0.8194)  evaluator_time: 0.0118 (0.0164)  time: 0.9186  data: 0.0886  max mem: 19190
# Test: Total time: 0:00:29 (0.9357 s / it)
# Averaged stats: model_time: 0.8406 (0.8194)  evaluator_time: 0.0118 (0.0164)
# Accumulating evaluation results...
# DONE (t=0.16s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.069
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.163
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.045
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.063
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.082
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.189
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.210
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.243
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.022
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8324 (0.8324)  evaluator_time: 0.0226 (0.0226)  time: 0.9674  data: 0.1035  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8343 (0.7926)  evaluator_time: 0.0226 (0.0229)  time: 0.9208  data: 0.0965  max mem: 19190
# Test: Total time: 0:00:05 (0.9210 s / it)
# Averaged stats: model_time: 0.8343 (0.7926)  evaluator_time: 0.0226 (0.0229)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.210
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.060
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.070
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.102
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.189
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.210
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.243
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.022
# EPOCH 2
# Epoch: [2]  [  0/250]  eta: 0:08:42  lr: 0.001000  loss: 0.5637 (0.5637)  loss_classifier: 0.2587 (0.2587)  loss_box_reg: 0.2447 (0.2447)  loss_objectness: 0.0447 (0.0447)  loss_rpn_box_reg: 0.0157 (0.0157)  time: 2.0920  data: 0.1063  max mem: 19190
# Epoch: [2]  [ 50/250]  eta: 0:07:02  lr: 0.001000  loss: 0.5024 (0.5122)  loss_classifier: 0.2235 (0.2266)  loss_box_reg: 0.2277 (0.2201)  loss_objectness: 0.0431 (0.0486)  loss_rpn_box_reg: 0.0130 (0.0170)  time: 2.0944  data: 0.1088  max mem: 19190
# Epoch: [2]  [100/250]  eta: 0:05:15  lr: 0.001000  loss: 0.4552 (0.5019)  loss_classifier: 0.2007 (0.2228)  loss_box_reg: 0.2161 (0.2189)  loss_objectness: 0.0335 (0.0446)  loss_rpn_box_reg: 0.0127 (0.0156)  time: 2.0972  data: 0.1092  max mem: 19190
# Epoch: [2]  [150/250]  eta: 0:03:30  lr: 0.001000  loss: 0.4626 (0.4964)  loss_classifier: 0.2026 (0.2180)  loss_box_reg: 0.2104 (0.2182)  loss_objectness: 0.0343 (0.0438)  loss_rpn_box_reg: 0.0120 (0.0163)  time: 2.0933  data: 0.1061  max mem: 19190
# Epoch: [2]  [200/250]  eta: 0:01:45  lr: 0.001000  loss: 0.4575 (0.4945)  loss_classifier: 0.1913 (0.2157)  loss_box_reg: 0.2148 (0.2197)  loss_objectness: 0.0363 (0.0426)  loss_rpn_box_reg: 0.0125 (0.0165)  time: 2.0973  data: 0.1084  max mem: 19190
# Epoch: [2]  [249/250]  eta: 0:00:02  lr: 0.001000  loss: 0.4468 (0.4867)  loss_classifier: 0.1862 (0.2106)  loss_box_reg: 0.2215 (0.2192)  loss_objectness: 0.0291 (0.0403)  loss_rpn_box_reg: 0.0123 (0.0165)  time: 2.1014  data: 0.1089  max mem: 19190
# Epoch: [2] Total time: 0:08:45 (2.1018 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8322 (0.8322)  evaluator_time: 0.0094 (0.0094)  time: 0.9388  data: 0.0880  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8419 (0.8191)  evaluator_time: 0.0149 (0.0187)  time: 0.9319  data: 0.0917  max mem: 19190
# Test: Total time: 0:00:30 (0.9399 s / it)
# Averaged stats: model_time: 0.8419 (0.8191)  evaluator_time: 0.0149 (0.0187)
# Accumulating evaluation results...
# DONE (t=0.19s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.080
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.188
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.052
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.048
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.104
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.080
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.194
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.223
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.185
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.253
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.067
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8344 (0.8344)  evaluator_time: 0.0335 (0.0335)  time: 0.9647  data: 0.0877  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8335 (0.7910)  evaluator_time: 0.0304 (0.0312)  time: 0.9224  data: 0.0913  max mem: 19190
# Test: Total time: 0:00:05 (0.9227 s / it)
# Averaged stats: model_time: 0.8335 (0.7910)  evaluator_time: 0.0304 (0.0312)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.217
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.061
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.116
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.080
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.194
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.223
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.185
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.253
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.067
# EPOCH 3
# Epoch: [3]  [  0/250]  eta: 0:11:10  lr: 0.001000  loss: 0.4420 (0.4420)  loss_classifier: 0.1781 (0.1781)  loss_box_reg: 0.2168 (0.2168)  loss_objectness: 0.0332 (0.0332)  loss_rpn_box_reg: 0.0139 (0.0139)  time: 2.6810  data: 0.6836  max mem: 19190
# Epoch: [3]  [ 50/250]  eta: 0:07:04  lr: 0.001000  loss: 0.4380 (0.4627)  loss_classifier: 0.1781 (0.1948)  loss_box_reg: 0.2048 (0.2186)  loss_objectness: 0.0330 (0.0346)  loss_rpn_box_reg: 0.0123 (0.0148)  time: 2.0965  data: 0.1093  max mem: 19190
# Epoch: [3]  [100/250]  eta: 0:05:16  lr: 0.001000  loss: 0.4308 (0.4564)  loss_classifier: 0.1843 (0.1921)  loss_box_reg: 0.2019 (0.2189)  loss_objectness: 0.0254 (0.0314)  loss_rpn_box_reg: 0.0114 (0.0139)  time: 2.1024  data: 0.1124  max mem: 19190
# Epoch: [3]  [150/250]  eta: 0:03:30  lr: 0.001000  loss: 0.4728 (0.4587)  loss_classifier: 0.1760 (0.1916)  loss_box_reg: 0.2285 (0.2215)  loss_objectness: 0.0243 (0.0307)  loss_rpn_box_reg: 0.0124 (0.0148)  time: 2.0966  data: 0.1084  max mem: 19190
# Epoch: [3]  [200/250]  eta: 0:01:45  lr: 0.001000  loss: 0.4319 (0.4598)  loss_classifier: 0.1830 (0.1910)  loss_box_reg: 0.2239 (0.2238)  loss_objectness: 0.0224 (0.0300)  loss_rpn_box_reg: 0.0120 (0.0150)  time: 2.0999  data: 0.1123  max mem: 19190
# Epoch: [3]  [249/250]  eta: 0:00:02  lr: 0.001000  loss: 0.4166 (0.4538)  loss_classifier: 0.1641 (0.1879)  loss_box_reg: 0.1971 (0.2219)  loss_objectness: 0.0196 (0.0292)  loss_rpn_box_reg: 0.0104 (0.0148)  time: 2.1022  data: 0.1093  max mem: 19190
# Epoch: [3] Total time: 0:08:45 (2.1038 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8352 (0.8352)  evaluator_time: 0.0098 (0.0098)  time: 0.9445  data: 0.0903  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8426 (0.8189)  evaluator_time: 0.0136 (0.0124)  time: 0.9214  data: 0.0910  max mem: 19190
# Test: Total time: 0:00:29 (0.9321 s / it)
# Averaged stats: model_time: 0.8426 (0.8189)  evaluator_time: 0.0136 (0.0124)
# Accumulating evaluation results...
# DONE (t=0.16s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.074
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.174
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.043
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.042
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.094
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.102
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.213
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.225
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.138
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.259
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8309 (0.8309)  evaluator_time: 0.0266 (0.0266)  time: 0.9719  data: 0.1052  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8315 (0.7896)  evaluator_time: 0.0246 (0.0253)  time: 0.9208  data: 0.0971  max mem: 19190
# Test: Total time: 0:00:05 (0.9210 s / it)
# Averaged stats: model_time: 0.8315 (0.7896)  evaluator_time: 0.0246 (0.0253)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.098
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.242
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.052
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.053
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.122
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.102
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.213
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.225
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.138
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.259
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 4
# Epoch: [4]  [  0/250]  eta: 0:08:42  lr: 0.001000  loss: 0.4492 (0.4492)  loss_classifier: 0.1899 (0.1899)  loss_box_reg: 0.2223 (0.2223)  loss_objectness: 0.0258 (0.0258)  loss_rpn_box_reg: 0.0111 (0.0111)  time: 2.0897  data: 0.1000  max mem: 19190
# Epoch: [4]  [ 50/250]  eta: 0:07:02  lr: 0.001000  loss: 0.4149 (0.4374)  loss_classifier: 0.1684 (0.1770)  loss_box_reg: 0.2170 (0.2278)  loss_objectness: 0.0177 (0.0206)  loss_rpn_box_reg: 0.0111 (0.0121)  time: 2.1008  data: 0.1138  max mem: 19190
# Epoch: [4]  [100/250]  eta: 0:05:15  lr: 0.001000  loss: 0.4193 (0.4309)  loss_classifier: 0.1638 (0.1721)  loss_box_reg: 0.2230 (0.2260)  loss_objectness: 0.0190 (0.0204)  loss_rpn_box_reg: 0.0101 (0.0125)  time: 2.0912  data: 0.1083  max mem: 19190
# Epoch: [4]  [150/250]  eta: 0:03:30  lr: 0.001000  loss: 0.3410 (0.4141)  loss_classifier: 0.1322 (0.1644)  loss_box_reg: 0.1825 (0.2167)  loss_objectness: 0.0171 (0.0200)  loss_rpn_box_reg: 0.0092 (0.0130)  time: 2.0933  data: 0.1084  max mem: 19190
# Epoch: [4]  [200/250]  eta: 0:01:44  lr: 0.001000  loss: 0.4074 (0.4092)  loss_classifier: 0.1447 (0.1610)  loss_box_reg: 0.2244 (0.2146)  loss_objectness: 0.0172 (0.0198)  loss_rpn_box_reg: 0.0130 (0.0138)  time: 2.0981  data: 0.1099  max mem: 19190
# Epoch: [4]  [249/250]  eta: 0:00:02  lr: 0.001000  loss: 0.3848 (0.4014)  loss_classifier: 0.1361 (0.1566)  loss_box_reg: 0.2025 (0.2114)  loss_objectness: 0.0149 (0.0192)  loss_rpn_box_reg: 0.0109 (0.0142)  time: 2.1000  data: 0.1094  max mem: 19190
# Epoch: [4] Total time: 0:08:44 (2.0992 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8321 (0.8321)  evaluator_time: 0.0100 (0.0100)  time: 0.9515  data: 0.1002  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8411 (0.8193)  evaluator_time: 0.0116 (0.0115)  time: 0.9214  data: 0.0917  max mem: 19190
# Test: Total time: 0:00:29 (0.9328 s / it)
# Averaged stats: model_time: 0.8411 (0.8193)  evaluator_time: 0.0116 (0.0115)
# Accumulating evaluation results...
# DONE (t=0.14s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.093
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.203
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.070
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.060
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.114
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.094
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.232
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.124
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.278
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8290 (0.8290)  evaluator_time: 0.0235 (0.0235)  time: 0.9487  data: 0.0870  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8342 (0.7904)  evaluator_time: 0.0223 (0.0216)  time: 0.9158  data: 0.0949  max mem: 19190
# Test: Total time: 0:00:05 (0.9160 s / it)
# Averaged stats: model_time: 0.8342 (0.7904)  evaluator_time: 0.0223 (0.0216)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.112
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.259
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.078
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.072
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.137
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.094
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.232
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.124
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.278
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 5
# Epoch: [5]  [  0/250]  eta: 0:08:46  lr: 0.001000  loss: 0.3657 (0.3657)  loss_classifier: 0.1548 (0.1548)  loss_box_reg: 0.1927 (0.1927)  loss_objectness: 0.0099 (0.0099)  loss_rpn_box_reg: 0.0083 (0.0083)  time: 2.1072  data: 0.1092  max mem: 19190
# Epoch: [5]  [ 50/250]  eta: 0:07:06  lr: 0.001000  loss: 0.3964 (0.3774)  loss_classifier: 0.1401 (0.1426)  loss_box_reg: 0.2192 (0.2086)  loss_objectness: 0.0128 (0.0144)  loss_rpn_box_reg: 0.0103 (0.0118)  time: 2.0998  data: 0.1103  max mem: 19190
# Epoch: [5]  [100/250]  eta: 0:05:17  lr: 0.001000  loss: 0.3595 (0.3675)  loss_classifier: 0.1354 (0.1397)  loss_box_reg: 0.1913 (0.2017)  loss_objectness: 0.0123 (0.0144)  loss_rpn_box_reg: 0.0101 (0.0117)  time: 2.1034  data: 0.1116  max mem: 19190
# Epoch: [5]  [150/250]  eta: 0:03:31  lr: 0.001000  loss: 0.3316 (0.3663)  loss_classifier: 0.1202 (0.1381)  loss_box_reg: 0.1855 (0.2019)  loss_objectness: 0.0118 (0.0145)  loss_rpn_box_reg: 0.0099 (0.0118)  time: 2.1013  data: 0.1090  max mem: 19190
# Epoch: [5]  [200/250]  eta: 0:01:45  lr: 0.001000  loss: 0.3130 (0.3584)  loss_classifier: 0.1117 (0.1336)  loss_box_reg: 0.1797 (0.1986)  loss_objectness: 0.0096 (0.0141)  loss_rpn_box_reg: 0.0086 (0.0121)  time: 2.0981  data: 0.1068  max mem: 19190
# Epoch: [5]  [249/250]  eta: 0:00:02  lr: 0.001000  loss: 0.3180 (0.3541)  loss_classifier: 0.1125 (0.1316)  loss_box_reg: 0.1684 (0.1968)  loss_objectness: 0.0091 (0.0136)  loss_rpn_box_reg: 0.0087 (0.0121)  time: 2.1054  data: 0.1112  max mem: 19190
# Epoch: [5] Total time: 0:08:47 (2.1082 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8342 (0.8342)  evaluator_time: 0.0082 (0.0082)  time: 0.9600  data: 0.1083  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8423 (0.8196)  evaluator_time: 0.0095 (0.0093)  time: 0.9186  data: 0.0904  max mem: 19190
# Test: Total time: 0:00:29 (0.9302 s / it)
# Averaged stats: model_time: 0.8423 (0.8196)  evaluator_time: 0.0095 (0.0093)
# Accumulating evaluation results...
# DONE (t=0.10s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.081
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.168
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.073
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.048
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.104
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.117
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.223
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.256
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.033
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8286 (0.8286)  evaluator_time: 0.0174 (0.0174)  time: 0.9605  data: 0.1053  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8333 (0.7918)  evaluator_time: 0.0168 (0.0174)  time: 0.9143  data: 0.0963  max mem: 19190
# Test: Total time: 0:00:05 (0.9148 s / it)
# Averaged stats: model_time: 0.8333 (0.7918)  evaluator_time: 0.0168 (0.0174)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.112
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.239
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.094
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.143
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.117
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.223
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.256
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.033
# EPOCH 6
# Epoch: [6]  [  0/250]  eta: 0:08:49  lr: 0.001000  loss: 0.4028 (0.4028)  loss_classifier: 0.1526 (0.1526)  loss_box_reg: 0.2191 (0.2191)  loss_objectness: 0.0198 (0.0198)  loss_rpn_box_reg: 0.0113 (0.0113)  time: 2.1190  data: 0.1196  max mem: 19190
# Epoch: [6]  [ 50/250]  eta: 0:07:05  lr: 0.001000  loss: 0.3251 (0.3277)  loss_classifier: 0.1121 (0.1212)  loss_box_reg: 0.1694 (0.1827)  loss_objectness: 0.0103 (0.0115)  loss_rpn_box_reg: 0.0095 (0.0122)  time: 2.0934  data: 0.1086  max mem: 19190
# Epoch: [6]  [100/250]  eta: 0:05:16  lr: 0.001000  loss: 0.2904 (0.3164)  loss_classifier: 0.0978 (0.1159)  loss_box_reg: 0.1632 (0.1790)  loss_objectness: 0.0084 (0.0105)  loss_rpn_box_reg: 0.0099 (0.0110)  time: 2.0953  data: 0.1078  max mem: 19190
# Epoch: [6]  [150/250]  eta: 0:03:30  lr: 0.001000  loss: 0.2748 (0.3115)  loss_classifier: 0.0954 (0.1125)  loss_box_reg: 0.1616 (0.1762)  loss_objectness: 0.0091 (0.0115)  loss_rpn_box_reg: 0.0084 (0.0114)  time: 2.0963  data: 0.1100  max mem: 19190
# Epoch: [6]  [200/250]  eta: 0:01:45  lr: 0.001000  loss: 0.2826 (0.3018)  loss_classifier: 0.0892 (0.1076)  loss_box_reg: 0.1639 (0.1727)  loss_objectness: 0.0062 (0.0104)  loss_rpn_box_reg: 0.0094 (0.0111)  time: 2.0973  data: 0.1116  max mem: 19190
# Epoch: [6]  [249/250]  eta: 0:00:02  lr: 0.001000  loss: 0.2754 (0.2950)  loss_classifier: 0.0929 (0.1042)  loss_box_reg: 0.1653 (0.1701)  loss_objectness: 0.0075 (0.0099)  loss_rpn_box_reg: 0.0078 (0.0108)  time: 2.0936  data: 0.1092  max mem: 19190
# Epoch: [6] Total time: 0:08:45 (2.1032 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8280 (0.8280)  evaluator_time: 0.0086 (0.0086)  time: 0.9342  data: 0.0881  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8389 (0.8170)  evaluator_time: 0.0097 (0.0142)  time: 0.9242  data: 0.0911  max mem: 19190
# Test: Total time: 0:00:29 (0.9325 s / it)
# Averaged stats: model_time: 0.8389 (0.8170)  evaluator_time: 0.0097 (0.0142)
# Accumulating evaluation results...
# DONE (t=0.10s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.087
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.178
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.072
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.049
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.112
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.110
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.208
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.213
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.130
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.252
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8308 (0.8308)  evaluator_time: 0.0183 (0.0183)  time: 0.9544  data: 0.0961  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8342 (0.7901)  evaluator_time: 0.0168 (0.0175)  time: 0.9147  data: 0.0984  max mem: 19190
# Test: Total time: 0:00:05 (0.9150 s / it)
# Averaged stats: model_time: 0.8342 (0.7901)  evaluator_time: 0.0168 (0.0175)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.238
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.064
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.139
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.110
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.208
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.213
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.130
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.252
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 7
# Epoch: [7]  [  0/250]  eta: 0:10:53  lr: 0.001000  loss: 0.2820 (0.2820)  loss_classifier: 0.1004 (0.1004)  loss_box_reg: 0.1687 (0.1687)  loss_objectness: 0.0070 (0.0070)  loss_rpn_box_reg: 0.0059 (0.0059)  time: 2.6150  data: 0.6234  max mem: 19190
# Epoch: [7]  [ 50/250]  eta: 0:07:02  lr: 0.001000  loss: 0.2381 (0.2503)  loss_classifier: 0.0850 (0.0843)  loss_box_reg: 0.1439 (0.1516)  loss_objectness: 0.0058 (0.0064)  loss_rpn_box_reg: 0.0071 (0.0080)  time: 2.0943  data: 0.1067  max mem: 19190
# Epoch: [7]  [100/250]  eta: 0:05:15  lr: 0.001000  loss: 0.2531 (0.2525)  loss_classifier: 0.0811 (0.0834)  loss_box_reg: 0.1544 (0.1527)  loss_objectness: 0.0061 (0.0067)  loss_rpn_box_reg: 0.0078 (0.0098)  time: 2.0990  data: 0.1101  max mem: 19190
# Epoch: [7]  [150/250]  eta: 0:03:30  lr: 0.001000  loss: 0.2461 (0.2490)  loss_classifier: 0.0869 (0.0828)  loss_box_reg: 0.1409 (0.1494)  loss_objectness: 0.0058 (0.0067)  loss_rpn_box_reg: 0.0086 (0.0100)  time: 2.0972  data: 0.1081  max mem: 19190
# Epoch: [7]  [200/250]  eta: 0:01:45  lr: 0.001000  loss: 0.2359 (0.2499)  loss_classifier: 0.0758 (0.0829)  loss_box_reg: 0.1458 (0.1494)  loss_objectness: 0.0057 (0.0068)  loss_rpn_box_reg: 0.0075 (0.0108)  time: 2.0967  data: 0.1091  max mem: 19190
# Epoch: [7]  [249/250]  eta: 0:00:02  lr: 0.001000  loss: 0.2547 (0.2500)  loss_classifier: 0.0887 (0.0831)  loss_box_reg: 0.1533 (0.1496)  loss_objectness: 0.0055 (0.0065)  loss_rpn_box_reg: 0.0077 (0.0108)  time: 2.0957  data: 0.1073  max mem: 19190
# Epoch: [7] Total time: 0:08:45 (2.1009 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8339 (0.8339)  evaluator_time: 0.0070 (0.0070)  time: 0.9508  data: 0.1008  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8404 (0.8189)  evaluator_time: 0.0083 (0.0080)  time: 0.9171  data: 0.0912  max mem: 19190
# Test: Total time: 0:00:29 (0.9286 s / it)
# Averaged stats: model_time: 0.8404 (0.8189)  evaluator_time: 0.0083 (0.0080)
# Accumulating evaluation results...
# DONE (t=0.08s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.184
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.068
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.055
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.113
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.178
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.178
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8303 (0.8303)  evaluator_time: 0.0175 (0.0175)  time: 0.9485  data: 0.0915  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8340 (0.7906)  evaluator_time: 0.0138 (0.0148)  time: 0.9066  data: 0.0924  max mem: 19190
# Test: Total time: 0:00:05 (0.9068 s / it)
# Averaged stats: model_time: 0.8340 (0.7906)  evaluator_time: 0.0138 (0.0148)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.105
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.228
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.076
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.061
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.138
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.178
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.178
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 8
# Epoch: [8]  [  0/250]  eta: 0:08:46  lr: 0.001000  loss: 0.2706 (0.2706)  loss_classifier: 0.0881 (0.0881)  loss_box_reg: 0.1636 (0.1636)  loss_objectness: 0.0068 (0.0068)  loss_rpn_box_reg: 0.0121 (0.0121)  time: 2.1072  data: 0.1124  max mem: 19190
# Epoch: [8]  [ 50/250]  eta: 0:07:00  lr: 0.001000  loss: 0.2335 (0.2406)  loss_classifier: 0.0766 (0.0824)  loss_box_reg: 0.1403 (0.1433)  loss_objectness: 0.0049 (0.0056)  loss_rpn_box_reg: 0.0077 (0.0093)  time: 2.0947  data: 0.1108  max mem: 19190
# Epoch: [8]  [100/250]  eta: 0:05:15  lr: 0.001000  loss: 0.2121 (0.2315)  loss_classifier: 0.0707 (0.0783)  loss_box_reg: 0.1208 (0.1385)  loss_objectness: 0.0035 (0.0050)  loss_rpn_box_reg: 0.0070 (0.0097)  time: 2.0972  data: 0.1119  max mem: 19190
# Epoch: [8]  [150/250]  eta: 0:03:30  lr: 0.001000  loss: 0.2019 (0.2241)  loss_classifier: 0.0653 (0.0743)  loss_box_reg: 0.1245 (0.1352)  loss_objectness: 0.0053 (0.0050)  loss_rpn_box_reg: 0.0074 (0.0097)  time: 2.1014  data: 0.1111  max mem: 19190
# Epoch: [8]  [200/250]  eta: 0:01:44  lr: 0.001000  loss: 0.2159 (0.2246)  loss_classifier: 0.0721 (0.0738)  loss_box_reg: 0.1343 (0.1354)  loss_objectness: 0.0045 (0.0051)  loss_rpn_box_reg: 0.0069 (0.0103)  time: 2.0973  data: 0.1099  max mem: 19190
# Epoch: [8]  [249/250]  eta: 0:00:02  lr: 0.001000  loss: 0.2238 (0.2230)  loss_classifier: 0.0670 (0.0727)  loss_box_reg: 0.1332 (0.1354)  loss_objectness: 0.0030 (0.0049)  loss_rpn_box_reg: 0.0064 (0.0101)  time: 2.0951  data: 0.1092  max mem: 19190
# Epoch: [8] Total time: 0:08:44 (2.0982 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8299 (0.8299)  evaluator_time: 0.0060 (0.0060)  time: 0.9490  data: 0.1040  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8383 (0.8161)  evaluator_time: 0.0071 (0.0071)  time: 0.9112  data: 0.0891  max mem: 19190
# Test: Total time: 0:00:29 (0.9287 s / it)
# Averaged stats: model_time: 0.8383 (0.8161)  evaluator_time: 0.0071 (0.0071)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.107
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.213
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.078
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.078
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.129
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.195
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.195
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.118
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.234
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8292 (0.8292)  evaluator_time: 0.0157 (0.0157)  time: 0.9464  data: 0.0922  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8316 (0.7891)  evaluator_time: 0.0139 (0.0143)  time: 0.9060  data: 0.0938  max mem: 19190
# Test: Total time: 0:00:05 (0.9062 s / it)
# Averaged stats: model_time: 0.8316 (0.7891)  evaluator_time: 0.0139 (0.0143)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.125
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.256
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.090
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.153
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.195
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.195
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.118
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.234
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 9
# Epoch: [9]  [  0/250]  eta: 0:08:47  lr: 0.001000  loss: 0.2226 (0.2226)  loss_classifier: 0.0632 (0.0632)  loss_box_reg: 0.1434 (0.1434)  loss_objectness: 0.0052 (0.0052)  loss_rpn_box_reg: 0.0108 (0.0108)  time: 2.1101  data: 0.1252  max mem: 19190
# Epoch: [9]  [ 50/250]  eta: 0:07:00  lr: 0.001000  loss: 0.2213 (0.2108)  loss_classifier: 0.0704 (0.0670)  loss_box_reg: 0.1417 (0.1321)  loss_objectness: 0.0035 (0.0043)  loss_rpn_box_reg: 0.0071 (0.0075)  time: 2.0925  data: 0.1077  max mem: 19190
# Epoch: [9]  [100/250]  eta: 0:05:15  lr: 0.001000  loss: 0.1934 (0.2098)  loss_classifier: 0.0607 (0.0676)  loss_box_reg: 0.1200 (0.1301)  loss_objectness: 0.0032 (0.0044)  loss_rpn_box_reg: 0.0062 (0.0077)  time: 2.1004  data: 0.1099  max mem: 19190
# Epoch: [9]  [150/250]  eta: 0:03:29  lr: 0.001000  loss: 0.2014 (0.2064)  loss_classifier: 0.0593 (0.0660)  loss_box_reg: 0.1277 (0.1282)  loss_objectness: 0.0038 (0.0043)  loss_rpn_box_reg: 0.0059 (0.0079)  time: 2.0993  data: 0.1092  max mem: 19190
# Epoch: [9]  [200/250]  eta: 0:01:44  lr: 0.001000  loss: 0.1953 (0.2041)  loss_classifier: 0.0609 (0.0647)  loss_box_reg: 0.1239 (0.1275)  loss_objectness: 0.0031 (0.0040)  loss_rpn_box_reg: 0.0054 (0.0079)  time: 2.0993  data: 0.1077  max mem: 19190
# Epoch: [9]  [249/250]  eta: 0:00:02  lr: 0.001000  loss: 0.1792 (0.2001)  loss_classifier: 0.0543 (0.0635)  loss_box_reg: 0.1172 (0.1252)  loss_objectness: 0.0021 (0.0038)  loss_rpn_box_reg: 0.0048 (0.0075)  time: 2.0984  data: 0.1116  max mem: 19190
# Epoch: [9] Total time: 0:08:44 (2.0991 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8250 (0.8250)  evaluator_time: 0.0067 (0.0067)  time: 0.9354  data: 0.0946  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8358 (0.8142)  evaluator_time: 0.0070 (0.0070)  time: 0.9100  data: 0.0895  max mem: 19190
# Test: Total time: 0:00:29 (0.9236 s / it)
# Averaged stats: model_time: 0.8358 (0.8142)  evaluator_time: 0.0070 (0.0070)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.108
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.212
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.104
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.057
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.140
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.107
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.203
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.203
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.107
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.246
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8277 (0.8277)  evaluator_time: 0.0148 (0.0148)  time: 0.9465  data: 0.0948  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8277 (0.7864)  evaluator_time: 0.0129 (0.0135)  time: 0.9028  data: 0.0943  max mem: 19190
# Test: Total time: 0:00:05 (0.9030 s / it)
# Averaged stats: model_time: 0.8277 (0.7864)  evaluator_time: 0.0129 (0.0135)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.128
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.261
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.115
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.073
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.162
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.107
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.203
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.203
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.107
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.246
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 10
# Epoch: [10]  [  0/250]  eta: 0:08:45  lr: 0.001000  loss: 0.1664 (0.1664)  loss_classifier: 0.0506 (0.0506)  loss_box_reg: 0.1081 (0.1081)  loss_objectness: 0.0025 (0.0025)  loss_rpn_box_reg: 0.0051 (0.0051)  time: 2.1026  data: 0.1138  max mem: 19190
# Epoch: [10]  [ 50/250]  eta: 0:07:00  lr: 0.001000  loss: 0.1833 (0.1770)  loss_classifier: 0.0577 (0.0552)  loss_box_reg: 0.1109 (0.1132)  loss_objectness: 0.0022 (0.0028)  loss_rpn_box_reg: 0.0055 (0.0059)  time: 2.0903  data: 0.1081  max mem: 19190
# Epoch: [10]  [100/250]  eta: 0:05:14  lr: 0.001000  loss: 0.1794 (0.1793)  loss_classifier: 0.0584 (0.0562)  loss_box_reg: 0.1075 (0.1126)  loss_objectness: 0.0034 (0.0037)  loss_rpn_box_reg: 0.0056 (0.0068)  time: 2.0916  data: 0.1097  max mem: 19190
# Epoch: [10]  [150/250]  eta: 0:03:30  lr: 0.001000  loss: 0.1844 (0.1806)  loss_classifier: 0.0540 (0.0562)  loss_box_reg: 0.1126 (0.1130)  loss_objectness: 0.0054 (0.0042)  loss_rpn_box_reg: 0.0076 (0.0072)  time: 2.1045  data: 0.1124  max mem: 19190
# Epoch: [10]  [200/250]  eta: 0:01:45  lr: 0.001000  loss: 0.1920 (0.1830)  loss_classifier: 0.0542 (0.0566)  loss_box_reg: 0.1221 (0.1149)  loss_objectness: 0.0031 (0.0042)  loss_rpn_box_reg: 0.0053 (0.0072)  time: 2.1018  data: 0.1110  max mem: 19190
# Epoch: [10]  [249/250]  eta: 0:00:02  lr: 0.001000  loss: 0.1771 (0.1834)  loss_classifier: 0.0547 (0.0567)  loss_box_reg: 0.1114 (0.1153)  loss_objectness: 0.0036 (0.0042)  loss_rpn_box_reg: 0.0059 (0.0072)  time: 2.0999  data: 0.1075  max mem: 19190
# Epoch: [10] Total time: 0:08:45 (2.1010 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8319 (0.8319)  evaluator_time: 0.0050 (0.0050)  time: 0.9343  data: 0.0880  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8394 (0.8171)  evaluator_time: 0.0063 (0.0062)  time: 0.9156  data: 0.0930  max mem: 19190
# Test: Total time: 0:00:29 (0.9300 s / it)
# Averaged stats: model_time: 0.8394 (0.8171)  evaluator_time: 0.0063 (0.0062)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.229
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.090
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.074
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.138
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# ...
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.172
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.090
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.066
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.115
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.082
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.127
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.127
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.081
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.154
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8201 (0.8201)  evaluator_time: 0.0094 (0.0094)  time: 0.9302  data: 0.0911  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8176 (0.7769)  evaluator_time: 0.0082 (0.0085)  time: 0.8888  data: 0.0942  max mem: 19190
# Test: Total time: 0:00:05 (0.8891 s / it)
# Averaged stats: model_time: 0.8176 (0.7769)  evaluator_time: 0.0082 (0.0085)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.106
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.195
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.072
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.127
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.082
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.127
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.127
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.081
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.154
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 27
# Epoch: [27]  [  0/250]  eta: 0:10:16  lr: 0.001000  loss: 0.0752 (0.0752)  loss_classifier: 0.0204 (0.0204)  loss_box_reg: 0.0523 (0.0523)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 2.4655  data: 0.5132  max mem: 19190
# Epoch: [27]  [ 50/250]  eta: 0:06:58  lr: 0.001000  loss: 0.0927 (0.0920)  loss_classifier: 0.0294 (0.0296)  loss_box_reg: 0.0579 (0.0566)  loss_objectness: 0.0007 (0.0015)  loss_rpn_box_reg: 0.0024 (0.0043)  time: 2.0903  data: 0.1091  max mem: 19190
# Epoch: [27]  [100/250]  eta: 0:05:14  lr: 0.001000  loss: 0.0896 (0.0897)  loss_classifier: 0.0263 (0.0275)  loss_box_reg: 0.0521 (0.0556)  loss_objectness: 0.0007 (0.0016)  loss_rpn_box_reg: 0.0042 (0.0050)  time: 2.0983  data: 0.1121  max mem: 19190
# Epoch: [27]  [150/250]  eta: 0:03:29  lr: 0.001000  loss: 0.0839 (0.0896)  loss_classifier: 0.0249 (0.0268)  loss_box_reg: 0.0553 (0.0561)  loss_objectness: 0.0005 (0.0014)  loss_rpn_box_reg: 0.0030 (0.0054)  time: 2.1021  data: 0.1122  max mem: 19190
# Epoch: [27]  [200/250]  eta: 0:01:44  lr: 0.001000  loss: 0.0839 (0.0900)  loss_classifier: 0.0256 (0.0267)  loss_box_reg: 0.0544 (0.0568)  loss_objectness: 0.0003 (0.0014)  loss_rpn_box_reg: 0.0030 (0.0051)  time: 2.1034  data: 0.1131  max mem: 19190
# Epoch: [27]  [249/250]  eta: 0:00:02  lr: 0.001000  loss: 0.0792 (0.0893)  loss_classifier: 0.0242 (0.0264)  loss_box_reg: 0.0527 (0.0564)  loss_objectness: 0.0004 (0.0012)  loss_rpn_box_reg: 0.0025 (0.0053)  time: 2.1006  data: 0.1125  max mem: 19190
# Epoch: [27] Total time: 0:08:44 (2.0980 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8227 (0.8227)  evaluator_time: 0.0039 (0.0039)  time: 0.9333  data: 0.0973  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8284 (0.8074)  evaluator_time: 0.0049 (0.0051)  time: 0.9070  data: 0.0959  max mem: 19190
# Test: Total time: 0:00:29 (0.9192 s / it)
# Averaged stats: model_time: 0.8284 (0.8074)  evaluator_time: 0.0049 (0.0051)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.119
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.211
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.111
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.063
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.156
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.111
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.164
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.164
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.082
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.209
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8261 (0.8261)  evaluator_time: 0.0105 (0.0105)  time: 0.9369  data: 0.0906  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8227 (0.7813)  evaluator_time: 0.0092 (0.0097)  time: 0.8950  data: 0.0949  max mem: 19190
# Test: Total time: 0:00:05 (0.8952 s / it)
# Averaged stats: model_time: 0.8227 (0.7813)  evaluator_time: 0.0092 (0.0097)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.138
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.249
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.126
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.069
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.179
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.111
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.164
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.164
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.082
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.209
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 28
# Epoch: [28]  [  0/250]  eta: 0:10:01  lr: 0.001000  loss: 0.0860 (0.0860)  loss_classifier: 0.0254 (0.0254)  loss_box_reg: 0.0582 (0.0582)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0020 (0.0020)  time: 2.4052  data: 0.4419  max mem: 19190
# Epoch: [28]  [ 50/250]  eta: 0:07:02  lr: 0.001000  loss: 0.0839 (0.0879)  loss_classifier: 0.0253 (0.0280)  loss_box_reg: 0.0562 (0.0558)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0027 (0.0032)  time: 2.0907  data: 0.1098  max mem: 19190
# Epoch: [28]  [100/250]  eta: 0:05:16  lr: 0.001000  loss: 0.0793 (0.0845)  loss_classifier: 0.0224 (0.0264)  loss_box_reg: 0.0515 (0.0542)  loss_objectness: 0.0009 (0.0009)  loss_rpn_box_reg: 0.0024 (0.0030)  time: 2.0986  data: 0.1111  max mem: 19190
# Epoch: [28]  [150/250]  eta: 0:03:30  lr: 0.001000  loss: 0.0757 (0.0838)  loss_classifier: 0.0237 (0.0252)  loss_box_reg: 0.0503 (0.0536)  loss_objectness: 0.0009 (0.0011)  loss_rpn_box_reg: 0.0019 (0.0039)  time: 2.1111  data: 0.1141  max mem: 19190
# Epoch: [28]  [200/250]  eta: 0:01:45  lr: 0.001000  loss: 0.0677 (0.0806)  loss_classifier: 0.0194 (0.0239)  loss_box_reg: 0.0464 (0.0519)  loss_objectness: 0.0002 (0.0012)  loss_rpn_box_reg: 0.0017 (0.0036)  time: 2.1014  data: 0.1076  max mem: 19190
# Epoch: [28]  [249/250]  eta: 0:00:02  lr: 0.001000  loss: 0.0730 (0.0800)  loss_classifier: 0.0193 (0.0237)  loss_box_reg: 0.0481 (0.0514)  loss_objectness: 0.0008 (0.0013)  loss_rpn_box_reg: 0.0023 (0.0037)  time: 2.0969  data: 0.1122  max mem: 19190
# Epoch: [28] Total time: 0:08:46 (2.1052 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8240 (0.8240)  evaluator_time: 0.0046 (0.0046)  time: 0.9329  data: 0.0949  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8237 (0.8045)  evaluator_time: 0.0050 (0.0051)  time: 0.8984  data: 0.0915  max mem: 19190
# Test: Total time: 0:00:29 (0.9125 s / it)
# Averaged stats: model_time: 0.8237 (0.8045)  evaluator_time: 0.0050 (0.0051)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.184
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.102
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.057
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.130
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.091
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.153
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.153
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.081
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.194
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8210 (0.8210)  evaluator_time: 0.0109 (0.0109)  time: 0.9322  data: 0.0909  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8202 (0.7773)  evaluator_time: 0.0101 (0.0099)  time: 0.8914  data: 0.0954  max mem: 19190
# Test: Total time: 0:00:05 (0.8917 s / it)
# Averaged stats: model_time: 0.8202 (0.7773)  evaluator_time: 0.0101 (0.0099)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.117
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.218
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.116
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.064
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.149
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.091
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.153
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.153
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.081
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.194
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 29
# Epoch: [29]  [  0/250]  eta: 0:11:15  lr: 0.001000  loss: 0.0919 (0.0919)  loss_classifier: 0.0316 (0.0316)  loss_box_reg: 0.0565 (0.0565)  loss_objectness: 0.0010 (0.0010)  loss_rpn_box_reg: 0.0029 (0.0029)  time: 2.7006  data: 0.7560  max mem: 19190
# Epoch: [29]  [ 50/250]  eta: 0:06:59  lr: 0.001000  loss: 0.0840 (0.0818)  loss_classifier: 0.0235 (0.0240)  loss_box_reg: 0.0542 (0.0524)  loss_objectness: 0.0007 (0.0010)  loss_rpn_box_reg: 0.0027 (0.0044)  time: 2.0964  data: 0.1137  max mem: 19190
# Epoch: [29]  [100/250]  eta: 0:05:14  lr: 0.001000  loss: 0.0748 (0.0781)  loss_classifier: 0.0218 (0.0229)  loss_box_reg: 0.0496 (0.0506)  loss_objectness: 0.0007 (0.0009)  loss_rpn_box_reg: 0.0020 (0.0037)  time: 2.0993  data: 0.1117  max mem: 19190
# Epoch: [29]  [150/250]  eta: 0:03:29  lr: 0.001000  loss: 0.0720 (0.0773)  loss_classifier: 0.0201 (0.0222)  loss_box_reg: 0.0454 (0.0500)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0021 (0.0044)  time: 2.0958  data: 0.1099  max mem: 19190
# Epoch: [29]  [200/250]  eta: 0:01:44  lr: 0.001000  loss: 0.0650 (0.0758)  loss_classifier: 0.0185 (0.0215)  loss_box_reg: 0.0443 (0.0491)  loss_objectness: 0.0001 (0.0007)  loss_rpn_box_reg: 0.0019 (0.0044)  time: 2.0949  data: 0.1104  max mem: 19190
# Epoch: [29]  [249/250]  eta: 0:00:02  lr: 0.001000  loss: 0.0729 (0.0755)  loss_classifier: 0.0201 (0.0214)  loss_box_reg: 0.0483 (0.0486)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0018 (0.0048)  time: 2.0955  data: 0.1061  max mem: 19190
# Epoch: [29] Total time: 0:08:44 (2.0963 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8299 (0.8299)  evaluator_time: 0.0038 (0.0038)  time: 0.9292  data: 0.0865  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8398 (0.8162)  evaluator_time: 0.0045 (0.0046)  time: 0.9095  data: 0.0887  max mem: 19190
# Test: Total time: 0:00:29 (0.9208 s / it)
# Averaged stats: model_time: 0.8398 (0.8162)  evaluator_time: 0.0045 (0.0046)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.116
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.207
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.123
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.068
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.147
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.095
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.079
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8351 (0.8351)  evaluator_time: 0.0103 (0.0103)  time: 0.9414  data: 0.0869  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8315 (0.7893)  evaluator_time: 0.0083 (0.0091)  time: 0.8993  data: 0.0923  max mem: 19190
# Test: Total time: 0:00:05 (0.8996 s / it)
# Averaged stats: model_time: 0.8315 (0.7893)  evaluator_time: 0.0083 (0.0091)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.126
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.231
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.128
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.072
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.159
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.095
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.079
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Training complete!

# %% [markdown]
# # Evaluation

# %%
model_tune = fasterrcnn_resnet50_fpn_v2(
    weights="DEFAULT")
num_classes = 4
in_features = model_tune.roi_heads.box_predictor.cls_score.in_features
model_tune.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

checkpoint_path = os.path.join("/content/gdrive/My Drive/Grad School/Dissertation/Data", "pretrain_transform_0.001_0.001_21.pt")
checkpoint = torch.load(checkpoint_path)

model_tune.load_state_dict(checkpoint['model'])

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model_tune.to(device)

print(f"Model loaded successfully from {checkpoint_path}")
# Out:
# Model loaded successfully from /content/gdrive/My Drive/Grad School/Dissertation/Data/pretrain_transform_0.001_0.001_21.pt

# %%
class AerialImageryDatasetOneClass(torch.utils.data.Dataset):
    def __init__(self, image_dir_path, annotation_path, background_weight, label, train=False):
        self.image_dir_path = image_dir_path

        self.transforms = []
        if train:
            self.transforms.append(T.RandomHorizontalFlip(p=0.5))
            self.transforms.append(T.RandomVerticalFlip(p=0.5))

        self.transforms.append(T.ToDtype(torch.float, scale=True))
        self.transforms.append(T.ToPureTensor())
        self.transforms = T.Compose(self.transforms)

        self.label_map = {"daylighting": 1,
                          "safety_islands": 2,
                          "curb_extensions": 3}

        with open(annotation_path) as json_file:
            self.annotations = json.load(json_file)

        self.weights = []

        for item in tqdm(self.annotations):
            curr_weight = 1
            self.weights.append(curr_weight)

        self.label = label

    def __getitem__(self, idx):
        img_path = os.path.join(
            self.image_dir_path,
            self.annotations[idx]["image"].split("%5C")[-1])

        img = decode_image(img_path, mode="RGB")

        if img.dtype != torch.float:
            img = to_dtype(img, dtype=torch.float, scale=True)

        img = tv_tensors.Image(img)

        if "label" in self.annotations[idx]:
            boxes = [[
                i["x"],
                i["y"],
                i["width"],
                i["height"]] for i in self.annotations[idx]["label"] if i["rectanglelabels"][0] == self.label]

            if len(boxes) == 0:
                boxes = torch.zeros((0, 4), dtype=torch.float32)
                labels = torch.zeros((0,), dtype=torch.int64)
            else:
                boxes = convert_bounding_box_format(tv_tensors.BoundingBoxes(boxes, format="XYWH", canvas_size=get_size(img)), new_format="XYXY")
                boxes = tv_tensors.BoundingBoxes(boxes * 416 / 100, format="XYXY", canvas_size=get_size(img))
                labels = torch.tensor([self.label_map[i["rectanglelabels"][0]] for i in self.annotations[idx]["label"] if i["rectanglelabels"][0] == self.label])

        else:
            boxes = torch.zeros((0, 4), dtype=torch.float32)
            labels = torch.zeros((0,), dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = int("".join(self.annotations[idx]["image"].split("%5C")[-1].split(".")[0].split("_")))
        target["area"] = torch.tensor([(box[2] - box[0]) * (box[3] - box[1]) for box in boxes])
        target["iscrowd"] = torch.tensor([0] * len(boxes))

        img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.annotations)

# %%
from tqdm import tqdm

image_path = os.path.join("/content/gdrive/My Drive/Grad School/Dissertation/Data", "test")
label_path = os.path.join("/content/gdrive/My Drive/Grad School/Dissertation/Data", "test.json")

batch_size = 16

dataset_valtest = AerialImageryDatasetOneClass(
    image_dir_path=image_path,
    annotation_path=label_path,
    background_weight=0.001,
    label="curb_extensions",
    train=False)


g = torch.Generator()
g.manual_seed(2025)
indices = torch.randperm(n=len(dataset_valtest), generator=g).tolist()

subset_val = Subset(dataset_valtest, indices[int(len(dataset_valtest) * 0.8):int(len(dataset_valtest) * 0.9)])

data_loader_val_curb = DataLoader(
    subset_val,
    batch_size=batch_size,
    collate_fn=utils.collate_fn
)

dataset_valtest = AerialImageryDatasetOneClass(
    image_dir_path=image_path,
    annotation_path=label_path,
    background_weight=0.001,
    label="daylighting",
    train=False)

g = torch.Generator()
g.manual_seed(2025)
indices = torch.randperm(n=len(dataset_valtest), generator=g).tolist()

subset_val = Subset(dataset_valtest, indices[int(len(dataset_valtest) * 0.8):int(len(dataset_valtest) * 0.9)])

data_loader_val_day = DataLoader(
    subset_val,
    batch_size=batch_size,
    collate_fn=utils.collate_fn
)

dataset_valtest = AerialImageryDatasetOneClass(
    image_dir_path=image_path,
    annotation_path=label_path,
    background_weight=0.001,
    label="safety_islands",
    train=False)

g = torch.Generator()
g.manual_seed(2025)
indices = torch.randperm(n=len(dataset_valtest), generator=g).tolist()

subset_val = Subset(dataset_valtest, indices[int(len(dataset_valtest) * 0.8):int(len(dataset_valtest) * 0.9)])

data_loader_val_island = DataLoader(
    subset_val,
    batch_size=batch_size,
    collate_fn=utils.collate_fn
)

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
# Out:
# 100%|██████████| 5000/5000 [00:00<00:00, 4317792.88it/s]
# 100%|██████████| 5000/5000 [00:00<00:00, 4184261.77it/s]
# 100%|██████████| 5000/5000 [00:00<00:00, 4104818.95it/s]

# %%
evaluate(model_tune, data_loader_val_curb, device=device)
# Out:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:01:14  model_time: 2.2217 (2.2217)  evaluator_time: 0.0066 (0.0066)  time: 2.3230  data: 0.0857  max mem: 5477
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8319 (0.8561)  evaluator_time: 0.0027 (0.0029)  time: 0.9164  data: 0.1039  max mem: 5486
# Test: Total time: 0:00:31 (0.9690 s / it)
# Averaged stats: model_time: 0.8319 (0.8561)  evaluator_time: 0.0027 (0.0029)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.015
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000

# %%
evaluate(model_tune, data_loader_val_day, device=device)
# Out:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8179 (0.8179)  evaluator_time: 0.0028 (0.0028)  time: 0.9130  data: 0.0834  max mem: 5486
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8261 (0.8045)  evaluator_time: 0.0031 (0.0032)  time: 0.8958  data: 0.0889  max mem: 5486
# Test: Total time: 0:00:29 (0.9069 s / it)
# Averaged stats: model_time: 0.8261 (0.8045)  evaluator_time: 0.0031 (0.0032)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.069
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.032
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.075
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.096
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.096
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.018
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.145
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000

# %%
evaluate(model_tune, data_loader_val_island, device=device)
# Out:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8221 (0.8221)  evaluator_time: 0.0027 (0.0027)  time: 0.9205  data: 0.0866  max mem: 5486
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8328 (0.8099)  evaluator_time: 0.0033 (0.0033)  time: 0.9024  data: 0.0895  max mem: 5486
# Test: Total time: 0:00:29 (0.9132 s / it)
# Averaged stats: model_time: 0.8328 (0.8099)  evaluator_time: 0.0033 (0.0033)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.352
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.653
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.316
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.258
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.419
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.256
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.449
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.449
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.343
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.511
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
