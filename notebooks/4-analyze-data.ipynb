# %%
import numpy as np
import pandas as pd

# %%
data_path = "C:/Users/ckaz3/Desktop/intersection-safety-infra-detection/data/interim/stations_inscope.csv"
data = pd.read_csv(data_path, index_col=0)
data.head()
# Out:
#                            Agency                                     Line(s)  \
# Station_ID
# 2907        Charm City Circulator  Charm City Circulator Harbor Connector(HC)
# 2908        Charm City Circulator  Charm City Circulator Harbor Connector(HC)
# 2909        Charm City Circulator  Charm City Circulator Harbor Connector(HC)
# 2910        Charm City Circulator  Charm City Circulator Harbor Connector(HC)
# 2911        Charm City Circulator  Charm City Circulator Harbor Connector(HC)
#
#                       Station Name Year Opened  Station_Latitude  \
# Station_ID
# 2907        CANTON WATERFRONT PARK    Pre-2000         39.277256
# 2908        CANTON WATERFRONT PARK    Pre-2000         39.277256
# 2909        CANTON WATERFRONT PARK    Pre-2000         39.277256
# 2910        CANTON WATERFRONT PARK    Pre-2000         39.277256
# 2911        CANTON WATERFRONT PARK    Pre-2000         39.277256
#
#             Station_Longitude  Inter_Latitude  Inter_Longitude  \
# Station_ID
# ...

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="my_app")


data[["Inter_Longitude", "Inter_Latitude"]]

def city_state_country(row):
    coord = f"{row['Inter_Latitude']}, {row['Inter_Longitude']}"
    location = geolocator.reverse(coord, exactly_one=True)
    address = location.raw['address']
    city = address.get('city', '')
    state = address.get('state', '')
    country = address.get('country', '')
    row['city'] = city
    row['state'] = state
    row['country'] = country
    return row

data.apply(city_state_country, axis=1)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\ckaz3\Desktop\intersection-safety-infra-detection\infra-detection\Lib\site-packages\urllib3\connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     464         except BaseException as e:
#     465             # Remove the TypeError from the exception chain in
#     466             # Python 3 (including for exceptions like SystemExit).
#     467             # Otherwise it looks like a bug in the code.
# --> 468             six.raise_from(e, None)
#     469 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# ...

# %%
data.head()
# Out:
#                            Agency                                     Line(s)  \
# Station_ID
# 2907        Charm City Circulator  Charm City Circulator Harbor Connector(HC)
# 2908        Charm City Circulator  Charm City Circulator Harbor Connector(HC)
# 2909        Charm City Circulator  Charm City Circulator Harbor Connector(HC)
# 2910        Charm City Circulator  Charm City Circulator Harbor Connector(HC)
# 2911        Charm City Circulator  Charm City Circulator Harbor Connector(HC)
#
#                       Station Name Year Opened  Station_Latitude  \
# Station_ID
# 2907        CANTON WATERFRONT PARK    Pre-2000         39.277256
# 2908        CANTON WATERFRONT PARK    Pre-2000         39.277256
# 2909        CANTON WATERFRONT PARK    Pre-2000         39.277256
# 2910        CANTON WATERFRONT PARK    Pre-2000         39.277256
# 2911        CANTON WATERFRONT PARK    Pre-2000         39.277256
#
#             Station_Longitude  Inter_Latitude  Inter_Longitude  \
# Station_ID
# ...
