# %% [markdown]
# # Setup

# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import os

os.system(
    "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py"
)
os.system(
    "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py"
)
os.system(
    "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py"
)
os.system(
    "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py"
)
os.system(
    "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py"
)
# Out:
# 0

# %%
import torch
from torch.utils.data import Subset, DataLoader

from torchvision import tv_tensors
from torchvision.io import decode_image

from torchvision.transforms import v2 as T
from torchvision.transforms.v2.functional import (
    to_dtype,
    get_size,
    convert_bounding_box_format,
)

from torchvision.models.detection import fasterrcnn_resnet50_fpn_v2
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

import pandas as pd
import numpy as np

import os
import json

import math
import sys

import utils
from engine import train_one_epoch, evaluate

# %% [markdown]
# # Data

# %%
class AerialImageryDataset(torch.utils.data.Dataset):
    def __init__(self, image_dir_path, annotation_path, background_weight, train=False):
        self.image_dir_path = image_dir_path

        self.transforms = []
        if train:
            self.transforms.append(T.RandomHorizontalFlip(p=0.5))
            self.transforms.append(T.RandomVerticalFlip(p=0.5))

        self.transforms.append(T.ToDtype(torch.float, scale=True))
        self.transforms.append(T.ToPureTensor())
        self.transforms = T.Compose(self.transforms)

        self.label_map = {"daylighting": 1, "safety_islands": 2, "curb_extensions": 3}

        with open(annotation_path) as json_file:
            self.annotations = json.load(json_file)

        self.weights = []

        for item in tqdm(self.annotations):
            curr_weight = 1

            if "label" in item:
                for label in item["label"]:
                    if label["rectanglelabels"][0] == "curb_extensions":
                        curr_weight = 3
                        break
            else:
                curr_weight = background_weight

            self.weights.append(curr_weight)

    def __getitem__(self, idx):
        img_path = os.path.join(
            self.image_dir_path, self.annotations[idx]["image"].split("%5C")[-1]
        )

        img = decode_image(img_path, mode="RGB")

        if img.dtype != torch.float:
            img = to_dtype(img, dtype=torch.float, scale=True)

        img = tv_tensors.Image(img)

        if "label" in self.annotations[idx]:
            boxes = [
                [i["x"], i["y"], i["width"], i["height"]]
                for i in self.annotations[idx]["label"]
            ]

            boxes = convert_bounding_box_format(
                tv_tensors.BoundingBoxes(
                    boxes, format="XYWH", canvas_size=get_size(img)
                ),
                new_format="XYXY",
            )
            boxes = tv_tensors.BoundingBoxes(
                boxes * 416 / 100, format="XYXY", canvas_size=get_size(img)
            )
            labels = torch.tensor(
                [
                    self.label_map[i["rectanglelabels"][0]]
                    for i in self.annotations[idx]["label"]
                ]
            )

        else:
            boxes = torch.zeros((0, 4), dtype=torch.float32)
            labels = torch.zeros((0,), dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = int(
            "".join(
                self.annotations[idx]["image"].split("%5C")[-1].split(".")[0].split("_")
            )
        )
        target["area"] = torch.tensor(
            [(box[2] - box[0]) * (box[3] - box[1]) for box in boxes]
        )
        target["iscrowd"] = torch.tensor([0] * len(boxes))

        img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.annotations)

# %%
from tqdm import tqdm

image_path = os.path.join(
    "/content/gdrive/My Drive/Grad School/Dissertation/Data", "test"
)
label_path = os.path.join(
    "/content/gdrive/My Drive/Grad School/Dissertation/Data", "test.json"
)

batch_size = 16

dataset_train = AerialImageryDataset(
    image_dir_path=image_path,
    annotation_path=label_path,
    background_weight=0.0001,
    train=True,
)
dataset_valtest = AerialImageryDataset(
    image_dir_path=image_path,
    annotation_path=label_path,
    background_weight=0.0001,
    train=False,
)


g = torch.Generator()
g.manual_seed(2025)
indices = torch.randperm(n=len(dataset_train), generator=g).tolist()

subset_train = Subset(dataset_train, indices[: int(len(dataset_train) * 0.8)])
subset_val = Subset(
    dataset_valtest,
    indices[int(len(dataset_valtest) * 0.8) : int(len(dataset_valtest) * 0.9)],
)
subset_test = Subset(dataset_valtest, indices[int(len(dataset_valtest) * 0.9) :])

train_weights = [
    dataset_train.weights[idx] for idx in indices[: int(len(dataset_train) * 0.8)]
]

data_loader_train = DataLoader(
    subset_train,
    batch_size=batch_size,
    sampler=torch.utils.data.WeightedRandomSampler(train_weights, len(train_weights)),
    collate_fn=utils.collate_fn,
)
data_loader_val = DataLoader(
    subset_val, batch_size=batch_size, collate_fn=utils.collate_fn
)

data_loader_test = DataLoader(
    subset_test, batch_size=batch_size, collate_fn=utils.collate_fn
)

annotated_indices = []
unannotated_indices = []

for i in subset_val.indices:
    if "label" in subset_val.dataset.annotations[i]:
        annotated_indices.append(i)
    else:
        unannotated_indices.append(i)

subset_val_annotated = Subset(dataset_valtest, annotated_indices)
subset_val_unannotated = Subset(dataset_valtest, unannotated_indices)

data_loader_val_annotated = DataLoader(
    subset_val_annotated, batch_size=batch_size, collate_fn=utils.collate_fn
)

data_loader_val_unannotated = DataLoader(
    subset_val_unannotated, batch_size=batch_size, collate_fn=utils.collate_fn
)
# Out:
# 100%|██████████| 5000/5000 [00:00<00:00, 3175578.44it/s]
# 100%|██████████| 5000/5000 [00:00<00:00, 2956233.44it/s]

# %%
train_label_path = os.path.join(
    "/content/gdrive/My Drive/Grad School/Dissertation/Data", "test.json"
)

with open(train_label_path) as json_file:
    test = json.load(json_file)


test = test[int(len(test) * 0.8) : int(len(test) * 0.9)]

daylighting_count = 0
safety_islands_count = 0
curb_extensions_count = 0
empty_count = 0

for item in test:
    if "label" in item:
        counts = [0, 0, 0]
        for annot in item["label"]:
            if annot["rectanglelabels"][0] == "daylighting":
                # daylighting_count += 1
                counts[0] += 1
            elif annot["rectanglelabels"][0] == "safety_islands":
                # safety_islands_count += 1
                counts[1] += 1
            elif annot["rectanglelabels"][0] == "curb_extensions":
                # curb_extensions_count += 1
                counts[2] += 1

        if counts[2] != 0:
            counts = [1 * i for i in counts]
        # elif counts[0] == 0 and counts[2] != 0:
        #     counts = [4 * i for i in counts]

        daylighting_count += counts[0]
        safety_islands_count += counts[1]
        curb_extensions_count += counts[2]

    else:
        empty_count += 1

print(f"Daylighting: {daylighting_count}")
print(f"Safety Islands: {safety_islands_count}")
print(f"Curb Extensions: {curb_extensions_count}")
print(f"Empty: {empty_count}")
# Out:
# Daylighting: 127
# Safety Islands: 53
# Curb Extensions: 37
# Empty: 402

# %% [markdown]
# # Training

# %%
def train_one_epoch_no_schedule(
    model, optimizer, data_loader, device, epoch, print_freq
):
    model.train()
    metric_logger = utils.MetricLogger(delimiter="  ")
    metric_logger.add_meter("lr", utils.SmoothedValue(window_size=1, fmt="{value:.6f}"))
    header = f"Epoch: [{epoch}]"

    for images, targets in metric_logger.log_every(data_loader, print_freq, header):
        images = list(image.to(device) for image in images)
        targets = [
            {
                k: v.to(device) if isinstance(v, torch.Tensor) else v
                for k, v in t.items()
            }
            for t in targets
        ]

        with torch.amp.autocast("cuda", enabled=False):
            loss_dict = model(images, targets)
            losses = sum(loss for loss in loss_dict.values())

        # reduce losses over all GPUs for logging purposes
        loss_dict_reduced = utils.reduce_dict(loss_dict)
        losses_reduced = sum(loss for loss in loss_dict_reduced.values())

        loss_value = losses_reduced.item()

        if not math.isfinite(loss_value):
            print(f"Loss is {loss_value}, stopping training")
            print(loss_dict_reduced)
            sys.exit(1)

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        metric_logger.update(loss=losses_reduced, **loss_dict_reduced)
        metric_logger.update(lr=optimizer.param_groups[0]["lr"])

    return metric_logger

# %%
def training(
    model,
    optimizer,
    num_epochs,
    lr,
    save_loc,
    starting_epoch=0,
):
    device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

    model.to(device)

    for epoch in range(starting_epoch, starting_epoch + num_epochs):
        print("EPOCH " + str(epoch))
        train_one_epoch_no_schedule(
            model, optimizer, data_loader_train, device, epoch, print_freq=50
        )
        # evaluate(model_tune, data_loader_train, device=device)
        print("VALIDATION EVALUATION:")
        evaluate(model_tune, data_loader_val, device=device)
        print("VALIDATION ANNOTATED EVALUATION:")
        evaluate(model_tune, data_loader_val_annotated, device=device)

        save_path = save_loc + "_" + str(lr) + "_" + str(epoch) + ".pt"
        save_path = os.path.join(
            "/content/gdrive/My Drive/Grad School/Dissertation/Data", save_path
        )

        checkpoint = {
            "epoch": epoch,
            "model": model.state_dict(),
            "optimizer": optimizer.state_dict(),
        }
        torch.save(checkpoint, save_path)

    print("Training complete!")

# %% [markdown]
# # Experiments

# %% [markdown]
# ## Experiment 1: Fine-tuning

# %%
lr = 0.0001
model_tune = fasterrcnn_resnet50_fpn_v2(
    weights="DEFAULT",
    # image_mean=[0.4715, 0.4723, 0.4587],
    # image_std=[0.2071, 0.1955, 0.1825]
)

# replace the pre-trained head with a new one
num_classes = 4
in_features = model_tune.roi_heads.box_predictor.cls_score.in_features
model_tune.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

params = [p for p in model_tune.parameters() if p.requires_grad]
optimizer = torch.optim.Adam(
    params,
    lr=lr,
)

training(
    model=model_tune,
    optimizer=optimizer,
    num_epochs=30,
    lr=lr,
    save_loc="pretrain_transform_0.0001",
    starting_epoch=0,
)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth
# 100%|██████████| 167M/167M [00:00<00:00, 221MB/s]
# EPOCH 0
# Epoch: [0]  [  0/250]  eta: 3:02:16  lr: 0.000100  loss: 1.6781 (1.6781)  loss_classifier: 1.2425 (1.2425)  loss_box_reg: 0.0484 (0.0484)  loss_objectness: 0.3643 (0.3643)  loss_rpn_box_reg: 0.0229 (0.0229)  time: 43.7456  data: 39.6369  max mem: 18863
# Epoch: [0]  [ 50/250]  eta: 0:40:07  lr: 0.000100  loss: 0.4824 (0.5385)  loss_classifier: 0.2201 (0.2624)  loss_box_reg: 0.1826 (0.1674)  loss_objectness: 0.0582 (0.0921)  loss_rpn_box_reg: 0.0114 (0.0167)  time: 8.3202  data: 6.3141  max mem: 19190
# Epoch: [0]  [100/250]  eta: 0:22:00  lr: 0.000100  loss: 0.4330 (0.5026)  loss_classifier: 0.1900 (0.2369)  loss_box_reg: 0.1813 (0.1827)  loss_objectness: 0.0335 (0.0681)  loss_rpn_box_reg: 0.0110 (0.0149)  time: 4.8419  data: 2.8403  max mem: 19190
# Epoch: [0]  [150/250]  eta: 0:11:54  lr: 0.000100  loss: 0.4015 (0.4771)  loss_classifier: 0.1630 (0.2182)  loss_box_reg: 0.1863 (0.1878)  loss_objectness: 0.0273 (0.0564)  loss_rpn_box_reg: 0.0092 (0.0147)  time: 3.4217  data: 1.4231  max mem: 19190
# Epoch: [0]  [200/250]  eta: 0:05:02  lr: 0.000100  loss: 0.3786 (0.4557)  loss_classifier: 0.1460 (0.2026)  loss_box_reg: 0.1854 (0.1894)  loss_objectness: 0.0239 (0.0494)  loss_rpn_box_reg: 0.0104 (0.0143)  time: 2.6752  data: 0.6779  max mem: 19190
# Epoch: [0]  [249/250]  eta: 0:00:05  lr: 0.000100  loss: 0.3791 (0.4388)  loss_classifier: 0.1426 (0.1910)  loss_box_reg: 0.2064 (0.1910)  loss_objectness: 0.0159 (0.0435)  loss_rpn_box_reg: 0.0076 (0.0132)  time: 2.5087  data: 0.5132  max mem: 19190
# Epoch: [0] Total time: 0:22:17 (5.3508 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8404 (0.8404)  evaluator_time: 0.0132 (0.0132)  time: 0.9491  data: 0.0863  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8365 (0.8159)  evaluator_time: 0.0105 (0.0108)  time: 0.9144  data: 0.0889  max mem: 19190
# Test: Total time: 0:00:29 (0.9273 s / it)
# Averaged stats: model_time: 0.8365 (0.8159)  evaluator_time: 0.0105 (0.0108)
# Accumulating evaluation results...
# DONE (t=0.13s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.123
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.265
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.066
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.160
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.139
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.337
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.354
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.182
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.410
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.033
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8396 (0.8396)  evaluator_time: 0.0218 (0.0218)  time: 0.9603  data: 0.0897  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8395 (0.7957)  evaluator_time: 0.0215 (0.0215)  time: 0.9197  data: 0.0936  max mem: 19190
# Test: Total time: 0:00:05 (0.9200 s / it)
# Averaged stats: model_time: 0.8395 (0.7957)  evaluator_time: 0.0215 (0.0215)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.157
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.351
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.122
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.092
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.197
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.139
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.337
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.354
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.182
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.410
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.033
# EPOCH 1
# Epoch: [1]  [  0/250]  eta: 0:08:51  lr: 0.000100  loss: 0.3922 (0.3922)  loss_classifier: 0.1374 (0.1374)  loss_box_reg: 0.2254 (0.2254)  loss_objectness: 0.0190 (0.0190)  loss_rpn_box_reg: 0.0103 (0.0103)  time: 2.1251  data: 0.1152  max mem: 19190
# Epoch: [1]  [ 50/250]  eta: 0:07:02  lr: 0.000100  loss: 0.3320 (0.3356)  loss_classifier: 0.1167 (0.1245)  loss_box_reg: 0.1810 (0.1850)  loss_objectness: 0.0143 (0.0178)  loss_rpn_box_reg: 0.0074 (0.0083)  time: 2.1034  data: 0.1099  max mem: 19190
# Epoch: [1]  [100/250]  eta: 0:05:16  lr: 0.000100  loss: 0.2639 (0.3189)  loss_classifier: 0.0978 (0.1153)  loss_box_reg: 0.1496 (0.1778)  loss_objectness: 0.0107 (0.0171)  loss_rpn_box_reg: 0.0058 (0.0086)  time: 2.1007  data: 0.1052  max mem: 19190
# Epoch: [1]  [150/250]  eta: 0:03:30  lr: 0.000100  loss: 0.2671 (0.3112)  loss_classifier: 0.0951 (0.1113)  loss_box_reg: 0.1591 (0.1762)  loss_objectness: 0.0070 (0.0153)  loss_rpn_box_reg: 0.0065 (0.0085)  time: 2.1043  data: 0.1096  max mem: 19190
# Epoch: [1]  [200/250]  eta: 0:01:45  lr: 0.000100  loss: 0.2356 (0.2975)  loss_classifier: 0.0817 (0.1057)  loss_box_reg: 0.1396 (0.1699)  loss_objectness: 0.0072 (0.0136)  loss_rpn_box_reg: 0.0048 (0.0083)  time: 2.1023  data: 0.1068  max mem: 19190
# Epoch: [1]  [249/250]  eta: 0:00:02  lr: 0.000100  loss: 0.2243 (0.2853)  loss_classifier: 0.0807 (0.1004)  loss_box_reg: 0.1348 (0.1641)  loss_objectness: 0.0057 (0.0125)  loss_rpn_box_reg: 0.0053 (0.0083)  time: 2.1043  data: 0.1075  max mem: 19190
# Epoch: [1] Total time: 0:08:46 (2.1059 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8348 (0.8348)  evaluator_time: 0.0070 (0.0070)  time: 0.9380  data: 0.0871  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8397 (0.8191)  evaluator_time: 0.0082 (0.0128)  time: 0.9145  data: 0.0886  max mem: 19190
# Test: Total time: 0:00:29 (0.9318 s / it)
# Averaged stats: model_time: 0.8397 (0.8191)  evaluator_time: 0.0082 (0.0128)
# Accumulating evaluation results...
# DONE (t=0.08s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.170
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.331
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.151
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.213
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.067
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.344
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.346
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.218
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.387
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.067
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8334 (0.8334)  evaluator_time: 0.0162 (0.0162)  time: 0.9445  data: 0.0860  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8334 (0.7910)  evaluator_time: 0.0162 (0.0159)  time: 0.9062  data: 0.0906  max mem: 19190
# Test: Total time: 0:00:05 (0.9064 s / it)
# Averaged stats: model_time: 0.8334 (0.7910)  evaluator_time: 0.0162 (0.0159)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.205
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.411
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.174
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.133
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.248
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.067
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.344
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.346
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.218
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.387
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.067
# EPOCH 2
# Epoch: [2]  [  0/250]  eta: 0:09:38  lr: 0.000100  loss: 0.2131 (0.2131)  loss_classifier: 0.0658 (0.0658)  loss_box_reg: 0.1393 (0.1393)  loss_objectness: 0.0031 (0.0031)  loss_rpn_box_reg: 0.0050 (0.0050)  time: 2.3146  data: 0.3133  max mem: 19190
# Epoch: [2]  [ 50/250]  eta: 0:07:08  lr: 0.000100  loss: 0.2094 (0.2298)  loss_classifier: 0.0664 (0.0774)  loss_box_reg: 0.1276 (0.1370)  loss_objectness: 0.0051 (0.0084)  loss_rpn_box_reg: 0.0049 (0.0071)  time: 2.1093  data: 0.1125  max mem: 19190
# Epoch: [2]  [100/250]  eta: 0:05:18  lr: 0.000100  loss: 0.2195 (0.2235)  loss_classifier: 0.0701 (0.0726)  loss_box_reg: 0.1402 (0.1368)  loss_objectness: 0.0042 (0.0078)  loss_rpn_box_reg: 0.0049 (0.0064)  time: 2.1072  data: 0.1086  max mem: 19190
# Epoch: [2]  [150/250]  eta: 0:03:31  lr: 0.000100  loss: 0.2213 (0.2253)  loss_classifier: 0.0659 (0.0724)  loss_box_reg: 0.1334 (0.1382)  loss_objectness: 0.0060 (0.0074)  loss_rpn_box_reg: 0.0044 (0.0073)  time: 2.1063  data: 0.1085  max mem: 19190
# Epoch: [2]  [200/250]  eta: 0:01:45  lr: 0.000100  loss: 0.1939 (0.2185)  loss_classifier: 0.0564 (0.0694)  loss_box_reg: 0.1244 (0.1359)  loss_objectness: 0.0030 (0.0064)  loss_rpn_box_reg: 0.0043 (0.0068)  time: 2.1063  data: 0.1104  max mem: 19190
# Epoch: [2]  [249/250]  eta: 0:00:02  lr: 0.000100  loss: 0.1759 (0.2118)  loss_classifier: 0.0573 (0.0674)  loss_box_reg: 0.1086 (0.1320)  loss_objectness: 0.0022 (0.0059)  loss_rpn_box_reg: 0.0037 (0.0064)  time: 2.1132  data: 0.1125  max mem: 19190
# Epoch: [2] Total time: 0:08:48 (2.1143 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8343 (0.8343)  evaluator_time: 0.0060 (0.0060)  time: 0.9357  data: 0.0861  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8410 (0.8186)  evaluator_time: 0.0064 (0.0063)  time: 0.9144  data: 0.0904  max mem: 19190
# Test: Total time: 0:00:29 (0.9258 s / it)
# Averaged stats: model_time: 0.8410 (0.8186)  evaluator_time: 0.0064 (0.0063)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.184
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.366
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.178
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.106
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.222
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.169
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.184
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.382
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.089
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8369 (0.8369)  evaluator_time: 0.0151 (0.0151)  time: 0.9484  data: 0.0871  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8391 (0.7956)  evaluator_time: 0.0129 (0.0130)  time: 0.9106  data: 0.0932  max mem: 19190
# Test: Total time: 0:00:05 (0.9108 s / it)
# Averaged stats: model_time: 0.8391 (0.7956)  evaluator_time: 0.0129 (0.0130)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.229
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.468
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.216
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.131
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.272
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.169
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.184
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.382
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.089
# EPOCH 3
# Epoch: [3]  [  0/250]  eta: 0:09:38  lr: 0.000100  loss: 0.1773 (0.1773)  loss_classifier: 0.0609 (0.0609)  loss_box_reg: 0.1092 (0.1092)  loss_objectness: 0.0030 (0.0030)  loss_rpn_box_reg: 0.0042 (0.0042)  time: 2.3124  data: 0.3030  max mem: 19190
# Epoch: [3]  [ 50/250]  eta: 0:07:04  lr: 0.000100  loss: 0.1547 (0.1717)  loss_classifier: 0.0489 (0.0541)  loss_box_reg: 0.0964 (0.1099)  loss_objectness: 0.0017 (0.0032)  loss_rpn_box_reg: 0.0031 (0.0045)  time: 2.1026  data: 0.1073  max mem: 19190
# Epoch: [3]  [100/250]  eta: 0:05:17  lr: 0.000100  loss: 0.1469 (0.1701)  loss_classifier: 0.0449 (0.0524)  loss_box_reg: 0.1023 (0.1099)  loss_objectness: 0.0018 (0.0028)  loss_rpn_box_reg: 0.0034 (0.0050)  time: 2.1053  data: 0.1089  max mem: 19190
# Epoch: [3]  [150/250]  eta: 0:03:31  lr: 0.000100  loss: 0.1557 (0.1690)  loss_classifier: 0.0447 (0.0516)  loss_box_reg: 0.1039 (0.1090)  loss_objectness: 0.0017 (0.0034)  loss_rpn_box_reg: 0.0031 (0.0050)  time: 2.1085  data: 0.1111  max mem: 19190
# Epoch: [3]  [200/250]  eta: 0:01:45  lr: 0.000100  loss: 0.1580 (0.1670)  loss_classifier: 0.0445 (0.0504)  loss_box_reg: 0.1065 (0.1075)  loss_objectness: 0.0018 (0.0036)  loss_rpn_box_reg: 0.0036 (0.0055)  time: 2.1073  data: 0.1096  max mem: 19190
# Epoch: [3]  [249/250]  eta: 0:00:02  lr: 0.000100  loss: 0.1479 (0.1637)  loss_classifier: 0.0419 (0.0493)  loss_box_reg: 0.1001 (0.1059)  loss_objectness: 0.0011 (0.0032)  loss_rpn_box_reg: 0.0031 (0.0053)  time: 2.1093  data: 0.1103  max mem: 19190
# Epoch: [3] Total time: 0:08:47 (2.1104 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8336 (0.8336)  evaluator_time: 0.0049 (0.0049)  time: 0.9406  data: 0.0928  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8389 (0.8176)  evaluator_time: 0.0060 (0.0058)  time: 0.9147  data: 0.0920  max mem: 19190
# Test: Total time: 0:00:29 (0.9264 s / it)
# Averaged stats: model_time: 0.8389 (0.8176)  evaluator_time: 0.0060 (0.0058)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.179
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.341
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.161
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.106
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.220
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.169
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.307
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.307
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.185
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.354
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.078
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8366 (0.8366)  evaluator_time: 0.0129 (0.0129)  time: 0.9529  data: 0.0940  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8323 (0.7902)  evaluator_time: 0.0115 (0.0118)  time: 0.9047  data: 0.0938  max mem: 19190
# Test: Total time: 0:00:05 (0.9049 s / it)
# Averaged stats: model_time: 0.8323 (0.7902)  evaluator_time: 0.0115 (0.0118)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.211
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.409
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.186
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.128
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.258
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.039
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.169
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.307
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.307
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.185
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.354
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.078
# EPOCH 4
# Epoch: [4]  [  0/250]  eta: 0:08:46  lr: 0.000100  loss: 0.1580 (0.1580)  loss_classifier: 0.0490 (0.0490)  loss_box_reg: 0.1042 (0.1042)  loss_objectness: 0.0022 (0.0022)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 2.1072  data: 0.1039  max mem: 19190
# Epoch: [4]  [ 50/250]  eta: 0:07:03  lr: 0.000100  loss: 0.1535 (0.1530)  loss_classifier: 0.0458 (0.0460)  loss_box_reg: 0.0996 (0.0999)  loss_objectness: 0.0023 (0.0025)  loss_rpn_box_reg: 0.0028 (0.0046)  time: 2.1065  data: 0.1097  max mem: 19190
# Epoch: [4]  [100/250]  eta: 0:05:16  lr: 0.000100  loss: 0.1304 (0.1456)  loss_classifier: 0.0378 (0.0430)  loss_box_reg: 0.0864 (0.0962)  loss_objectness: 0.0007 (0.0019)  loss_rpn_box_reg: 0.0027 (0.0045)  time: 2.1034  data: 0.1088  max mem: 19190
# Epoch: [4]  [150/250]  eta: 0:03:31  lr: 0.000100  loss: 0.1338 (0.1427)  loss_classifier: 0.0354 (0.0420)  loss_box_reg: 0.0929 (0.0941)  loss_objectness: 0.0011 (0.0018)  loss_rpn_box_reg: 0.0026 (0.0047)  time: 2.1029  data: 0.1090  max mem: 19190
# Epoch: [4]  [200/250]  eta: 0:01:45  lr: 0.000100  loss: 0.1164 (0.1386)  loss_classifier: 0.0321 (0.0408)  loss_box_reg: 0.0818 (0.0918)  loss_objectness: 0.0006 (0.0017)  loss_rpn_box_reg: 0.0020 (0.0043)  time: 2.1025  data: 0.1082  max mem: 19190
# Epoch: [4]  [249/250]  eta: 0:00:02  lr: 0.000100  loss: 0.1239 (0.1359)  loss_classifier: 0.0387 (0.0402)  loss_box_reg: 0.0841 (0.0900)  loss_objectness: 0.0005 (0.0016)  loss_rpn_box_reg: 0.0022 (0.0042)  time: 2.1023  data: 0.1082  max mem: 19190
# Epoch: [4] Total time: 0:08:46 (2.1077 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8366 (0.8366)  evaluator_time: 0.0054 (0.0054)  time: 0.9379  data: 0.0866  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8416 (0.8207)  evaluator_time: 0.0063 (0.0061)  time: 0.9169  data: 0.0914  max mem: 19190
# Test: Total time: 0:00:29 (0.9284 s / it)
# Averaged stats: model_time: 0.8416 (0.8207)  evaluator_time: 0.0063 (0.0061)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.183
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.339
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.187
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.225
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.011
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.175
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.319
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.319
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.180
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.369
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.067
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8314 (0.8314)  evaluator_time: 0.0135 (0.0135)  time: 0.9435  data: 0.0895  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8354 (0.7929)  evaluator_time: 0.0114 (0.0120)  time: 0.9069  data: 0.0931  max mem: 19190
# Test: Total time: 0:00:05 (0.9071 s / it)
# Averaged stats: model_time: 0.8354 (0.7929)  evaluator_time: 0.0114 (0.0120)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.220
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.411
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.222
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.126
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.268
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.017
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.175
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.319
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.319
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.180
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.369
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.067
# EPOCH 5
# Epoch: [5]  [  0/250]  eta: 0:08:49  lr: 0.000100  loss: 0.1097 (0.1097)  loss_classifier: 0.0352 (0.0352)  loss_box_reg: 0.0719 (0.0719)  loss_objectness: 0.0005 (0.0005)  loss_rpn_box_reg: 0.0021 (0.0021)  time: 2.1186  data: 0.1205  max mem: 19190
# Epoch: [5]  [ 50/250]  eta: 0:07:03  lr: 0.000100  loss: 0.1150 (0.1186)  loss_classifier: 0.0338 (0.0342)  loss_box_reg: 0.0774 (0.0780)  loss_objectness: 0.0011 (0.0014)  loss_rpn_box_reg: 0.0019 (0.0049)  time: 2.1075  data: 0.1102  max mem: 19190
# Epoch: [5]  [100/250]  eta: 0:05:16  lr: 0.000100  loss: 0.1141 (0.1184)  loss_classifier: 0.0327 (0.0337)  loss_box_reg: 0.0793 (0.0792)  loss_objectness: 0.0005 (0.0013)  loss_rpn_box_reg: 0.0020 (0.0042)  time: 2.1004  data: 0.1047  max mem: 19190
# Epoch: [5]  [150/250]  eta: 0:03:30  lr: 0.000100  loss: 0.1085 (0.1181)  loss_classifier: 0.0293 (0.0336)  loss_box_reg: 0.0760 (0.0793)  loss_objectness: 0.0006 (0.0013)  loss_rpn_box_reg: 0.0022 (0.0040)  time: 2.1063  data: 0.1093  max mem: 19190
# Epoch: [5]  [200/250]  eta: 0:01:45  lr: 0.000100  loss: 0.1022 (0.1162)  loss_classifier: 0.0295 (0.0333)  loss_box_reg: 0.0688 (0.0779)  loss_objectness: 0.0006 (0.0012)  loss_rpn_box_reg: 0.0019 (0.0037)  time: 2.1073  data: 0.1108  max mem: 19190
# Epoch: [5]  [249/250]  eta: 0:00:02  lr: 0.000100  loss: 0.1085 (0.1150)  loss_classifier: 0.0327 (0.0330)  loss_box_reg: 0.0727 (0.0770)  loss_objectness: 0.0007 (0.0013)  loss_rpn_box_reg: 0.0019 (0.0037)  time: 2.1087  data: 0.1098  max mem: 19190
# Epoch: [5] Total time: 0:08:47 (2.1090 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8338 (0.8338)  evaluator_time: 0.0048 (0.0048)  time: 0.9362  data: 0.0886  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8434 (0.8197)  evaluator_time: 0.0052 (0.0099)  time: 0.9213  data: 0.0896  max mem: 19190
# Test: Total time: 0:00:29 (0.9304 s / it)
# Averaged stats: model_time: 0.8434 (0.8197)  evaluator_time: 0.0052 (0.0099)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.179
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.334
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.178
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.223
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.160
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.292
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.292
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.161
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.342
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.078
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8336 (0.8336)  evaluator_time: 0.0121 (0.0121)  time: 0.9404  data: 0.0855  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8336 (0.7912)  evaluator_time: 0.0109 (0.0111)  time: 0.9017  data: 0.0905  max mem: 19190
# Test: Total time: 0:00:05 (0.9019 s / it)
# Averaged stats: model_time: 0.8336 (0.7912)  evaluator_time: 0.0109 (0.0111)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.214
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.404
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.211
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.117
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.270
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.160
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.292
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.292
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.161
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.342
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.078
# EPOCH 6
# Epoch: [6]  [  0/250]  eta: 0:08:49  lr: 0.000100  loss: 0.1044 (0.1044)  loss_classifier: 0.0310 (0.0310)  loss_box_reg: 0.0708 (0.0708)  loss_objectness: 0.0010 (0.0010)  loss_rpn_box_reg: 0.0016 (0.0016)  time: 2.1171  data: 0.1166  max mem: 19190
# Epoch: [6]  [ 50/250]  eta: 0:07:03  lr: 0.000100  loss: 0.1056 (0.1095)  loss_classifier: 0.0305 (0.0316)  loss_box_reg: 0.0729 (0.0736)  loss_objectness: 0.0003 (0.0009)  loss_rpn_box_reg: 0.0021 (0.0035)  time: 2.1043  data: 0.1094  max mem: 19190
# Epoch: [6]  [100/250]  eta: 0:05:16  lr: 0.000100  loss: 0.1040 (0.1077)  loss_classifier: 0.0280 (0.0310)  loss_box_reg: 0.0714 (0.0718)  loss_objectness: 0.0005 (0.0011)  loss_rpn_box_reg: 0.0019 (0.0038)  time: 2.1103  data: 0.1119  max mem: 19190
# Epoch: [6]  [150/250]  eta: 0:03:31  lr: 0.000100  loss: 0.1003 (0.1049)  loss_classifier: 0.0287 (0.0302)  loss_box_reg: 0.0694 (0.0703)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0017 (0.0034)  time: 2.1093  data: 0.1099  max mem: 19190
# Epoch: [6]  [200/250]  eta: 0:01:45  lr: 0.000100  loss: 0.0911 (0.1024)  loss_classifier: 0.0247 (0.0293)  loss_box_reg: 0.0600 (0.0688)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0017 (0.0035)  time: 2.1083  data: 0.1074  max mem: 19190
# Epoch: [6]  [249/250]  eta: 0:00:02  lr: 0.000100  loss: 0.0818 (0.0998)  loss_classifier: 0.0233 (0.0286)  loss_box_reg: 0.0558 (0.0669)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0014 (0.0035)  time: 2.1093  data: 0.1110  max mem: 19190
# Epoch: [6] Total time: 0:08:47 (2.1097 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8310 (0.8310)  evaluator_time: 0.0039 (0.0039)  time: 0.9374  data: 0.0933  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8420 (0.8193)  evaluator_time: 0.0048 (0.0051)  time: 0.9162  data: 0.0920  max mem: 19190
# Test: Total time: 0:00:29 (0.9268 s / it)
# Averaged stats: model_time: 0.8420 (0.8193)  evaluator_time: 0.0048 (0.0051)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.196
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.364
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.203
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.113
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.237
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.161
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.297
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.297
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.145
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.351
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.089
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8354 (0.8354)  evaluator_time: 0.0126 (0.0126)  time: 0.9458  data: 0.0886  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8354 (0.7921)  evaluator_time: 0.0108 (0.0109)  time: 0.9031  data: 0.0912  max mem: 19190
# Test: Total time: 0:00:05 (0.9033 s / it)
# Averaged stats: model_time: 0.8354 (0.7921)  evaluator_time: 0.0108 (0.0109)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.230
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.430
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.237
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.121
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.279
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.161
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.297
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.297
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.145
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.351
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.089
# EPOCH 7
# Epoch: [7]  [  0/250]  eta: 0:08:49  lr: 0.000100  loss: 0.1040 (0.1040)  loss_classifier: 0.0290 (0.0290)  loss_box_reg: 0.0721 (0.0721)  loss_objectness: 0.0016 (0.0016)  loss_rpn_box_reg: 0.0013 (0.0013)  time: 2.1170  data: 0.1171  max mem: 19190
# Epoch: [7]  [ 50/250]  eta: 0:07:02  lr: 0.000100  loss: 0.0957 (0.0910)  loss_classifier: 0.0307 (0.0278)  loss_box_reg: 0.0616 (0.0593)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0017 (0.0030)  time: 2.1035  data: 0.1073  max mem: 19190
# Epoch: [7]  [100/250]  eta: 0:05:16  lr: 0.000100  loss: 0.0742 (0.0868)  loss_classifier: 0.0210 (0.0258)  loss_box_reg: 0.0512 (0.0580)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0014 (0.0024)  time: 2.1052  data: 0.1055  max mem: 19190
# Epoch: [7]  [150/250]  eta: 0:03:30  lr: 0.000100  loss: 0.0822 (0.0863)  loss_classifier: 0.0227 (0.0251)  loss_box_reg: 0.0559 (0.0576)  loss_objectness: 0.0005 (0.0006)  loss_rpn_box_reg: 0.0015 (0.0029)  time: 2.1103  data: 0.1113  max mem: 19190
# Epoch: [7]  [200/250]  eta: 0:01:45  lr: 0.000100  loss: 0.0866 (0.0857)  loss_classifier: 0.0241 (0.0251)  loss_box_reg: 0.0584 (0.0573)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0015 (0.0027)  time: 2.1073  data: 0.1089  max mem: 19190
# Epoch: [7]  [249/250]  eta: 0:00:02  lr: 0.000100  loss: 0.0805 (0.0841)  loss_classifier: 0.0239 (0.0246)  loss_box_reg: 0.0561 (0.0565)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0015 (0.0025)  time: 2.1057  data: 0.1068  max mem: 19190
# Epoch: [7] Total time: 0:08:47 (2.1085 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8328 (0.8328)  evaluator_time: 0.0039 (0.0039)  time: 0.9327  data: 0.0867  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8416 (0.8193)  evaluator_time: 0.0049 (0.0049)  time: 0.9133  data: 0.0894  max mem: 19190
# Test: Total time: 0:00:29 (0.9254 s / it)
# Averaged stats: model_time: 0.8416 (0.8193)  evaluator_time: 0.0049 (0.0049)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.200
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.355
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.215
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.124
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.241
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.179
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.285
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.285
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.159
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.345
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8336 (0.8336)  evaluator_time: 0.0108 (0.0108)  time: 0.9459  data: 0.0924  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8349 (0.7927)  evaluator_time: 0.0099 (0.0105)  time: 0.9071  data: 0.0952  max mem: 19190
# Test: Total time: 0:00:05 (0.9073 s / it)
# Averaged stats: model_time: 0.8349 (0.7927)  evaluator_time: 0.0099 (0.0105)
# Accumulating evaluation results...
# DONE (t=0.17s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.230
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.410
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.250
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.134
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.280
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.179
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.285
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.285
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.159
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.345
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 8
# Epoch: [8]  [  0/250]  eta: 0:08:47  lr: 0.000100  loss: 0.0838 (0.0838)  loss_classifier: 0.0225 (0.0225)  loss_box_reg: 0.0595 (0.0595)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0016 (0.0016)  time: 2.1093  data: 0.1073  max mem: 19190
# Epoch: [8]  [ 50/250]  eta: 0:07:02  lr: 0.000100  loss: 0.0738 (0.0794)  loss_classifier: 0.0213 (0.0236)  loss_box_reg: 0.0518 (0.0532)  loss_objectness: 0.0003 (0.0004)  loss_rpn_box_reg: 0.0014 (0.0022)  time: 2.1094  data: 0.1113  max mem: 19190
# Epoch: [8]  [100/250]  eta: 0:05:16  lr: 0.000100  loss: 0.0839 (0.0806)  loss_classifier: 0.0248 (0.0238)  loss_box_reg: 0.0568 (0.0540)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0013 (0.0024)  time: 2.1086  data: 0.1114  max mem: 19190
# Epoch: [8]  [150/250]  eta: 0:03:31  lr: 0.000100  loss: 0.0794 (0.0806)  loss_classifier: 0.0224 (0.0237)  loss_box_reg: 0.0542 (0.0543)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0015 (0.0021)  time: 2.1041  data: 0.1055  max mem: 19190
# Epoch: [8]  [200/250]  eta: 0:01:45  lr: 0.000100  loss: 0.0760 (0.0802)  loss_classifier: 0.0221 (0.0236)  loss_box_reg: 0.0523 (0.0539)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0014 (0.0021)  time: 2.1091  data: 0.1087  max mem: 19190
# Epoch: [8]  [249/250]  eta: 0:00:02  lr: 0.000100  loss: 0.0761 (0.0802)  loss_classifier: 0.0219 (0.0235)  loss_box_reg: 0.0513 (0.0538)  loss_objectness: 0.0003 (0.0005)  loss_rpn_box_reg: 0.0014 (0.0024)  time: 2.1040  data: 0.1043  max mem: 19190
# Epoch: [8] Total time: 0:08:47 (2.1095 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8261 (0.8261)  evaluator_time: 0.0038 (0.0038)  time: 0.9267  data: 0.0876  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8385 (0.8157)  evaluator_time: 0.0047 (0.0049)  time: 0.9103  data: 0.0898  max mem: 19190
# Test: Total time: 0:00:29 (0.9213 s / it)
# Averaged stats: model_time: 0.8385 (0.8157)  evaluator_time: 0.0047 (0.0049)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.192
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.343
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.185
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.123
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.236
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.175
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.286
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.286
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.169
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.344
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8339 (0.8339)  evaluator_time: 0.0110 (0.0110)  time: 0.9424  data: 0.0885  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8339 (0.7915)  evaluator_time: 0.0093 (0.0103)  time: 0.9059  data: 0.0953  max mem: 19190
# Test: Total time: 0:00:05 (0.9062 s / it)
# Averaged stats: model_time: 0.8339 (0.7915)  evaluator_time: 0.0093 (0.0103)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.224
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.404
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.212
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.141
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.276
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.175
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.286
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.286
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.169
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.344
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 9
# Epoch: [9]  [  0/250]  eta: 0:08:46  lr: 0.000100  loss: 0.0528 (0.0528)  loss_classifier: 0.0165 (0.0165)  loss_box_reg: 0.0355 (0.0355)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 2.1051  data: 0.1091  max mem: 19190
# Epoch: [9]  [ 50/250]  eta: 0:07:01  lr: 0.000100  loss: 0.0772 (0.0806)  loss_classifier: 0.0227 (0.0239)  loss_box_reg: 0.0525 (0.0528)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0016 (0.0035)  time: 2.1025  data: 0.1076  max mem: 19190
# Epoch: [9]  [100/250]  eta: 0:05:16  lr: 0.000100  loss: 0.0750 (0.0790)  loss_classifier: 0.0213 (0.0231)  loss_box_reg: 0.0499 (0.0521)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0013 (0.0031)  time: 2.1093  data: 0.1115  max mem: 19190
# Epoch: [9]  [150/250]  eta: 0:03:30  lr: 0.000100  loss: 0.0771 (0.0766)  loss_classifier: 0.0207 (0.0221)  loss_box_reg: 0.0530 (0.0512)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0013 (0.0026)  time: 2.1053  data: 0.1072  max mem: 19190
# Epoch: [9]  [200/250]  eta: 0:01:45  lr: 0.000100  loss: 0.0665 (0.0756)  loss_classifier: 0.0196 (0.0218)  loss_box_reg: 0.0458 (0.0509)  loss_objectness: 0.0001 (0.0005)  loss_rpn_box_reg: 0.0010 (0.0024)  time: 2.1083  data: 0.1095  max mem: 19190
# Epoch: [9]  [249/250]  eta: 0:00:02  lr: 0.000100  loss: 0.0725 (0.0746)  loss_classifier: 0.0224 (0.0216)  loss_box_reg: 0.0471 (0.0502)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0011 (0.0022)  time: 2.1063  data: 0.1083  max mem: 19190
# Epoch: [9] Total time: 0:08:46 (2.1074 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8306 (0.8306)  evaluator_time: 0.0039 (0.0039)  time: 0.9312  data: 0.0876  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8405 (0.8181)  evaluator_time: 0.0045 (0.0046)  time: 0.9140  data: 0.0916  max mem: 19190
# Test: Total time: 0:00:29 (0.9251 s / it)
# Averaged stats: model_time: 0.8405 (0.8181)  evaluator_time: 0.0045 (0.0046)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.192
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.338
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.207
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.120
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.233
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.172
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.287
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.287
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.342
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8299 (0.8299)  evaluator_time: 0.0117 (0.0117)  time: 0.9384  data: 0.0876  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8299 (0.7894)  evaluator_time: 0.0089 (0.0100)  time: 0.9022  data: 0.0940  max mem: 19190
# Test: Total time: 0:00:05 (0.9024 s / it)
# Averaged stats: model_time: 0.8299 (0.7894)  evaluator_time: 0.0089 (0.0100)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.223
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.395
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.235
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.134
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.272
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.172
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.287
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.287
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.342
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 10
# Epoch: [10]  [  0/250]  eta: 0:08:46  lr: 0.000100  loss: 0.0600 (0.0600)  loss_classifier: 0.0198 (0.0198)  loss_box_reg: 0.0389 (0.0389)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0011 (0.0011)  time: 2.1059  data: 0.1076  max mem: 19190
# Epoch: [10]  [ 50/250]  eta: 0:07:02  lr: 0.000100  loss: 0.0700 (0.0712)  loss_classifier: 0.0195 (0.0208)  loss_box_reg: 0.0458 (0.0481)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0011 (0.0020)  time: 2.1063  data: 0.1104  max mem: 19190
# Epoch: [10]  [100/250]  eta: 0:05:16  lr: 0.000100  loss: 0.0721 (0.0699)  loss_classifier: 0.0206 (0.0206)  loss_box_reg: 0.0486 (0.0471)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0011 (0.0019)  time: 2.1063  data: 0.1101  max mem: 19190
# Epoch: [10]  [150/250]  eta: 0:03:30  lr: 0.000100  loss: 0.0619 (0.0678)  loss_classifier: 0.0184 (0.0199)  loss_box_reg: 0.0423 (0.0455)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0009 (0.0021)  time: 2.1032  data: 0.1058  max mem: 19190
# Epoch: [10]  [200/250]  eta: 0:01:45  lr: 0.000100  loss: 0.0630 (0.0672)  loss_classifier: 0.0182 (0.0198)  loss_box_reg: 0.0412 (0.0453)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0010 (0.0020)  time: 2.1113  data: 0.1095  max mem: 19190
# Epoch: [10]  [249/250]  eta: 0:00:02  lr: 0.000100  loss: 0.0684 (0.0678)  loss_classifier: 0.0200 (0.0200)  loss_box_reg: 0.0458 (0.0456)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0011 (0.0021)  time: 2.1023  data: 0.1059  max mem: 19190
# Epoch: [10] Total time: 0:08:46 (2.1072 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8324 (0.8324)  evaluator_time: 0.0044 (0.0044)  time: 0.9392  data: 0.0934  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8376 (0.8177)  evaluator_time: 0.0050 (0.0050)  time: 0.9128  data: 0.0910  max mem: 19190
# Test: Total time: 0:00:29 (0.9242 s / it)
# Averaged stats: model_time: 0.8376 (0.8177)  evaluator_time: 0.0050 (0.0050)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.189
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.344
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.189
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.115
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.229
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# ...
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.316
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.204
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.123
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.211
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.160
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.246
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.246
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.152
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.294
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8327 (0.8327)  evaluator_time: 0.0099 (0.0099)  time: 0.9545  data: 0.1025  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8327 (0.7896)  evaluator_time: 0.0082 (0.0090)  time: 0.9042  data: 0.0966  max mem: 19190
# Test: Total time: 0:00:05 (0.9044 s / it)
# Averaged stats: model_time: 0.8327 (0.7896)  evaluator_time: 0.0082 (0.0090)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.198
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.353
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.225
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.134
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.240
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.160
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.246
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.246
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.152
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.294
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 27
# Epoch: [27]  [  0/250]  eta: 0:08:46  lr: 0.000100  loss: 0.0286 (0.0286)  loss_classifier: 0.0086 (0.0086)  loss_box_reg: 0.0192 (0.0192)  loss_objectness: 0.0006 (0.0006)  loss_rpn_box_reg: 0.0002 (0.0002)  time: 2.1065  data: 0.1071  max mem: 19190
# Epoch: [27]  [ 50/250]  eta: 0:07:05  lr: 0.000100  loss: 0.0351 (0.0379)  loss_classifier: 0.0116 (0.0123)  loss_box_reg: 0.0238 (0.0246)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0005 (0.0009)  time: 2.0978  data: 0.1048  max mem: 19190
# Epoch: [27]  [100/250]  eta: 0:05:17  lr: 0.000100  loss: 0.0361 (0.0379)  loss_classifier: 0.0125 (0.0124)  loss_box_reg: 0.0232 (0.0245)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0005 (0.0009)  time: 2.1034  data: 0.1079  max mem: 19190
# Epoch: [27]  [150/250]  eta: 0:03:31  lr: 0.000100  loss: 0.0486 (0.0405)  loss_classifier: 0.0159 (0.0139)  loss_box_reg: 0.0282 (0.0254)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0007 (0.0012)  time: 2.1033  data: 0.1086  max mem: 19190
# Epoch: [27]  [200/250]  eta: 0:01:45  lr: 0.000100  loss: 0.0458 (0.0420)  loss_classifier: 0.0153 (0.0146)  loss_box_reg: 0.0265 (0.0259)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0007 (0.0013)  time: 2.1033  data: 0.1108  max mem: 19190
# Epoch: [27]  [249/250]  eta: 0:00:02  lr: 0.000100  loss: 0.0579 (0.0445)  loss_classifier: 0.0250 (0.0161)  loss_box_reg: 0.0323 (0.0266)  loss_objectness: 0.0004 (0.0003)  loss_rpn_box_reg: 0.0010 (0.0015)  time: 2.1054  data: 0.1102  max mem: 19190
# Epoch: [27] Total time: 0:08:47 (2.1082 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8307 (0.8307)  evaluator_time: 0.0041 (0.0041)  time: 0.9305  data: 0.0864  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8430 (0.8207)  evaluator_time: 0.0055 (0.0052)  time: 0.9211  data: 0.0953  max mem: 19190
# Test: Total time: 0:00:29 (0.9307 s / it)
# Averaged stats: model_time: 0.8430 (0.8207)  evaluator_time: 0.0055 (0.0052)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.159
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.277
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.166
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.096
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.193
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.133
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.230
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.230
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.118
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.286
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8358 (0.8358)  evaluator_time: 0.0111 (0.0111)  time: 0.9471  data: 0.0906  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8358 (0.7927)  evaluator_time: 0.0109 (0.0107)  time: 0.9051  data: 0.0928  max mem: 19190
# Test: Total time: 0:00:05 (0.9053 s / it)
# Averaged stats: model_time: 0.8358 (0.7927)  evaluator_time: 0.0109 (0.0107)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.176
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.309
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.183
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.218
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.133
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.230
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.230
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.118
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.286
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 28
# Epoch: [28]  [  0/250]  eta: 0:08:49  lr: 0.000100  loss: 0.0747 (0.0747)  loss_classifier: 0.0221 (0.0221)  loss_box_reg: 0.0307 (0.0307)  loss_objectness: 0.0038 (0.0038)  loss_rpn_box_reg: 0.0181 (0.0181)  time: 2.1191  data: 0.1176  max mem: 19190
# Epoch: [28]  [ 50/250]  eta: 0:07:08  lr: 0.000100  loss: 0.0546 (0.0580)  loss_classifier: 0.0179 (0.0203)  loss_box_reg: 0.0308 (0.0327)  loss_objectness: 0.0016 (0.0023)  loss_rpn_box_reg: 0.0012 (0.0028)  time: 2.1455  data: 0.1487  max mem: 19190
# Epoch: [28]  [100/250]  eta: 0:05:20  lr: 0.000100  loss: 0.0542 (0.0590)  loss_classifier: 0.0202 (0.0215)  loss_box_reg: 0.0321 (0.0335)  loss_objectness: 0.0006 (0.0018)  loss_rpn_box_reg: 0.0012 (0.0022)  time: 2.1306  data: 0.1326  max mem: 19190
# Epoch: [28]  [150/250]  eta: 0:03:34  lr: 0.000100  loss: 0.0504 (0.0578)  loss_classifier: 0.0158 (0.0205)  loss_box_reg: 0.0337 (0.0336)  loss_objectness: 0.0003 (0.0015)  loss_rpn_box_reg: 0.0009 (0.0022)  time: 2.1592  data: 0.1537  max mem: 19190
# Epoch: [28]  [200/250]  eta: 0:01:47  lr: 0.000100  loss: 0.0449 (0.0554)  loss_classifier: 0.0152 (0.0193)  loss_box_reg: 0.0288 (0.0328)  loss_objectness: 0.0004 (0.0013)  loss_rpn_box_reg: 0.0009 (0.0019)  time: 2.1313  data: 0.1349  max mem: 19190
# Epoch: [28]  [249/250]  eta: 0:00:02  lr: 0.000100  loss: 0.0435 (0.0535)  loss_classifier: 0.0140 (0.0185)  loss_box_reg: 0.0284 (0.0320)  loss_objectness: 0.0003 (0.0012)  loss_rpn_box_reg: 0.0008 (0.0018)  time: 2.1324  data: 0.1353  max mem: 19190
# Epoch: [28] Total time: 0:08:55 (2.1423 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8302 (0.8302)  evaluator_time: 0.0046 (0.0046)  time: 0.9397  data: 0.0958  max mem: 19190
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8398 (0.8184)  evaluator_time: 0.0057 (0.0058)  time: 0.9789  data: 0.1556  max mem: 19190
# Test: Total time: 0:00:31 (0.9706 s / it)
# Averaged stats: model_time: 0.8398 (0.8184)  evaluator_time: 0.0057 (0.0058)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.158
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.264
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.177
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.096
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.202
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.156
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.250
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.250
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.152
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.301
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8325 (0.8325)  evaluator_time: 0.0120 (0.0120)  time: 0.9479  data: 0.0943  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8324 (0.7894)  evaluator_time: 0.0116 (0.0112)  time: 0.9064  data: 0.0971  max mem: 19190
# Test: Total time: 0:00:05 (0.9066 s / it)
# Averaged stats: model_time: 0.8324 (0.7894)  evaluator_time: 0.0116 (0.0112)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.196
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.328
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.221
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.113
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.244
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.156
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.250
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.250
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.152
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.301
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# EPOCH 29
# Epoch: [29]  [  0/250]  eta: 0:08:46  lr: 0.000100  loss: 0.0404 (0.0404)  loss_classifier: 0.0153 (0.0153)  loss_box_reg: 0.0239 (0.0239)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0010 (0.0010)  time: 2.1064  data: 0.1109  max mem: 19190
# Epoch: [29]  [ 50/250]  eta: 0:07:16  lr: 0.000100  loss: 0.0374 (0.0412)  loss_classifier: 0.0125 (0.0133)  loss_box_reg: 0.0238 (0.0263)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0006 (0.0013)  time: 2.1581  data: 0.1649  max mem: 19190
# Epoch: [29]  [100/250]  eta: 0:05:25  lr: 0.000100  loss: 0.0387 (0.0410)  loss_classifier: 0.0128 (0.0135)  loss_box_reg: 0.0246 (0.0259)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0006 (0.0011)  time: 2.1561  data: 0.1619  max mem: 19190
# Epoch: [29]  [150/250]  eta: 0:03:37  lr: 0.000100  loss: 0.0462 (0.0422)  loss_classifier: 0.0159 (0.0143)  loss_box_reg: 0.0283 (0.0263)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0007 (0.0011)  time: 2.1334  data: 0.1344  max mem: 19190
# Epoch: [29]  [200/250]  eta: 0:01:48  lr: 0.000100  loss: 0.0380 (0.0426)  loss_classifier: 0.0132 (0.0144)  loss_box_reg: 0.0247 (0.0266)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0007 (0.0012)  time: 2.1604  data: 0.1648  max mem: 19190
# Epoch: [29]  [249/250]  eta: 0:00:02  lr: 0.000100  loss: 0.0381 (0.0417)  loss_classifier: 0.0119 (0.0141)  loss_box_reg: 0.0243 (0.0261)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0006 (0.0011)  time: 2.1372  data: 0.1365  max mem: 19190
# Epoch: [29] Total time: 0:08:59 (2.1594 s / it)
# VALIDATION EVALUATION:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:30  model_time: 0.8353 (0.8353)  evaluator_time: 0.0036 (0.0036)  time: 0.9382  data: 0.0899  max mem: 19190
# Test:  [31/32]  eta: 0:00:01  model_time: 0.8413 (0.8197)  evaluator_time: 0.0045 (0.0043)  time: 1.0358  data: 0.2131  max mem: 19190
# Test: Total time: 0:00:32 (1.0026 s / it)
# Averaged stats: model_time: 0.8413 (0.8197)  evaluator_time: 0.0045 (0.0043)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.167
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.189
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.207
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.152
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.242
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.242
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.157
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.286
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# VALIDATION ANNOTATED EVALUATION:
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:05  model_time: 0.8347 (0.8347)  evaluator_time: 0.0098 (0.0098)  time: 0.9444  data: 0.0908  max mem: 19190
# Test:  [5/6]  eta: 0:00:00  model_time: 0.8347 (0.7917)  evaluator_time: 0.0091 (0.0096)  time: 0.9035  data: 0.0935  max mem: 19190
# Test: Total time: 0:00:05 (0.9037 s / it)
# Averaged stats: model_time: 0.8347 (0.7917)  evaluator_time: 0.0091 (0.0096)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.192
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.333
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.214
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.115
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.239
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.152
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.242
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.242
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.157
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.286
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Training complete!

# %% [markdown]
# # Evaluation

# %%
model_tune = fasterrcnn_resnet50_fpn_v2(weights="DEFAULT")
num_classes = 4
in_features = model_tune.roi_heads.box_predictor.cls_score.in_features
model_tune.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

checkpoint_path = os.path.join(
    "/content/gdrive/My Drive/Grad School/Dissertation/Data",
    "pretrain_transform_0.001_0.001_21.pt",
)
checkpoint = torch.load(checkpoint_path)

model_tune.load_state_dict(checkpoint["model"])

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model_tune.to(device)

print(f"Model loaded successfully from {checkpoint_path}")
# Out:
# Model loaded successfully from /content/gdrive/My Drive/Grad School/Dissertation/Data/pretrain_transform_0.001_0.001_21.pt

# %%
class AerialImageryDatasetOneClass(torch.utils.data.Dataset):
    def __init__(
        self, image_dir_path, annotation_path, background_weight, label, train=False
    ):
        self.image_dir_path = image_dir_path

        self.transforms = []
        if train:
            self.transforms.append(T.RandomHorizontalFlip(p=0.5))
            self.transforms.append(T.RandomVerticalFlip(p=0.5))

        self.transforms.append(T.ToDtype(torch.float, scale=True))
        self.transforms.append(T.ToPureTensor())
        self.transforms = T.Compose(self.transforms)

        self.label_map = {"daylighting": 1, "safety_islands": 2, "curb_extensions": 3}

        with open(annotation_path) as json_file:
            self.annotations = json.load(json_file)

        self.weights = []

        for item in tqdm(self.annotations):
            curr_weight = 1
            self.weights.append(curr_weight)

        self.label = label

    def __getitem__(self, idx):
        img_path = os.path.join(
            self.image_dir_path, self.annotations[idx]["image"].split("%5C")[-1]
        )

        img = decode_image(img_path, mode="RGB")

        if img.dtype != torch.float:
            img = to_dtype(img, dtype=torch.float, scale=True)

        img = tv_tensors.Image(img)

        if "label" in self.annotations[idx]:
            boxes = [
                [i["x"], i["y"], i["width"], i["height"]]
                for i in self.annotations[idx]["label"]
                if i["rectanglelabels"][0] == self.label
            ]

            if len(boxes) == 0:
                boxes = torch.zeros((0, 4), dtype=torch.float32)
                labels = torch.zeros((0,), dtype=torch.int64)
            else:
                boxes = convert_bounding_box_format(
                    tv_tensors.BoundingBoxes(
                        boxes, format="XYWH", canvas_size=get_size(img)
                    ),
                    new_format="XYXY",
                )
                boxes = tv_tensors.BoundingBoxes(
                    boxes * 416 / 100, format="XYXY", canvas_size=get_size(img)
                )
                labels = torch.tensor(
                    [
                        self.label_map[i["rectanglelabels"][0]]
                        for i in self.annotations[idx]["label"]
                        if i["rectanglelabels"][0] == self.label
                    ]
                )

        else:
            boxes = torch.zeros((0, 4), dtype=torch.float32)
            labels = torch.zeros((0,), dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = int(
            "".join(
                self.annotations[idx]["image"].split("%5C")[-1].split(".")[0].split("_")
            )
        )
        target["area"] = torch.tensor(
            [(box[2] - box[0]) * (box[3] - box[1]) for box in boxes]
        )
        target["iscrowd"] = torch.tensor([0] * len(boxes))

        img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.annotations)

# %%
from tqdm import tqdm

image_path = os.path.join(
    "/content/gdrive/My Drive/Grad School/Dissertation/Data", "test"
)
label_path = os.path.join(
    "/content/gdrive/My Drive/Grad School/Dissertation/Data", "test.json"
)

batch_size = 16

dataset_valtest = AerialImageryDatasetOneClass(
    image_dir_path=image_path,
    annotation_path=label_path,
    background_weight=0.001,
    label="curb_extensions",
    train=False,
)


g = torch.Generator()
g.manual_seed(2025)
indices = torch.randperm(n=len(dataset_valtest), generator=g).tolist()

subset_val = Subset(
    dataset_valtest,
    indices[int(len(dataset_valtest) * 0.8) : int(len(dataset_valtest) * 0.9)],
)

data_loader_val_curb = DataLoader(
    subset_val, batch_size=batch_size, collate_fn=utils.collate_fn
)

dataset_valtest = AerialImageryDatasetOneClass(
    image_dir_path=image_path,
    annotation_path=label_path,
    background_weight=0.001,
    label="daylighting",
    train=False,
)

g = torch.Generator()
g.manual_seed(2025)
indices = torch.randperm(n=len(dataset_valtest), generator=g).tolist()

subset_val = Subset(
    dataset_valtest,
    indices[int(len(dataset_valtest) * 0.8) : int(len(dataset_valtest) * 0.9)],
)

data_loader_val_day = DataLoader(
    subset_val, batch_size=batch_size, collate_fn=utils.collate_fn
)

dataset_valtest = AerialImageryDatasetOneClass(
    image_dir_path=image_path,
    annotation_path=label_path,
    background_weight=0.001,
    label="safety_islands",
    train=False,
)

g = torch.Generator()
g.manual_seed(2025)
indices = torch.randperm(n=len(dataset_valtest), generator=g).tolist()

subset_val = Subset(
    dataset_valtest,
    indices[int(len(dataset_valtest) * 0.8) : int(len(dataset_valtest) * 0.9)],
)

data_loader_val_island = DataLoader(
    subset_val, batch_size=batch_size, collate_fn=utils.collate_fn
)

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
# Out:
# 100%|██████████| 5000/5000 [00:00<00:00, 4317792.88it/s]
# 100%|██████████| 5000/5000 [00:00<00:00, 4184261.77it/s]
# 100%|██████████| 5000/5000 [00:00<00:00, 4104818.95it/s]

# %%
evaluate(model_tune, data_loader_val_curb, device=device)
# Out:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:01:14  model_time: 2.2217 (2.2217)  evaluator_time: 0.0066 (0.0066)  time: 2.3230  data: 0.0857  max mem: 5477
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8319 (0.8561)  evaluator_time: 0.0027 (0.0029)  time: 0.9164  data: 0.1039  max mem: 5486
# Test: Total time: 0:00:31 (0.9690 s / it)
# Averaged stats: model_time: 0.8319 (0.8561)  evaluator_time: 0.0027 (0.0029)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.015
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000

# %%
evaluate(model_tune, data_loader_val_day, device=device)
# Out:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8179 (0.8179)  evaluator_time: 0.0028 (0.0028)  time: 0.9130  data: 0.0834  max mem: 5486
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8261 (0.8045)  evaluator_time: 0.0031 (0.0032)  time: 0.8958  data: 0.0889  max mem: 5486
# Test: Total time: 0:00:29 (0.9069 s / it)
# Averaged stats: model_time: 0.8261 (0.8045)  evaluator_time: 0.0031 (0.0032)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.069
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.032
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.075
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.096
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.096
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.018
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.145
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000

# %%
evaluate(model_tune, data_loader_val_island, device=device)
# Out:
# creating index...
# index created!
# Test:  [ 0/32]  eta: 0:00:29  model_time: 0.8221 (0.8221)  evaluator_time: 0.0027 (0.0027)  time: 0.9205  data: 0.0866  max mem: 5486
# Test:  [31/32]  eta: 0:00:00  model_time: 0.8328 (0.8099)  evaluator_time: 0.0033 (0.0033)  time: 0.9024  data: 0.0895  max mem: 5486
# Test: Total time: 0:00:29 (0.9132 s / it)
# Averaged stats: model_time: 0.8328 (0.8099)  evaluator_time: 0.0033 (0.0033)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.352
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.653
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.316
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.258
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.419
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.256
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.449
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.449
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.343
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.511
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
